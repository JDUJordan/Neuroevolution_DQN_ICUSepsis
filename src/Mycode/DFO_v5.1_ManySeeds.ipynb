# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.3

# %%
import os
import sys
# Add the root directory to Python path
root_dir = "C:\\Users\\Jordan Lankford\\Documents\\GitHub\\FineTune-DQN"
if root_dir not in sys.path:
    sys.path.append(root_dir)

# Now imports should work
from src.utils.utils import set_seeds
import torch
import torch.nn as nn
import gymnasium as gym
import numpy as np
from src.utils.utils import set_seeds
from torchsummary import summary

def encode_state(obs, n_states):
    obs = torch.Tensor(obs)
    return nn.functional.one_hot(obs.long(), n_states).float()

def get_mask(info, n_actions=25):
    allowed_actions = info['admissible_actions']
    mask = np.zeros(n_actions)
    mask[allowed_actions] = 1
    return torch.Tensor(mask).unsqueeze(0)

# Modified QNetwork to match the deep DQN structure
class QNetwork(nn.Module):
    def __init__(self, env):
        super().__init__()
        self.n_states = env.observation_space.n
        self.n_actions = env.action_space.n
        
        # Match the architecture of the deep DQN
        self.network = nn.Sequential(
            nn.Linear(self.n_states, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, self.n_actions)
        )

    def forward(self, x, action_masks=None):
        q_values = self.network(x)
        if action_masks is not None:
            q_values = q_values - ((1 - action_masks) * 1e10)
        return q_values

# Create environment and network
env = gym.make('Sepsis/ICU-Sepsis-v2')
q_network = QNetwork(env)

# Load the trained deep DQN weights
model_path = r"C:\Users\Jordan Lankford\Documents\GitHub\FineTune-DQN\models\dqn\dqn_final_seed_0.pt"
state_dict = torch.load(model_path)

# Print the keys in the state dict to verify structure
print("State dict keys:", state_dict.keys())

# Load the weights
try:
    q_network.load_state_dict(state_dict)
    print("Successfully loaded weights!")
except Exception as e:
    print(f"Error loading weights: {e}")
    # Try loading with strict=False if there are issues
    q_network.load_state_dict(state_dict, strict=False)
    print("Loaded weights with strict=False")

# Print model structure
print("\nModel Architecture:")
print(q_network)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 9
#       6     sys.path.append(root_dir)
#       8 # Now imports should work
# ----> 9 from src.utils.utils import set_seeds
#      10 import torch
#      11 import torch.nn as nn
#
# File ~\Documents\GitHub\FineTune-DQN\src\utils\utils.py:1
# ----> 1 import numpy as np
#       2 import gymnasium as gym
#       3 import icu_sepsis
#
# ModuleNotFoundError: No module named 'numpy'

# %%
weight_shapes = []
for param in q_network.parameters():
    weight_shapes.append(param.shape)
print(weight_shapes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 weight_shapes = []
# ----> 2 for param in q_network.parameters():
#       3     weight_shapes.append(param.shape)
#       4 print(weight_shapes)
#
# NameError: name 'q_network' is not defined

# %%
values_in_dimension=[]
for shape in weight_shapes:
    values_in_dimension.append(np.prod(shape))
print(values_in_dimension)
# Out:
# [np.int64(91648), np.int64(128), np.int64(16384), np.int64(128), np.int64(3200), np.int64(25)]

# %%
weights = [param.detach().numpy() for param in q_network.parameters()]  # Get all model weights as numpy arrays

# %%
def f(fly, flies_history=None, model=q_network, env=env, eval_seeds=[0, 1, 2, 3, 4]):
    """Use fixed seeds for more consistent evaluation while maintaining some variety"""
    cloned_model = q_network
    reshaped_fly = reshape_to_model_weights(fly, model)
    cloned_model.load_state_dict(dict(zip([name for name, _ in cloned_model.named_parameters()], reshaped_fly)))
    cloned_model.eval()


    start_seed=0
    end_seed=200
    num_episodes_per_seed=100

    all_returns = []
    all_episode_lengths = []
    all_discounted_returns = []

for seed in range(start_seed, end_seed + 1):
        set_seeds(seed)
        env.action_space.seed(seed)
        env.observation_space.seed(seed)
        
        seed_returns = []
        seed_lengths = []
        seed_discounted_returns = []

        for episode in range(num_episodes_per_seed):
            state, info = env.reset(seed=seed)
            episode_reward = 0
            steps = 0
            done = False
            episode_rewards = []
            
            while not done:
                state_encoded = encode_state(np.array([state]), env.observation_space.n)
                action_mask = get_mask(info)
                
                state_encoded = state_encoded.to(device)
                action_mask = action_mask.to(device)
                
                with torch.no_grad():
                    q_values = q_network(state_encoded, action_mask)
                    action = torch.argmax(q_values, dim=1).cpu().item()
                
                next_state, reward, terminated, truncated, info = env.step(action)
                
                episode_rewards.append(reward)
                episode_reward += reward
                steps += 1
                state = next_state
                done = terminated or truncated

            discounted_return = calculate_discounted_return(episode_rewards)
            
            seed_returns.append(episode_reward)
            seed_lengths.append(steps)
            seed_discounted_returns.append(discounted_return)

        seed_mean_return = np.mean(seed_returns)
        all_returns.append(seed_mean_return)
        all_episode_lengths.append(np.mean(seed_lengths))
        all_discounted_returns.append(np.mean(seed_discounted_returns))
        
        if seed % 1 == 0:  # Print progress every 10 seeds
            print(f"Seed {seed} completed. Mean return: {seed_mean_return}")


        fitness = np.mean(all_returns),
    return -fitness
    #return -f_avrg(fitness, flies_history) if flies_history is not None else -fitness
# Out:
#   File <string>:68
#     return -fitness
#                    ^
# IndentationError: unindent does not match any outer indentation level

# %%
#run fly through the fitness function 20 times, calculate the range in fitness values

#f(fly, flies_history = None, model=q_network,env=env)
fitness_values = []
for i in range(10):
    fitness_values.append(f(flies[0], flies_history = None, model=q_network,env=env))

print(fitness_values)
#range of fitness values
range_fitness = max(fitness_values) - min(fitness_values)
print(range_fitness)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 6
#       4 fitness_values = []
#       5 for i in range(10):
# ----> 6     fitness_values.append(f(flies[0], flies_history = None, model=q_network,env=env))
#       8 print(fitness_values)
#       9 #range of fitness values
#
# NameError: name 'flies' is not defined

# %%
#standard deviation of fitness values
std_fitness = np.std(fitness_values)
print(std_fitness)
#mean of fitness values
mean_fitness = np.mean(fitness_values)
print(mean_fitness)

# %%
for i in range(20):
    #take the firtst ith number of flies and caluculate mean fitness
    mean_fitness = np.mean(fitness_values[:i])
    print("mean when using", i ,"flies:", mean_fitness)

# %%
def reshape_to_model_weights(flattened_fly, model=q_network):
    # List to store reshaped weights
    reshaped_weights = []
    counter = 0  # Counter for elements in fly
    
    # Get the shapes of the model's parameters
    values_in_dimension = [param.numel() for param in model.parameters()]
    weight_shapes = [param.shape for param in model.parameters()]
    
    for i in range(len(values_in_dimension)):
        # Get the flattened weights for this layer
        weight_flat = flattened_fly[counter: counter + values_in_dimension[i]]
        
        # Reshape and convert to torch.Tensor
        reshaped_layer_weights = torch.tensor(weight_flat, dtype=torch.float32).reshape(weight_shapes[i])
        
        # Append the reshaped weight to the list
        reshaped_weights.append(reshaped_layer_weights)
        
        # Move the counter to the next parameter block
        counter += values_in_dimension[i]
    
    return reshaped_weights
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 def reshape_to_model_weights(flattened_fly, model=q_network):
#       2     # List to store reshaped weights
#       3     reshaped_weights = []
#       4     counter = 0  # Counter for elements in fly
#
# NameError: name 'q_network' is not defined

# %%
def initialize_flies_from_model(number_of_flies, weights, model, inclusive):
    population = []

    if inclusive == False:
        for i in range(number_of_flies):
            fly = []  # This will hold the flattened weights for a single fly
            
            for param in model.parameters():  # Iterate through model parameters (weights and biases)
                # Generate random weights with the same shape as the model's weight matrix
                scalers = np.random.uniform(0.9, 1.1, size=param.shape)
                print(param.shape)  # Print the shape to see what the weights look like
                scaledweights = param.detach().numpy() * scalers  # Multiply the weight values by the scalers
                
                # Flatten the random weights and add them to the fly
                flattened_weights = scaledweights.flatten()
                fly.append(flattened_weights)
            
            # After flattening each layer's weights, flatten the entire fly and add to population
            population.append(np.concatenate(fly))  # Concatenate the list of flattened weight arrays
            
    if inclusive == True:
        for i in range(number_of_flies):
            fly = []  # This will hold the flattened weights for a single fly
            
            for param in model.parameters():  # Iterate through model parameters (weights and biases)
                if i == 0:
                    flattened_weights = param.detach().numpy().flatten()  # Get the flattened weights for the first fly
                    fly.append(flattened_weights)
                else:
                    scalers = np.random.uniform(0.9, 1.1, size=param.shape)
                    print(param.shape)  # Print the shape to see what the weights look like
                    scaledweights = param.detach().numpy() * scalers  # Multiply the weight values by the scalers
                    
                    # Flatten the random weights and add them to the fly
                    flattened_weights = scaledweights.flatten()
                    fly.append(flattened_weights)
                
            # After flattening each layer's weights, flatten the entire fly and add to population
            population.append(np.concatenate(fly))  # Concatenate the list of flattened weight arrays
        
    return population

# %%
num_of_flies = 10

flies = initialize_flies_from_model(num_of_flies,weights,q_network,True)



from collections import deque
max_history = 5
flies_history = [deque(maxlen=max_history) for _ in range(num_of_flies)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 num_of_flies = 10
# ----> 3 flies = initialize_flies_from_model(num_of_flies,weights,q_network,True)
#       7 from collections import deque
#       8 max_history = 5
#
# NameError: name 'weights' is not defined

# %%
print(flies_history[0])

# %%
def f_avrg(fitness, flies_history):

    flies_history.append(fitness)

    print(flies_history)

    return sum(flies_history) / len(flies_history) # mean

# %%
f(flies[0],flies_history[0])

# %%
len(flies[0])

# %%
N = len(flies)			# POPULATION SIZE
D = len(flies[0])					# DIMENSIONALITY 
#delta = 0.005			# DISTURBANCE THRESHOLD 
maxIterations = 200	# ITERATIONS ALLOWED
sd = np.std(flies[0])		# STANDARD DEVIATION

# %%
#print the min and max values and the range of the initial population
min_value = np.min(flies[0])
max_value = np.max(flies[0])
range_value = max_value - min_value
print("Initial Population:")
print("Min:", min_value)
print("Max:", max_value)
print("Range:", range_value)
sd = np.std(flies[0])
print("Standard Deviation:", sd)
median = np.median(flies[0])
print("Median:", median)
# Out:
# Initial Population:
# Min: -4.9936833
# Max: 4.964795
# Range: 9.958479
# Standard Deviation: 0.1878362
# Median: 0.0

# %%
import numpy as np

def disturbance_threashold_mechanism(delta, disturbance_counter, patience):
    if delta == 1 and disturbance_counter > patience:
        return 0, 0 #delta, disturbance_counter
    elif delta != 1 and disturbance_counter > patience:
        delta = (delta + np.random.uniform(high=0.5)) #add rand number between 0-0.5
        if delta > 1:
            return 1, 0
        else:
            return delta, 0
    else:
        return delta, disturbance_counter

# %%
def DFO(start_flies):
    """
    DFO with dynamic delta control and detailed fitness reporting
    """
    X = np.array(start_flies)     
    fitness = np.zeros(N)         
    #flies_history = [deque(maxlen=5) for _ in range(N)]
    disturbance_counter = 0
    fitness_history = []
    delta_history = []
    delta = 1
    
    for i in range(N):
        #fitness[i] = f(X[i], flies_history[i])
        fitness[i] = f(X[i])


    # Find initial best fly
    s = np.argmin(fitness)
    
    # Main DFO loop
    for itr in range(maxIterations):
        print(f"\n{'='*50}")
        print(f"Iteration: {itr}")
        print(f"Current delta: {delta:.6f}")
        print(f"disturbance_counter: {disturbance_counter}")

        for i in range(N):
            if i == s:
                print(f"Fly {i} (Best fly) fitness = {fitness[i]:.6f}")
                continue

            left = (i-1) % N
            right = (i+1) % N
            bNeighbour = right if fitness[right] < fitness[left] else left

            

            U = np.random.uniform(0, 1, D)
            R = np.random.uniform(0, 1, D)
            X[i] = np.where(R < delta,
                           np.random.normal(loc=X[bNeighbour], scale=2*sd),
                           X[bNeighbour] + U * (X[s] - X[i]))

            #new_fitness = f(X[i], flies_history[i])

            #print(f"\nFly {i} after update:")
            #print(f"First 5 dimensions: {X[i][:5]}")
            
        

            
            fitness[i] = f(X[i])
            
            
            
        new_s = np.argmin(fitness)
        
        if new_s <= s:
            disturbance_counter += 1
            delta, disturbance_counter = disturbance_threashold_mechanism(delta, disturbance_counter, patience=10)
        s = new_s
            

        fitness_history.append(fitness[s])
        delta_history.append(delta)
        
        print(f"\nEnd of iteration summary:")
        print(f"Best fly: {s} with fitness = {fitness[s]:.6f}")
        print(f"All flies fitness values:")
        for i in range(N):
            print(f"Fly {i}: {fitness[i]:.6f}")

    return X[s], fitness_history, delta_history

# %%
best_solution, fitness_history, delta_history = DFO(flies)
# Out:
# ==================================================
# Iteration: 0
# Current delta: 1.000000
# disturbance_counter: 0
# Fly 0 (Best fly) fitness = -0.810850
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.810850
# All flies fitness values:
# Fly 0: -0.810850
# Fly 1: -0.767150
# Fly 2: -0.780400
# Fly 3: -0.787250
# Fly 4: -0.781450
# Fly 5: -0.782350
# Fly 6: -0.757000
# Fly 7: -0.783500
# Fly 8: -0.780350
# Fly 9: -0.769600
#
# ==================================================
# Iteration: 1
# Current delta: 1.000000
# disturbance_counter: 1
# Fly 0 (Best fly) fitness = -0.810850
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.810850
# All flies fitness values:
# Fly 0: -0.810850
# Fly 1: -0.789900
# Fly 2: -0.774000
# Fly 3: -0.780350
# Fly 4: -0.779300
# Fly 5: -0.789600
# Fly 6: -0.777600
# Fly 7: -0.784900
# Fly 8: -0.774400
# Fly 9: -0.769150
#
# ==================================================
# Iteration: 2
# Current delta: 1.000000
# disturbance_counter: 2
# Fly 0 (Best fly) fitness = -0.810850
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.810850
# All flies fitness values:
# Fly 0: -0.810850
# Fly 1: -0.767200
# Fly 2: -0.785550
# Fly 3: -0.776200
# Fly 4: -0.781700
# Fly 5: -0.774600
# Fly 6: -0.768050
# Fly 7: -0.772300
# Fly 8: -0.775500
# Fly 9: -0.785250
#
# ==================================================
# Iteration: 3
# Current delta: 1.000000
# disturbance_counter: 3
# Fly 0 (Best fly) fitness = -0.810850
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.810850
# All flies fitness values:
# Fly 0: -0.810850
# Fly 1: -0.773200
# Fly 2: -0.775600
# Fly 3: -0.773400
# Fly 4: -0.782150
# Fly 5: -0.777550
# Fly 6: -0.782450
# Fly 7: -0.781200
# Fly 8: -0.781800
# Fly 9: -0.776250
#
# ==================================================
# Iteration: 4
# Current delta: 1.000000
# disturbance_counter: 4
# Fly 0 (Best fly) fitness = -0.810850
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.810850
# All flies fitness values:
# Fly 0: -0.810850
# Fly 1: -0.778700
# Fly 2: -0.769050
# Fly 3: -0.789750
# Fly 4: -0.777400
# Fly 5: -0.777050
# Fly 6: -0.779900
# Fly 7: -0.784750
# Fly 8: -0.791850
# Fly 9: -0.779800
#
# ==================================================
# Iteration: 5
# Current delta: 1.000000
# disturbance_counter: 5
# Fly 0 (Best fly) fitness = -0.810850
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.810850
# All flies fitness values:
# Fly 0: -0.810850
# Fly 1: -0.779250
# Fly 2: -0.785500
# Fly 3: -0.788000
# Fly 4: -0.786900
# Fly 5: -0.778600
# Fly 6: -0.791300
# Fly 7: -0.765200
# Fly 8: -0.774250
# Fly 9: -0.763350
#
# ==================================================
# Iteration: 6
# Current delta: 1.000000
# disturbance_counter: 6
# Fly 0 (Best fly) fitness = -0.810850
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.810850
# All flies fitness values:
# Fly 0: -0.810850
# Fly 1: -0.763450
# Fly 2: -0.784150
# Fly 3: -0.780950
# Fly 4: -0.783650
# Fly 5: -0.782600
# Fly 6: -0.767200
# Fly 7: -0.769200
# Fly 8: -0.764350
# Fly 9: -0.776700
#
# ==================================================
# Iteration: 7
# Current delta: 1.000000
# disturbance_counter: 7
# Fly 0 (Best fly) fitness = -0.810850
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.810850
# All flies fitness values:
# Fly 0: -0.810850
# Fly 1: -0.779500
# Fly 2: -0.781150
# Fly 3: -0.784500
# Fly 4: -0.788850
# Fly 5: -0.796450
# Fly 6: -0.793800
# Fly 7: -0.788450
# Fly 8: -0.787000
# Fly 9: -0.784600
#
# ==================================================
# Iteration: 8
# Current delta: 1.000000
# disturbance_counter: 8
# Fly 0 (Best fly) fitness = -0.810850
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.810850
# All flies fitness values:
# Fly 0: -0.810850
# Fly 1: -0.765500
# Fly 2: -0.789000
# Fly 3: -0.780900
# Fly 4: -0.788400
# Fly 5: -0.794300
# Fly 6: -0.781600
# Fly 7: -0.788450
# Fly 8: -0.795000
# Fly 9: -0.774450
#
# ==================================================
# Iteration: 9
# Current delta: 1.000000
# disturbance_counter: 9
# Fly 0 (Best fly) fitness = -0.810850
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.810850
# All flies fitness values:
# Fly 0: -0.810850
# Fly 1: -0.765450
# Fly 2: -0.782700
# Fly 3: -0.783000
# Fly 4: -0.786050
# Fly 5: -0.783200
# Fly 6: -0.786850
# Fly 7: -0.788050
# Fly 8: -0.791500
# Fly 9: -0.752850
#
# ==================================================
# Iteration: 10
# Current delta: 1.000000
# disturbance_counter: 10
# Fly 0 (Best fly) fitness = -0.810850
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.810850
# All flies fitness values:
# Fly 0: -0.810850
# Fly 1: -0.760200
# Fly 2: -0.785600
# Fly 3: -0.781400
# Fly 4: -0.780100
# Fly 5: -0.779650
# Fly 6: -0.789850
# Fly 7: -0.791800
# Fly 8: -0.785950
# Fly 9: -0.767450
#
# ==================================================
# Iteration: 11
# Current delta: 0.000000
# disturbance_counter: 0
# Fly 0 (Best fly) fitness = -0.810850
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.810850
# All flies fitness values:
# Fly 0: -0.810850
# Fly 1: -0.774750
# Fly 2: -0.766400
# Fly 3: -0.773750
# Fly 4: -0.782650
# Fly 5: -0.784850
# Fly 6: -0.789800
# Fly 7: -0.759950
# Fly 8: -0.763750
# Fly 9: -0.794800
#
# ==================================================
# Iteration: 12
# Current delta: 0.000000
# disturbance_counter: 1
# Fly 0 (Best fly) fitness = -0.810850
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.810850
# All flies fitness values:
# Fly 0: -0.810850
# Fly 1: -0.796450
# Fly 2: -0.761400
# Fly 3: -0.784200
# Fly 4: -0.789450
# Fly 5: -0.763350
# Fly 6: -0.770600
# Fly 7: -0.781650
# Fly 8: -0.790200
# Fly 9: -0.798600
#
# ==================================================
# Iteration: 13
# Current delta: 0.000000
# disturbance_counter: 2
# Fly 0 (Best fly) fitness = -0.810850
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.810850
# All flies fitness values:
# Fly 0: -0.810850
# Fly 1: -0.803150
# Fly 2: -0.752350
# Fly 3: -0.790750
# Fly 4: -0.774950
# Fly 5: -0.784850
# Fly 6: -0.776000
# Fly 7: -0.792200
# Fly 8: -0.767750
# Fly 9: -0.800500
#
# ==================================================
# Iteration: 14
# Current delta: 0.000000
# disturbance_counter: 3
# Fly 0 (Best fly) fitness = -0.810850
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.810850
# All flies fitness values:
# Fly 0: -0.810850
# Fly 1: -0.801500
# Fly 2: -0.779350
# Fly 3: -0.764300
# Fly 4: -0.783400
# Fly 5: -0.776400
# Fly 6: -0.786750
# Fly 7: -0.778950
# Fly 8: -0.788200
# Fly 9: -0.805700
#
# ==================================================
# Iteration: 15
# Current delta: 0.000000
# disturbance_counter: 4
# Fly 0 (Best fly) fitness = -0.810850
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.810850
# All flies fitness values:
# Fly 0: -0.810850
# Fly 1: -0.800350
# Fly 2: -0.783350
# Fly 3: -0.776700
# Fly 4: -0.782550
# Fly 5: -0.786650
# Fly 6: -0.787100
# Fly 7: -0.788750
# Fly 8: -0.784700
# Fly 9: -0.801650
#
# ==================================================
# Iteration: 16
# Current delta: 0.000000
# disturbance_counter: 5
# Fly 0 (Best fly) fitness = -0.810850
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.810850
# All flies fitness values:
# Fly 0: -0.810850
# Fly 1: -0.807850
# Fly 2: -0.796700
# Fly 3: -0.785550
# Fly 4: -0.786600
# Fly 5: -0.787450
# Fly 6: -0.778850
# Fly 7: -0.769700
# Fly 8: -0.794400
# Fly 9: -0.807900
#
# ==================================================
# Iteration: 17
# Current delta: 0.000000
# disturbance_counter: 6
# Fly 0 (Best fly) fitness = -0.810850
#
# End of iteration summary:
# Best fly: 1 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.810850
# Fly 1: -0.811800
# Fly 2: -0.798400
# Fly 3: -0.777650
# Fly 4: -0.785350
# Fly 5: -0.779400
# Fly 6: -0.778000
# Fly 7: -0.785850
# Fly 8: -0.794050
# Fly 9: -0.805800
#
# ==================================================
# Iteration: 18
# Current delta: 0.000000
# disturbance_counter: 6
# Fly 1 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 1 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811550
# Fly 1: -0.811800
# Fly 2: -0.809450
# Fly 3: -0.781500
# Fly 4: -0.773200
# Fly 5: -0.777450
# Fly 6: -0.782150
# Fly 7: -0.774150
# Fly 8: -0.804150
# Fly 9: -0.809750
#
# ==================================================
# Iteration: 19
# Current delta: 0.000000
# disturbance_counter: 7
# Fly 1 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 1 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.810850
# Fly 1: -0.811800
# Fly 2: -0.805650
# Fly 3: -0.791700
# Fly 4: -0.777750
# Fly 5: -0.792750
# Fly 6: -0.795500
# Fly 7: -0.795250
# Fly 8: -0.800900
# Fly 9: -0.810850
#
# ==================================================
# Iteration: 20
# Current delta: 0.000000
# disturbance_counter: 8
# Fly 1 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.811800
# Fly 2: -0.810500
# Fly 3: -0.796550
# Fly 4: -0.774000
# Fly 5: -0.774150
# Fly 6: -0.785000
# Fly 7: -0.781000
# Fly 8: -0.807050
# Fly 9: -0.811200
#
# ==================================================
# Iteration: 21
# Current delta: 0.000000
# disturbance_counter: 9
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.811800
# Fly 2: -0.803250
# Fly 3: -0.795600
# Fly 4: -0.790050
# Fly 5: -0.786400
# Fly 6: -0.787450
# Fly 7: -0.796800
# Fly 8: -0.804900
# Fly 9: -0.811700
#
# ==================================================
# Iteration: 22
# Current delta: 0.000000
# disturbance_counter: 10
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.811800
# Fly 2: -0.811750
# Fly 3: -0.802500
# Fly 4: -0.796600
# Fly 5: -0.766150
# Fly 6: -0.772550
# Fly 7: -0.802350
# Fly 8: -0.809600
# Fly 9: -0.811800
#
# ==================================================
# Iteration: 23
# Current delta: 0.383217
# disturbance_counter: 0
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.785450
# Fly 2: -0.781150
# Fly 3: -0.792550
# Fly 4: -0.794550
# Fly 5: -0.784700
# Fly 6: -0.781800
# Fly 7: -0.782400
# Fly 8: -0.796400
# Fly 9: -0.778050
#
# ==================================================
# Iteration: 24
# Current delta: 0.383217
# disturbance_counter: 1
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.781550
# Fly 2: -0.780950
# Fly 3: -0.780200
# Fly 4: -0.792750
# Fly 5: -0.788200
# Fly 6: -0.784150
# Fly 7: -0.772300
# Fly 8: -0.762600
# Fly 9: -0.779500
#
# ==================================================
# Iteration: 25
# Current delta: 0.383217
# disturbance_counter: 2
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.762600
# Fly 2: -0.790900
# Fly 3: -0.767000
# Fly 4: -0.766150
# Fly 5: -0.774850
# Fly 6: -0.771150
# Fly 7: -0.775150
# Fly 8: -0.763300
# Fly 9: -0.781550
#
# ==================================================
# Iteration: 26
# Current delta: 0.383217
# disturbance_counter: 3
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.781650
# Fly 2: -0.785850
# Fly 3: -0.790050
# Fly 4: -0.778100
# Fly 5: -0.776900
# Fly 6: -0.790850
# Fly 7: -0.783050
# Fly 8: -0.784450
# Fly 9: -0.772150
#
# ==================================================
# Iteration: 27
# Current delta: 0.383217
# disturbance_counter: 4
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.788850
# Fly 2: -0.778200
# Fly 3: -0.768650
# Fly 4: -0.776050
# Fly 5: -0.777300
# Fly 6: -0.787000
# Fly 7: -0.778400
# Fly 8: -0.782300
# Fly 9: -0.780250
#
# ==================================================
# Iteration: 28
# Current delta: 0.383217
# disturbance_counter: 5
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.781200
# Fly 2: -0.781950
# Fly 3: -0.781950
# Fly 4: -0.770650
# Fly 5: -0.775600
# Fly 6: -0.779100
# Fly 7: -0.769400
# Fly 8: -0.783000
# Fly 9: -0.778050
#
# ==================================================
# Iteration: 29
# Current delta: 0.383217
# disturbance_counter: 6
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.772300
# Fly 2: -0.781550
# Fly 3: -0.774000
# Fly 4: -0.777100
# Fly 5: -0.787000
# Fly 6: -0.780700
# Fly 7: -0.762900
# Fly 8: -0.773100
# Fly 9: -0.784600
#
# ==================================================
# Iteration: 30
# Current delta: 0.383217
# disturbance_counter: 7
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.773950
# Fly 2: -0.766050
# Fly 3: -0.777200
# Fly 4: -0.786200
# Fly 5: -0.781700
# Fly 6: -0.784850
# Fly 7: -0.786000
# Fly 8: -0.784000
# Fly 9: -0.784950
#
# ==================================================
# Iteration: 31
# Current delta: 0.383217
# disturbance_counter: 8
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.782500
# Fly 2: -0.758500
# Fly 3: -0.784300
# Fly 4: -0.779450
# Fly 5: -0.781750
# Fly 6: -0.778550
# Fly 7: -0.789700
# Fly 8: -0.774850
# Fly 9: -0.788250
#
# ==================================================
# Iteration: 32
# Current delta: 0.383217
# disturbance_counter: 9
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.782000
# Fly 2: -0.785000
# Fly 3: -0.780250
# Fly 4: -0.766200
# Fly 5: -0.788900
# Fly 6: -0.790550
# Fly 7: -0.781300
# Fly 8: -0.777650
# Fly 9: -0.786350
#
# ==================================================
# Iteration: 33
# Current delta: 0.383217
# disturbance_counter: 10
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.786100
# Fly 2: -0.752300
# Fly 3: -0.782150
# Fly 4: -0.788300
# Fly 5: -0.786450
# Fly 6: -0.794950
# Fly 7: -0.793950
# Fly 8: -0.792750
# Fly 9: -0.776300
#
# ==================================================
# Iteration: 34
# Current delta: 0.731172
# disturbance_counter: 0
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.776700
# Fly 2: -0.792650
# Fly 3: -0.776500
# Fly 4: -0.793650
# Fly 5: -0.786100
# Fly 6: -0.781050
# Fly 7: -0.790800
# Fly 8: -0.784100
# Fly 9: -0.770200
#
# ==================================================
# Iteration: 35
# Current delta: 0.731172
# disturbance_counter: 1
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.769150
# Fly 2: -0.769100
# Fly 3: -0.787300
# Fly 4: -0.775050
# Fly 5: -0.778350
# Fly 6: -0.784700
# Fly 7: -0.785200
# Fly 8: -0.796450
# Fly 9: -0.787450
#
# ==================================================
# Iteration: 36
# Current delta: 0.731172
# disturbance_counter: 2
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.789500
# Fly 2: -0.782950
# Fly 3: -0.777850
# Fly 4: -0.786400
# Fly 5: -0.760300
# Fly 6: -0.780700
# Fly 7: -0.784850
# Fly 8: -0.774800
# Fly 9: -0.771200
#
# ==================================================
# Iteration: 37
# Current delta: 0.731172
# disturbance_counter: 3
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.772750
# Fly 2: -0.787400
# Fly 3: -0.783850
# Fly 4: -0.774700
# Fly 5: -0.783950
# Fly 6: -0.787400
# Fly 7: -0.783300
# Fly 8: -0.767900
# Fly 9: -0.777000
#
# ==================================================
# Iteration: 38
# Current delta: 0.731172
# disturbance_counter: 4
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.775550
# Fly 2: -0.782000
# Fly 3: -0.777450
# Fly 4: -0.770900
# Fly 5: -0.791350
# Fly 6: -0.791700
# Fly 7: -0.787450
# Fly 8: -0.784700
# Fly 9: -0.773750
#
# ==================================================
# Iteration: 39
# Current delta: 0.731172
# disturbance_counter: 5
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.763000
# Fly 2: -0.775400
# Fly 3: -0.777350
# Fly 4: -0.786250
# Fly 5: -0.788500
# Fly 6: -0.794500
# Fly 7: -0.788950
# Fly 8: -0.791100
# Fly 9: -0.774150
#
# ==================================================
# Iteration: 40
# Current delta: 0.731172
# disturbance_counter: 6
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.773000
# Fly 2: -0.770450
# Fly 3: -0.787500
# Fly 4: -0.782650
# Fly 5: -0.783600
# Fly 6: -0.781050
# Fly 7: -0.790600
# Fly 8: -0.790850
# Fly 9: -0.777950
#
# ==================================================
# Iteration: 41
# Current delta: 0.731172
# disturbance_counter: 7
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.776850
# Fly 2: -0.789200
# Fly 3: -0.793500
# Fly 4: -0.790200
# Fly 5: -0.787850
# Fly 6: -0.794350
# Fly 7: -0.791700
# Fly 8: -0.770000
# Fly 9: -0.775350
#
# ==================================================
# Iteration: 42
# Current delta: 0.731172
# disturbance_counter: 8
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.782500
# Fly 2: -0.785350
# Fly 3: -0.787250
# Fly 4: -0.783650
# Fly 5: -0.778100
# Fly 6: -0.775900
# Fly 7: -0.759800
# Fly 8: -0.787250
# Fly 9: -0.769850
#
# ==================================================
# Iteration: 43
# Current delta: 0.731172
# disturbance_counter: 9
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.772800
# Fly 2: -0.790300
# Fly 3: -0.790400
# Fly 4: -0.794350
# Fly 5: -0.780950
# Fly 6: -0.792150
# Fly 7: -0.792950
# Fly 8: -0.796050
# Fly 9: -0.770950
#
# ==================================================
# Iteration: 44
# Current delta: 0.731172
# disturbance_counter: 10
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.772050
# Fly 2: -0.794500
# Fly 3: -0.784500
# Fly 4: -0.776500
# Fly 5: -0.785050
# Fly 6: -0.789100
# Fly 7: -0.789700
# Fly 8: -0.785450
# Fly 9: -0.762550
#
# ==================================================
# Iteration: 45
# Current delta: 0.989312
# disturbance_counter: 0
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.779950
# Fly 2: -0.772650
# Fly 3: -0.784550
# Fly 4: -0.788650
# Fly 5: -0.791500
# Fly 6: -0.792400
# Fly 7: -0.793950
# Fly 8: -0.787550
# Fly 9: -0.772250
#
# ==================================================
# Iteration: 46
# Current delta: 0.989312
# disturbance_counter: 1
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.775200
# Fly 2: -0.789850
# Fly 3: -0.787050
# Fly 4: -0.797250
# Fly 5: -0.793450
# Fly 6: -0.792500
# Fly 7: -0.791500
# Fly 8: -0.793950
# Fly 9: -0.784150
#
# ==================================================
# Iteration: 47
# Current delta: 0.989312
# disturbance_counter: 2
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.780400
# Fly 2: -0.782850
# Fly 3: -0.794750
# Fly 4: -0.791450
# Fly 5: -0.791150
# Fly 6: -0.795450
# Fly 7: -0.792700
# Fly 8: -0.793850
# Fly 9: -0.771700
#
# ==================================================
# Iteration: 48
# Current delta: 0.989312
# disturbance_counter: 3
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.785350
# Fly 2: -0.796700
# Fly 3: -0.794500
# Fly 4: -0.787900
# Fly 5: -0.794350
# Fly 6: -0.789350
# Fly 7: -0.787150
# Fly 8: -0.795300
# Fly 9: -0.755700
#
# ==================================================
# Iteration: 49
# Current delta: 0.989312
# disturbance_counter: 4
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.782950
# Fly 2: -0.792600
# Fly 3: -0.795250
# Fly 4: -0.794600
# Fly 5: -0.783050
# Fly 6: -0.788900
# Fly 7: -0.790050
# Fly 8: -0.783150
# Fly 9: -0.780750
#
# ==================================================
# Iteration: 50
# Current delta: 0.989312
# disturbance_counter: 5
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.776750
# Fly 2: -0.788850
# Fly 3: -0.794400
# Fly 4: -0.795650
# Fly 5: -0.795050
# Fly 6: -0.790850
# Fly 7: -0.793500
# Fly 8: -0.794250
# Fly 9: -0.787750
#
# ==================================================
# Iteration: 51
# Current delta: 0.989312
# disturbance_counter: 6
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.773050
# Fly 2: -0.790100
# Fly 3: -0.791800
# Fly 4: -0.791500
# Fly 5: -0.792250
# Fly 6: -0.790950
# Fly 7: -0.791850
# Fly 8: -0.790450
# Fly 9: -0.784350
#
# ==================================================
# Iteration: 52
# Current delta: 0.989312
# disturbance_counter: 7
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.776300
# Fly 2: -0.792450
# Fly 3: -0.790850
# Fly 4: -0.791150
# Fly 5: -0.784600
# Fly 6: -0.792800
# Fly 7: -0.791000
# Fly 8: -0.793800
# Fly 9: -0.766650
#
# ==================================================
# Iteration: 53
# Current delta: 0.989312
# disturbance_counter: 8
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.776000
# Fly 2: -0.782900
# Fly 3: -0.784550
# Fly 4: -0.783850
# Fly 5: -0.796600
# Fly 6: -0.794300
# Fly 7: -0.786200
# Fly 8: -0.795050
# Fly 9: -0.787450
#
# ==================================================
# Iteration: 54
# Current delta: 0.989312
# disturbance_counter: 9
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.778850
# Fly 2: -0.787000
# Fly 3: -0.792950
# Fly 4: -0.795350
# Fly 5: -0.796100
# Fly 6: -0.790300
# Fly 7: -0.795050
# Fly 8: -0.793700
# Fly 9: -0.779650
#
# ==================================================
# Iteration: 55
# Current delta: 0.989312
# disturbance_counter: 10
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.780150
# Fly 2: -0.781100
# Fly 3: -0.796200
# Fly 4: -0.786250
# Fly 5: -0.790600
# Fly 6: -0.793000
# Fly 7: -0.792900
# Fly 8: -0.792500
# Fly 9: -0.786800
#
# ==================================================
# Iteration: 56
# Current delta: 1.000000
# disturbance_counter: 0
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.771300
# Fly 2: -0.788350
# Fly 3: -0.789600
# Fly 4: -0.793300
# Fly 5: -0.786700
# Fly 6: -0.792400
# Fly 7: -0.795750
# Fly 8: -0.800400
# Fly 9: -0.779350
#
# ==================================================
# Iteration: 57
# Current delta: 1.000000
# disturbance_counter: 1
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.774200
# Fly 2: -0.794850
# Fly 3: -0.791250
# Fly 4: -0.787700
# Fly 5: -0.793450
# Fly 6: -0.794850
# Fly 7: -0.799650
# Fly 8: -0.798800
# Fly 9: -0.770050
#
# ==================================================
# Iteration: 58
# Current delta: 1.000000
# disturbance_counter: 2
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.778450
# Fly 2: -0.798300
# Fly 3: -0.794100
# Fly 4: -0.789650
# Fly 5: -0.793650
# Fly 6: -0.792750
# Fly 7: -0.794200
# Fly 8: -0.794700
# Fly 9: -0.784650
#
# ==================================================
# Iteration: 59
# Current delta: 1.000000
# disturbance_counter: 3
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.775100
# Fly 2: -0.794050
# Fly 3: -0.795400
# Fly 4: -0.795450
# Fly 5: -0.789700
# Fly 6: -0.789750
# Fly 7: -0.800350
# Fly 8: -0.795150
# Fly 9: -0.776100
#
# ==================================================
# Iteration: 60
# Current delta: 1.000000
# disturbance_counter: 4
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.771900
# Fly 2: -0.796350
# Fly 3: -0.791950
# Fly 4: -0.794750
# Fly 5: -0.794450
# Fly 6: -0.796150
# Fly 7: -0.796000
# Fly 8: -0.796400
# Fly 9: -0.766050
#
# ==================================================
# Iteration: 61
# Current delta: 1.000000
# disturbance_counter: 5
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.770100
# Fly 2: -0.789200
# Fly 3: -0.787450
# Fly 4: -0.792700
# Fly 5: -0.800200
# Fly 6: -0.795450
# Fly 7: -0.799450
# Fly 8: -0.801200
# Fly 9: -0.767050
#
# ==================================================
# Iteration: 62
# Current delta: 1.000000
# disturbance_counter: 6
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.773100
# Fly 2: -0.791500
# Fly 3: -0.796350
# Fly 4: -0.794250
# Fly 5: -0.796050
# Fly 6: -0.800950
# Fly 7: -0.798700
# Fly 8: -0.799750
# Fly 9: -0.798500
#
# ==================================================
# Iteration: 63
# Current delta: 1.000000
# disturbance_counter: 7
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.764200
# Fly 2: -0.796000
# Fly 3: -0.803250
# Fly 4: -0.797650
# Fly 5: -0.798850
# Fly 6: -0.799800
# Fly 7: -0.797300
# Fly 8: -0.778050
# Fly 9: -0.784450
#
# ==================================================
# Iteration: 64
# Current delta: 1.000000
# disturbance_counter: 8
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.789800
# Fly 2: -0.796450
# Fly 3: -0.799400
# Fly 4: -0.796100
# Fly 5: -0.795450
# Fly 6: -0.794800
# Fly 7: -0.796750
# Fly 8: -0.793150
# Fly 9: -0.784400
#
# ==================================================
# Iteration: 65
# Current delta: 1.000000
# disturbance_counter: 9
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.782700
# Fly 2: -0.797600
# Fly 3: -0.789000
# Fly 4: -0.796000
# Fly 5: -0.795200
# Fly 6: -0.796550
# Fly 7: -0.798000
# Fly 8: -0.796000
# Fly 9: -0.772250
#
# ==================================================
# Iteration: 66
# Current delta: 1.000000
# disturbance_counter: 10
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.779400
# Fly 2: -0.799350
# Fly 3: -0.793950
# Fly 4: -0.792500
# Fly 5: -0.794950
# Fly 6: -0.796700
# Fly 7: -0.796600
# Fly 8: -0.797050
# Fly 9: -0.788500
#
# ==================================================
# Iteration: 67
# Current delta: 0.000000
# disturbance_counter: 0
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.781000
# Fly 2: -0.796250
# Fly 3: -0.774900
# Fly 4: -0.785850
# Fly 5: -0.784950
# Fly 6: -0.791600
# Fly 7: -0.795750
# Fly 8: -0.769550
# Fly 9: -0.772250
#
# ==================================================
# Iteration: 68
# Current delta: 0.000000
# disturbance_counter: 1
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.794500
# Fly 2: -0.764850
# Fly 3: -0.762350
# Fly 4: -0.792250
# Fly 5: -0.783250
# Fly 6: -0.789800
# Fly 7: -0.758450
# Fly 8: -0.782950
# Fly 9: -0.794500
#
# ==================================================
# Iteration: 69
# Current delta: 0.000000
# disturbance_counter: 2
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.806750
# Fly 2: -0.785650
# Fly 3: -0.773600
# Fly 4: -0.773500
# Fly 5: -0.786100
# Fly 6: -0.794850
# Fly 7: -0.786700
# Fly 8: -0.783150
# Fly 9: -0.807700
#
# ==================================================
# Iteration: 70
# Current delta: 0.000000
# disturbance_counter: 3
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.805650
# Fly 2: -0.773250
# Fly 3: -0.766100
# Fly 4: -0.780300
# Fly 5: -0.766500
# Fly 6: -0.774600
# Fly 7: -0.761050
# Fly 8: -0.775300
# Fly 9: -0.802800
#
# ==================================================
# Iteration: 71
# Current delta: 0.000000
# disturbance_counter: 4
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.807650
# Fly 2: -0.787200
# Fly 3: -0.774850
# Fly 4: -0.780700
# Fly 5: -0.782550
# Fly 6: -0.774000
# Fly 7: -0.770000
# Fly 8: -0.790800
# Fly 9: -0.811400
#
# ==================================================
# Iteration: 72
# Current delta: 0.000000
# disturbance_counter: 5
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.811800
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.804850
# Fly 2: -0.794800
# Fly 3: -0.769400
# Fly 4: -0.777950
# Fly 5: -0.775850
# Fly 6: -0.771500
# Fly 7: -0.784850
# Fly 8: -0.789900
# Fly 9: -0.807650
#
# ==================================================
# Iteration: 73
# Current delta: 0.000000
# disturbance_counter: 6
# Fly 0 (Best fly) fitness = -0.811800
#
# End of iteration summary:
# Best fly: 9 with fitness = -0.812500
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.811650
# Fly 2: -0.794000
# Fly 3: -0.783650
# Fly 4: -0.778600
# Fly 5: -0.758400
# Fly 6: -0.778250
# Fly 7: -0.782800
# Fly 8: -0.807350
# Fly 9: -0.812500
#
# ==================================================
# Iteration: 74
# Current delta: 0.000000
# disturbance_counter: 6
# Fly 9 (Best fly) fitness = -0.812500
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.812750
# All flies fitness values:
# Fly 0: -0.812750
# Fly 1: -0.812750
# Fly 2: -0.809300
# Fly 3: -0.787100
# Fly 4: -0.776100
# Fly 5: -0.769900
# Fly 6: -0.774550
# Fly 7: -0.782450
# Fly 8: -0.807250
# Fly 9: -0.812500
#
# ==================================================
# Iteration: 75
# Current delta: 0.000000
# disturbance_counter: 7
# Fly 0 (Best fly) fitness = -0.812750
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.812750
# All flies fitness values:
# Fly 0: -0.812750
# Fly 1: -0.812750
# Fly 2: -0.809000
# Fly 3: -0.802100
# Fly 4: -0.787600
# Fly 5: -0.778450
# Fly 6: -0.785500
# Fly 7: -0.773150
# Fly 8: -0.808800
# Fly 9: -0.812750
#
# ==================================================
# Iteration: 76
# Current delta: 0.000000
# disturbance_counter: 8
# Fly 0 (Best fly) fitness = -0.812750
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.812750
# All flies fitness values:
# Fly 0: -0.812750
# Fly 1: -0.812750
# Fly 2: -0.811150
# Fly 3: -0.801550
# Fly 4: -0.787850
# Fly 5: -0.779600
# Fly 6: -0.779250
# Fly 7: -0.798450
# Fly 8: -0.811400
# Fly 9: -0.812750
#
# ==================================================
# Iteration: 77
# Current delta: 0.000000
# disturbance_counter: 9
# Fly 0 (Best fly) fitness = -0.812750
#
# End of iteration summary:
# Best fly: 2 with fitness = -0.814150
# All flies fitness values:
# Fly 0: -0.812750
# Fly 1: -0.812750
# Fly 2: -0.814150
# Fly 3: -0.798650
# Fly 4: -0.784950
# Fly 5: -0.776300
# Fly 6: -0.773750
# Fly 7: -0.802100
# Fly 8: -0.812750
# Fly 9: -0.812750
#
# ==================================================
# Iteration: 78
# Current delta: 0.000000
# disturbance_counter: 9
# Fly 2 (Best fly) fitness = -0.814150
#
# End of iteration summary:
# Best fly: 8 with fitness = -0.814450
# All flies fitness values:
# Fly 0: -0.811800
# Fly 1: -0.812850
# Fly 2: -0.814150
# Fly 3: -0.809250
# Fly 4: -0.798300
# Fly 5: -0.773500
# Fly 6: -0.776100
# Fly 7: -0.801300
# Fly 8: -0.814450
# Fly 9: -0.813350
#
# ==================================================
# Iteration: 79
# Current delta: 0.000000
# disturbance_counter: 9
# Fly 8 (Best fly) fitness = -0.814450
#
# End of iteration summary:
# Best fly: 9 with fitness = -0.814750
# All flies fitness values:
# Fly 0: -0.813200
# Fly 1: -0.812500
# Fly 2: -0.811950
# Fly 3: -0.808100
# Fly 4: -0.797450
# Fly 5: -0.775650
# Fly 6: -0.793350
# Fly 7: -0.809900
# Fly 8: -0.814450
# Fly 9: -0.814750
#
# ==================================================
# Iteration: 80
# Current delta: 0.000000
# disturbance_counter: 9
# Fly 9 (Best fly) fitness = -0.814750
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.815200
# All flies fitness values:
# Fly 0: -0.815200
# Fly 1: -0.814000
# Fly 2: -0.813450
# Fly 3: -0.810400
# Fly 4: -0.809450
# Fly 5: -0.791200
# Fly 6: -0.796650
# Fly 7: -0.804700
# Fly 8: -0.814750
# Fly 9: -0.814750
#
# ==================================================
# Iteration: 81
# Current delta: 0.000000
# disturbance_counter: 10
# Fly 0 (Best fly) fitness = -0.815200
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.815200
# All flies fitness values:
# Fly 0: -0.815200
# Fly 1: -0.814600
# Fly 2: -0.813050
# Fly 3: -0.803900
# Fly 4: -0.808100
# Fly 5: -0.796400
# Fly 6: -0.806800
# Fly 7: -0.812400
# Fly 8: -0.814750
# Fly 9: -0.813250
#
# ==================================================
# Iteration: 82
# Current delta: 0.241605
# disturbance_counter: 0
# Fly 0 (Best fly) fitness = -0.815200
#
# End of iteration summary:
# Best fly: 0 with fitness = -0.815200
# All flies fitness values:
# Fly 0: -0.815200
# Fly 1: -0.786650
# Fly 2: -0.777450
# Fly 3: -0.761600
# Fly 4: -0.791900
# Fly 5: -0.790850
# Fly 6: -0.767300
# Fly 7: -0.772750
# Fly 8: -0.792200
# Fly 9: -0.780900
#
# ==================================================
# Iteration: 83
# Current delta: 0.241605
# disturbance_counter: 1
# Fly 0 (Best fly) fitness = -0.815200

# %%
np.save('realbest_fly_weights.npy', best_solution)

# %%
newweihgts = np.load('realbest_fly_weights.npy')

# %%
#Saving fine tuned weights

cloned_model = q_network
    # Reshape fly's weights to match the model's weight shape
reshaped_fly = reshape_to_model_weights(newweihgts)
    
    # Load the reshaped weights into the cloned model
cloned_model.load_state_dict(dict(zip([name for name, _ in cloned_model.named_parameters()], reshaped_fly)))


# save the model as dfoFineTuned
torch.save(cloned_model.state_dict(), '2timesSDAndFIxedUpdatedfoFineTuned.pt')

# %%
len(fitness_history)

# %%
# Plot results after all iterations
import matplotlib.pyplot as plt

# Plot fitness[s]
plt.figure(figsize=(10, 5))
plt.plot(fitness_history, label="Fitness (Best Fly)")
plt.xlabel("Iteration")
plt.ylabel("Fitness")
plt.title("Fitness vs Iteration")
plt.legend()
plt.grid()

# Plot delta
plt.figure(figsize=(10, 5))
plt.plot(delta_history, label="Delta", color='orange')
plt.xlabel("Iteration")
plt.ylabel("Delta")
plt.title("Delta vs Iteration")
plt.legend()
plt.grid()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       4 # Plot fitness[s]
#       5 plt.figure(figsize=(10, 5))
# ----> 6 plt.plot(fitness_history, label="Fitness (Best Fly)")
#       7 plt.xlabel("Iteration")
#       8 plt.ylabel("Fitness")
#
# NameError: name 'fitness_history' is not defined
