# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.3

# %%
import os
import sys
# Add the root directory to Python path
root_dir = "C:\\Users\\Jordan Lankford\\Documents\\GitHub\\FineTune-DQN"
if root_dir not in sys.path:
    sys.path.append(root_dir)

# Now imports should work
from src.utils.utils import set_seeds
import torch
import torch.nn as nn
import gymnasium as gym
import numpy as np
from src.utils.utils import set_seeds
from torchsummary import summary

def encode_state(obs, n_states):  # Modified to take n_states as parameter
    obs = torch.Tensor(obs)
    return nn.functional.one_hot(obs.long(), n_states).float()

def get_mask(info, n_actions=25):
    allowed_actions = info['admissible_actions']
    mask = np.zeros(n_actions)
    mask[allowed_actions] = 1
    return torch.Tensor(mask).unsqueeze(0)

class QNetwork(nn.Module):
    def __init__(self, env):
        super().__init__()
        self.n_states = env.observation_space.n
        self.n_actions = env.action_space.n
        self.network = nn.Linear(self.n_states, self.n_actions, bias=False)
        torch.nn.init.constant_(self.network.weight, 0.0)

    def forward(self, x, action_masks=None):
        q_values = self.network(x)
        if action_masks is not None:
            q_values = q_values - ((1 - action_masks) * 1e10)
        return q_values
    

env = gym.make('Sepsis/ICU-Sepsis-v2')
    
    # Create network and load weights
q_network = QNetwork(env)
state_dict = torch.load(r"C:\Users\Jordan Lankford\Documents\GitHub\FineTune-DQN\models\dqn\dqn_final_seed_0.pt")
#q_network.load_state_dict(state_dict)
q_network.load_state_dict(state_dict, strict=False)
# Out:
# C:\Users\Jordan Lankford\AppData\Local\Temp\ipykernel_2836\2830723202.py:46: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(r"C:\Users\Jordan Lankford\Documents\GitHub\FineTune-DQN\models\dqn\dqn_final_seed_0.pt")
# _IncompatibleKeys(missing_keys=['network.weight'], unexpected_keys=['network.0.weight', 'network.0.bias', 'network.2.weight', 'network.2.bias', 'network.4.weight', 'network.4.bias'])

# %%
weight_shapes = []
for param in q_network.parameters():
    weight_shapes.append(param.shape)
print(weight_shapes)
# Out:
# [torch.Size([25, 716])]

# %%
values_in_dimension=[]
for shape in weight_shapes:
    values_in_dimension.append(np.prod(shape))
print(values_in_dimension)
# Out:
# [np.int64(17900)]

# %%
weights = [param.detach().numpy() for param in q_network.parameters()]  # Get all model weights as numpy arrays

# %%
import torch
import torch.nn as nn
import numpy as np
import gymnasium as gym
from torchsummary import summary

# Assuming QNetwork and set_seeds are defined earlier in the code
# Assuming the reshape function is defined as needed


def f(fly, flies_history, model=q_network,env=env):
    # Clone the model (you don't really need to clone in PyTorch, just create a new instance)
    cloned_model = q_network
    
    # Reshape fly's weights to match the model's weight shape
    reshaped_fly = reshape_to_model_weights(fly, model)
    
    # Load the reshaped weights into the cloned model
    cloned_model.load_state_dict(dict(zip([name for name, _ in cloned_model.named_parameters()], reshaped_fly)))

    # Set the model to evaluation mode
    cloned_model.eval()

    # Run the evaluation (similar to what is done in evaluate_network)
    episode_rewards = []
    episode_lengths = []
    
    num_episodes = 10000  # or any other number you'd like to test  USE 100000 FOR STABAL ISH
    for episode in range(num_episodes):
        state, info = env.reset()
        episode_reward = 0
        steps = 0
        done = False
        
        while not done:
            state_encoded = encode_state(np.array([state]), env.observation_space.n)
            action_mask = get_mask(info, n_actions=env.action_space.n)
            
            with torch.no_grad():
                q_values = cloned_model(state_encoded, action_mask)
                action = torch.argmax(q_values).item()
            
            next_state, reward, terminated, truncated, info = env.step(action)
            episode_reward += reward
            steps += 1
            state = next_state
            done = terminated or truncated

        episode_rewards.append(episode_reward)
        episode_lengths.append(steps)
    

    fitness = np.mean(episode_rewards)
    # Return the average reward (or any other metric you want)
    return -f_avrg(fitness, flies_history)
    #return -fitness

# %%
def reshape_to_model_weights(flattened_fly, model=q_network):
    # List to store reshaped weights
    reshaped_weights = []
    counter = 0  # Counter for elements in fly
    
    # Get the shapes of the model's parameters
    values_in_dimension = [param.numel() for param in model.parameters()]
    weight_shapes = [param.shape for param in model.parameters()]
    
    for i in range(len(values_in_dimension)):
        # Get the flattened weights for this layer
        weight_flat = flattened_fly[counter: counter + values_in_dimension[i]]
        
        # Reshape and convert to torch.Tensor
        reshaped_layer_weights = torch.tensor(weight_flat, dtype=torch.float32).reshape(weight_shapes[i])
        
        # Append the reshaped weight to the list
        reshaped_weights.append(reshaped_layer_weights)
        
        # Move the counter to the next parameter block
        counter += values_in_dimension[i]
    
    return reshaped_weights

# %%
def initialize_flies_from_model(number_of_flies, weights, model, inclusive):
    population = []

    if inclusive == False:
        for i in range(number_of_flies):
            fly = []  # This will hold the flattened weights for a single fly
            
            for param in model.parameters():  # Iterate through model parameters (weights and biases)
                # Generate random weights with the same shape as the model's weight matrix
                scalers = np.random.uniform(0.9, 1.1, size=param.shape)
                print(param.shape)  # Print the shape to see what the weights look like
                scaledweights = param.detach().numpy() * scalers  # Multiply the weight values by the scalers
                
                # Flatten the random weights and add them to the fly
                flattened_weights = scaledweights.flatten()
                fly.append(flattened_weights)
            
            # After flattening each layer's weights, flatten the entire fly and add to population
            population.append(np.concatenate(fly))  # Concatenate the list of flattened weight arrays
            
    if inclusive == True:
        for i in range(number_of_flies):
            fly = []  # This will hold the flattened weights for a single fly
            
            for param in model.parameters():  # Iterate through model parameters (weights and biases)
                if i == 0:
                    flattened_weights = param.detach().numpy().flatten()  # Get the flattened weights for the first fly
                    fly.append(flattened_weights)
                else:
                    scalers = np.random.uniform(0.9, 1.1, size=param.shape)
                    print(param.shape)  # Print the shape to see what the weights look like
                    scaledweights = param.detach().numpy() * scalers  # Multiply the weight values by the scalers
                    
                    # Flatten the random weights and add them to the fly
                    flattened_weights = scaledweights.flatten()
                    fly.append(flattened_weights)
                
            # After flattening each layer's weights, flatten the entire fly and add to population
            population.append(np.concatenate(fly))  # Concatenate the list of flattened weight arrays
        
    return population

# %%
num_of_flies = 10

flies = initialize_flies_from_model(num_of_flies,weights,q_network,True)



from collections import deque
max_history = 5
flies_history = [deque(maxlen=max_history) for _ in range(num_of_flies)]
# Out:
# torch.Size([25, 716])
# torch.Size([25, 716])
# torch.Size([25, 716])
# torch.Size([25, 716])
# torch.Size([25, 716])
# torch.Size([25, 716])
# torch.Size([25, 716])
# torch.Size([25, 716])
# torch.Size([25, 716])

# %%
print(flies_history[0])
# Out:
# deque([], maxlen=5)

# %%
def f_avrg(fitness, flies_history):

    flies_history.append(fitness)

    print(flies_history)

    return sum(flies_history) / len(flies_history) # mean

# %%
f_avrg(f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 f_avrg(f)
#
# TypeError: f_avrg() missing 1 required positional argument: 'flies_history'

# %%
#f(flies[0],flies_history[0])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 f(flies[0],flies_history[0])
#
# Cell In[5], line 40, in f(fly, flies_history, model, env)
#      37 action_mask = get_mask(info, n_actions=env.action_space.n)
#      39 with torch.no_grad():
# ---> 40     q_values = cloned_model(state_encoded, action_mask)
#      41     action = torch.argmax(q_values).item()
#      43 next_state, reward, terminated, truncated, info = env.step(action)
#
# File c:\Users\Jordan Lankford\Documents\GitHub\choudhary2024icu\venv\Lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# KeyboardInterrupt:

# %%
len(flies[0])
# Out:
# 17900

# %%
N = len(flies)			# POPULATION SIZE
D = len(flies[0])					# DIMENSIONALITY 
delta = 0.005			# DISTURBANCE THRESHOLD 
maxIterations = 1000	# ITERATIONS ALLOWED

# %%
# MAIN DFO LOOP


def DFO(start_flies):
	counter = 0
	X = start_flies
	fitness = [None]*len(start_flies) 

	for itr in range (maxIterations):
		for i in range(N): # EVALUATION --- 10 needs to be the population size
			fitness[i] = f(X[i], flies_history[i])
		s = np.argmin(fitness) # FIND BEST FLY

	
			
		
		#fitness_history.append(fitness[s])
		#delta_history.append(delta)

		if (itr%1 == 0): # PRINT BEST FLY EVERY 100 ITERATIONS
			print ("Iteration:", itr, "\tBest fly index:", s, 
				"\tFitness value:", fitness[s], "delta: ", delta, "counter: ", counter)

		# TAKE EACH FLY INDIVIDUALLY 
		for i in range(N): 
			if i == s: continue # ELITIST STRATEGY

			# FIND BEST NEIGHBOUR
			left = (i-1)%N
			right = (i+1)%N
			bNeighbour = right if fitness[right]<fitness[left] else left

			for d in range(D): # UPDATE EACH DIMENSION SEPARATELY 
				if (np.random.rand() < delta):
					X[i][d] = np.random.normal(loc=X[bNeighbour][d], scale=(delta))
					#X[i][d] = np.random.normal(loc=X[bNeighbour][d], scale=(delta**2.0))	#update between a normal distribution with the mean set to the best neighbours location using a SD of delta squared
					continue;

				u = np.random.rand()
				X[i][d] = X[bNeighbour][d] + u*(X[s][d] - X[bNeighbour][d])	#standard fucntion uses current fly location, update will be a seflless method using the best neighbor 

				# OUT OF BOUND CONTROL
				#if X[i][d] < lowerB[d] or X[i][d] > upperB[d]:
					#X[i][d] = np.random.uniform(lowerB[d], upperB[d])

	for i in range(N): fitness[i] = f(X[i], flies_history[i]) # EVALUATION
	new_s = np.argmin(fitness) # FIND BEST FLY
	s = new_s
	return(X[s])

#print("\nFinal best fitness:\t", fitness[s])
#print("\nBest fly position:\n",  X[s])

# %%
newweihgts = DFO(flies)
# Out:
# deque([0.8609], maxlen=5)
# deque([0.8357], maxlen=5)
# deque([0.8259], maxlen=5)
# deque([0.8282], maxlen=5)
# deque([0.8374], maxlen=5)
# deque([0.8264], maxlen=5)
# deque([0.8403], maxlen=5)
# deque([0.832], maxlen=5)
# deque([0.8247], maxlen=5)
# deque([0.8382], maxlen=5)
# Iteration: 0 	Best fly index: 0 	Fitness value: -0.8609 delta:  0.005 counter:  0
# deque([0.8609, 0.8572], maxlen=5)
# deque([0.8357, 0.8556], maxlen=5)
# deque([0.8259, 0.8509], maxlen=5)
# deque([0.8282, 0.8396], maxlen=5)
# deque([0.8374, 0.8464], maxlen=5)
# deque([0.8264, 0.8383], maxlen=5)
# deque([0.8403, 0.8477], maxlen=5)
# deque([0.832, 0.8538], maxlen=5)
# deque([0.8247, 0.8413], maxlen=5)
# deque([0.8382, 0.8555], maxlen=5)
# Iteration: 1 	Best fly index: 0 	Fitness value: -0.85905 delta:  0.005 counter:  0
# deque([0.8609, 0.8572, 0.859], maxlen=5)
# deque([0.8357, 0.8556, 0.8538], maxlen=5)
# deque([0.8259, 0.8509, 0.8585], maxlen=5)
# deque([0.8282, 0.8396, 0.8544], maxlen=5)
# deque([0.8374, 0.8464, 0.8562], maxlen=5)
# deque([0.8264, 0.8383, 0.8589], maxlen=5)
# deque([0.8403, 0.8477, 0.8498], maxlen=5)
# deque([0.832, 0.8538, 0.8595], maxlen=5)
# deque([0.8247, 0.8413, 0.8537], maxlen=5)
# deque([0.8382, 0.8555, 0.8545], maxlen=5)
# Iteration: 2 	Best fly index: 0 	Fitness value: -0.8590333333333332 delta:  0.005 counter:  0
# deque([0.8609, 0.8572, 0.859, 0.8624], maxlen=5)
# deque([0.8357, 0.8556, 0.8538, 0.8519], maxlen=5)
# deque([0.8259, 0.8509, 0.8585, 0.8562], maxlen=5)
# deque([0.8282, 0.8396, 0.8544, 0.8515], maxlen=5)
# deque([0.8374, 0.8464, 0.8562, 0.8534], maxlen=5)
# deque([0.8264, 0.8383, 0.8589, 0.8539], maxlen=5)
# deque([0.8403, 0.8477, 0.8498, 0.859], maxlen=5)
# deque([0.832, 0.8538, 0.8595, 0.8537], maxlen=5)
# deque([0.8247, 0.8413, 0.8537, 0.854], maxlen=5)
# deque([0.8382, 0.8555, 0.8545, 0.8537], maxlen=5)
# Iteration: 3 	Best fly index: 0 	Fitness value: -0.859875 delta:  0.005 counter:  0
# deque([0.8609, 0.8572, 0.859, 0.8624, 0.8585], maxlen=5)
# deque([0.8357, 0.8556, 0.8538, 0.8519, 0.856], maxlen=5)
# deque([0.8259, 0.8509, 0.8585, 0.8562, 0.8529], maxlen=5)
# deque([0.8282, 0.8396, 0.8544, 0.8515, 0.8509], maxlen=5)
# deque([0.8374, 0.8464, 0.8562, 0.8534, 0.8575], maxlen=5)
# deque([0.8264, 0.8383, 0.8589, 0.8539, 0.8601], maxlen=5)
# deque([0.8403, 0.8477, 0.8498, 0.859, 0.8573], maxlen=5)
# deque([0.832, 0.8538, 0.8595, 0.8537, 0.8513], maxlen=5)
# deque([0.8247, 0.8413, 0.8537, 0.854, 0.8525], maxlen=5)
# deque([0.8382, 0.8555, 0.8545, 0.8537, 0.8518], maxlen=5)
# Iteration: 4 	Best fly index: 0 	Fitness value: -0.8596 delta:  0.005 counter:  0
# deque([0.8572, 0.859, 0.8624, 0.8585, 0.8608], maxlen=5)
# deque([0.8556, 0.8538, 0.8519, 0.856, 0.8592], maxlen=5)
# deque([0.8509, 0.8585, 0.8562, 0.8529, 0.8521], maxlen=5)
# deque([0.8396, 0.8544, 0.8515, 0.8509, 0.8523], maxlen=5)
# deque([0.8464, 0.8562, 0.8534, 0.8575, 0.8535], maxlen=5)
# deque([0.8383, 0.8589, 0.8539, 0.8601, 0.8584], maxlen=5)
# deque([0.8477, 0.8498, 0.859, 0.8573, 0.8493], maxlen=5)
# deque([0.8538, 0.8595, 0.8537, 0.8513, 0.8612], maxlen=5)
# deque([0.8413, 0.8537, 0.854, 0.8525, 0.8579], maxlen=5)
# deque([0.8555, 0.8545, 0.8537, 0.8518, 0.855], maxlen=5)
# Iteration: 5 	Best fly index: 0 	Fitness value: -0.85958 delta:  0.005 counter:  0
# deque([0.859, 0.8624, 0.8585, 0.8608, 0.8535], maxlen=5)
# deque([0.8538, 0.8519, 0.856, 0.8592, 0.8576], maxlen=5)
# deque([0.8585, 0.8562, 0.8529, 0.8521, 0.8598], maxlen=5)
# deque([0.8544, 0.8515, 0.8509, 0.8523, 0.8545], maxlen=5)
# deque([0.8562, 0.8534, 0.8575, 0.8535, 0.8576], maxlen=5)
# deque([0.8589, 0.8539, 0.8601, 0.8584, 0.8517], maxlen=5)
# deque([0.8498, 0.859, 0.8573, 0.8493, 0.8559], maxlen=5)
# deque([0.8595, 0.8537, 0.8513, 0.8612, 0.8547], maxlen=5)
# deque([0.8537, 0.854, 0.8525, 0.8579, 0.8542], maxlen=5)
# deque([0.8545, 0.8537, 0.8518, 0.855, 0.8532], maxlen=5)
# Iteration: 6 	Best fly index: 0 	Fitness value: -0.8588400000000002 delta:  0.005 counter:  0
# deque([0.8624, 0.8585, 0.8608, 0.8535, 0.8497], maxlen=5)
# deque([0.8519, 0.856, 0.8592, 0.8576, 0.8563], maxlen=5)
# deque([0.8562, 0.8529, 0.8521, 0.8598, 0.8562], maxlen=5)
# deque([0.8515, 0.8509, 0.8523, 0.8545, 0.8604], maxlen=5)
# deque([0.8534, 0.8575, 0.8535, 0.8576, 0.8531], maxlen=5)
# deque([0.8539, 0.8601, 0.8584, 0.8517, 0.8555], maxlen=5)
# deque([0.859, 0.8573, 0.8493, 0.8559, 0.8578], maxlen=5)
# deque([0.8537, 0.8513, 0.8612, 0.8547, 0.8569], maxlen=5)
# deque([0.854, 0.8525, 0.8579, 0.8542, 0.8554], maxlen=5)
# deque([0.8537, 0.8518, 0.855, 0.8532, 0.8573], maxlen=5)
# Iteration: 7 	Best fly index: 0 	Fitness value: -0.8569800000000001 delta:  0.005 counter:  0
# deque([0.8585, 0.8608, 0.8535, 0.8497, 0.8522], maxlen=5)
# deque([0.856, 0.8592, 0.8576, 0.8563, 0.8507], maxlen=5)
# deque([0.8529, 0.8521, 0.8598, 0.8562, 0.8528], maxlen=5)
# deque([0.8509, 0.8523, 0.8545, 0.8604, 0.8516], maxlen=5)
# deque([0.8575, 0.8535, 0.8576, 0.8531, 0.8581], maxlen=5)
# deque([0.8601, 0.8584, 0.8517, 0.8555, 0.8549], maxlen=5)
# deque([0.8573, 0.8493, 0.8559, 0.8578, 0.8547], maxlen=5)
# deque([0.8513, 0.8612, 0.8547, 0.8569, 0.8656], maxlen=5)
# deque([0.8525, 0.8579, 0.8542, 0.8554, 0.8576], maxlen=5)
# deque([0.8518, 0.855, 0.8532, 0.8573, 0.8599], maxlen=5)
# Iteration: 8 	Best fly index: 7 	Fitness value: -0.8579399999999999 delta:  0.005 counter:  0
# deque([0.8608, 0.8535, 0.8497, 0.8522, 0.8532], maxlen=5)
# deque([0.8592, 0.8576, 0.8563, 0.8507, 0.8595], maxlen=5)
# deque([0.8521, 0.8598, 0.8562, 0.8528, 0.8534], maxlen=5)
# deque([0.8523, 0.8545, 0.8604, 0.8516, 0.8577], maxlen=5)
# deque([0.8535, 0.8576, 0.8531, 0.8581, 0.8551], maxlen=5)
# deque([0.8584, 0.8517, 0.8555, 0.8549, 0.8625], maxlen=5)
# deque([0.8493, 0.8559, 0.8578, 0.8547, 0.8584], maxlen=5)
# deque([0.8612, 0.8547, 0.8569, 0.8656, 0.8588], maxlen=5)
# deque([0.8579, 0.8542, 0.8554, 0.8576, 0.8579], maxlen=5)
# deque([0.855, 0.8532, 0.8573, 0.8599, 0.8527], maxlen=5)
# Iteration: 9 	Best fly index: 7 	Fitness value: -0.85944 delta:  0.005 counter:  0
# deque([0.8535, 0.8497, 0.8522, 0.8532, 0.8578], maxlen=5)
# deque([0.8576, 0.8563, 0.8507, 0.8595, 0.8544], maxlen=5)
# deque([0.8598, 0.8562, 0.8528, 0.8534, 0.8604], maxlen=5)
# deque([0.8545, 0.8604, 0.8516, 0.8577, 0.8589], maxlen=5)
# deque([0.8576, 0.8531, 0.8581, 0.8551, 0.853], maxlen=5)
# deque([0.8517, 0.8555, 0.8549, 0.8625, 0.8563], maxlen=5)
# deque([0.8559, 0.8578, 0.8547, 0.8584, 0.8568], maxlen=5)
# deque([0.8547, 0.8569, 0.8656, 0.8588, 0.8532], maxlen=5)
# deque([0.8542, 0.8554, 0.8576, 0.8579, 0.8511], maxlen=5)
# deque([0.8532, 0.8573, 0.8599, 0.8527, 0.8586], maxlen=5)
# Iteration: 10 	Best fly index: 7 	Fitness value: -0.85784 delta:  0.005 counter:  0
# deque([0.8497, 0.8522, 0.8532, 0.8578, 0.8577], maxlen=5)
# deque([0.8563, 0.8507, 0.8595, 0.8544, 0.8552], maxlen=5)
# deque([0.8562, 0.8528, 0.8534, 0.8604, 0.8544], maxlen=5)
# deque([0.8604, 0.8516, 0.8577, 0.8589, 0.8579], maxlen=5)
# deque([0.8531, 0.8581, 0.8551, 0.853, 0.8635], maxlen=5)
# deque([0.8555, 0.8549, 0.8625, 0.8563, 0.857], maxlen=5)
# deque([0.8578, 0.8547, 0.8584, 0.8568, 0.8532], maxlen=5)
# deque([0.8569, 0.8656, 0.8588, 0.8532, 0.8531], maxlen=5)
# deque([0.8554, 0.8576, 0.8579, 0.8511, 0.8552], maxlen=5)
# deque([0.8573, 0.8599, 0.8527, 0.8586, 0.8522], maxlen=5)
# Iteration: 11 	Best fly index: 7 	Fitness value: -0.8575199999999998 delta:  0.005 counter:  0
# deque([0.8522, 0.8532, 0.8578, 0.8577, 0.8516], maxlen=5)
# deque([0.8507, 0.8595, 0.8544, 0.8552, 0.853], maxlen=5)
# deque([0.8528, 0.8534, 0.8604, 0.8544, 0.8575], maxlen=5)
# deque([0.8516, 0.8577, 0.8589, 0.8579, 0.8524], maxlen=5)
# deque([0.8581, 0.8551, 0.853, 0.8635, 0.8539], maxlen=5)
# deque([0.8549, 0.8625, 0.8563, 0.857, 0.8527], maxlen=5)
# deque([0.8547, 0.8584, 0.8568, 0.8532, 0.8533], maxlen=5)
# deque([0.8656, 0.8588, 0.8532, 0.8531, 0.8582], maxlen=5)
# deque([0.8576, 0.8579, 0.8511, 0.8552, 0.8547], maxlen=5)
# deque([0.8599, 0.8527, 0.8586, 0.8522, 0.863], maxlen=5)
# Iteration: 12 	Best fly index: 7 	Fitness value: -0.85778 delta:  0.005 counter:  0
# deque([0.8532, 0.8578, 0.8577, 0.8516, 0.8554], maxlen=5)
# deque([0.8595, 0.8544, 0.8552, 0.853, 0.8537], maxlen=5)
# deque([0.8534, 0.8604, 0.8544, 0.8575, 0.8582], maxlen=5)
# deque([0.8577, 0.8589, 0.8579, 0.8524, 0.8533], maxlen=5)
# deque([0.8551, 0.853, 0.8635, 0.8539, 0.8562], maxlen=5)
# deque([0.8625, 0.8563, 0.857, 0.8527, 0.8582], maxlen=5)
# deque([0.8584, 0.8568, 0.8532, 0.8533, 0.8603], maxlen=5)
# deque([0.8588, 0.8532, 0.8531, 0.8582, 0.8532], maxlen=5)
# deque([0.8579, 0.8511, 0.8552, 0.8547, 0.8543], maxlen=5)
# deque([0.8527, 0.8586, 0.8522, 0.863, 0.8495], maxlen=5)
# Iteration: 13 	Best fly index: 5 	Fitness value: -0.85734 delta:  0.005 counter:  0
# deque([0.8578, 0.8577, 0.8516, 0.8554, 0.8531], maxlen=5)
# deque([0.8544, 0.8552, 0.853, 0.8537, 0.8541], maxlen=5)
# deque([0.8604, 0.8544, 0.8575, 0.8582, 0.8556], maxlen=5)
# deque([0.8589, 0.8579, 0.8524, 0.8533, 0.8536], maxlen=5)
# deque([0.853, 0.8635, 0.8539, 0.8562, 0.8547], maxlen=5)
# deque([0.8563, 0.857, 0.8527, 0.8582, 0.8567], maxlen=5)
# deque([0.8568, 0.8532, 0.8533, 0.8603, 0.8566], maxlen=5)
# deque([0.8532, 0.8531, 0.8582, 0.8532, 0.8566], maxlen=5)
# deque([0.8511, 0.8552, 0.8547, 0.8543, 0.8586], maxlen=5)
# deque([0.8586, 0.8522, 0.863, 0.8495, 0.8582], maxlen=5)
# Iteration: 14 	Best fly index: 2 	Fitness value: -0.8572200000000001 delta:  0.005 counter:  0
# deque([0.8577, 0.8516, 0.8554, 0.8531, 0.8525], maxlen=5)
# deque([0.8552, 0.853, 0.8537, 0.8541, 0.855], maxlen=5)
# deque([0.8544, 0.8575, 0.8582, 0.8556, 0.8483], maxlen=5)
# deque([0.8579, 0.8524, 0.8533, 0.8536, 0.852], maxlen=5)
# deque([0.8635, 0.8539, 0.8562, 0.8547, 0.8569], maxlen=5)
# deque([0.857, 0.8527, 0.8582, 0.8567, 0.853], maxlen=5)
# deque([0.8532, 0.8533, 0.8603, 0.8566, 0.8548], maxlen=5)
# deque([0.8531, 0.8582, 0.8532, 0.8566, 0.8564], maxlen=5)
# deque([0.8552, 0.8547, 0.8543, 0.8586, 0.8511], maxlen=5)
# deque([0.8522, 0.863, 0.8495, 0.8582, 0.8551], maxlen=5)
# Iteration: 15 	Best fly index: 4 	Fitness value: -0.8570399999999999 delta:  0.005 counter:  0
# deque([0.8516, 0.8554, 0.8531, 0.8525, 0.85], maxlen=5)
# deque([0.853, 0.8537, 0.8541, 0.855, 0.8619], maxlen=5)
# deque([0.8575, 0.8582, 0.8556, 0.8483, 0.8502], maxlen=5)
# deque([0.8524, 0.8533, 0.8536, 0.852, 0.8535], maxlen=5)
# deque([0.8539, 0.8562, 0.8547, 0.8569, 0.8561], maxlen=5)
# deque([0.8527, 0.8582, 0.8567, 0.853, 0.8631], maxlen=5)
# deque([0.8533, 0.8603, 0.8566, 0.8548, 0.8538], maxlen=5)
# deque([0.8582, 0.8532, 0.8566, 0.8564, 0.8575], maxlen=5)
# deque([0.8547, 0.8543, 0.8586, 0.8511, 0.8547], maxlen=5)
# deque([0.863, 0.8495, 0.8582, 0.8551, 0.8588], maxlen=5)
# Iteration: 16 	Best fly index: 9 	Fitness value: -0.8569199999999999 delta:  0.005 counter:  0
# deque([0.8554, 0.8531, 0.8525, 0.85, 0.8578], maxlen=5)
# deque([0.8537, 0.8541, 0.855, 0.8619, 0.8593], maxlen=5)
# deque([0.8582, 0.8556, 0.8483, 0.8502, 0.8543], maxlen=5)
# deque([0.8533, 0.8536, 0.852, 0.8535, 0.8536], maxlen=5)
# deque([0.8562, 0.8547, 0.8569, 0.8561, 0.8517], maxlen=5)
# deque([0.8582, 0.8567, 0.853, 0.8631, 0.8536], maxlen=5)
# deque([0.8603, 0.8566, 0.8548, 0.8538, 0.8567], maxlen=5)
# deque([0.8532, 0.8566, 0.8564, 0.8575, 0.8532], maxlen=5)
# deque([0.8543, 0.8586, 0.8511, 0.8547, 0.849], maxlen=5)
# deque([0.8495, 0.8582, 0.8551, 0.8588, 0.8524], maxlen=5)
# Iteration: 17 	Best fly index: 5 	Fitness value: -0.85692 delta:  0.005 counter:  0
# deque([0.8531, 0.8525, 0.85, 0.8578, 0.8548], maxlen=5)
# deque([0.8541, 0.855, 0.8619, 0.8593, 0.8523], maxlen=5)
# deque([0.8556, 0.8483, 0.8502, 0.8543, 0.8497], maxlen=5)
# deque([0.8536, 0.852, 0.8535, 0.8536, 0.8545], maxlen=5)
# deque([0.8547, 0.8569, 0.8561, 0.8517, 0.8551], maxlen=5)
# deque([0.8567, 0.853, 0.8631, 0.8536, 0.8569], maxlen=5)
# deque([0.8566, 0.8548, 0.8538, 0.8567, 0.8608], maxlen=5)
# deque([0.8566, 0.8564, 0.8575, 0.8532, 0.8506], maxlen=5)
# deque([0.8586, 0.8511, 0.8547, 0.849, 0.8558], maxlen=5)
# deque([0.8582, 0.8551, 0.8588, 0.8524, 0.8512], maxlen=5)
# Iteration: 18 	Best fly index: 5 	Fitness value: -0.8566600000000001 delta:  0.005 counter:  0
# deque([0.8525, 0.85, 0.8578, 0.8548, 0.8531], maxlen=5)
# deque([0.855, 0.8619, 0.8593, 0.8523, 0.8593], maxlen=5)
# deque([0.8483, 0.8502, 0.8543, 0.8497, 0.8523], maxlen=5)
# deque([0.852, 0.8535, 0.8536, 0.8545, 0.8596], maxlen=5)
# deque([0.8569, 0.8561, 0.8517, 0.8551, 0.8538], maxlen=5)
# deque([0.853, 0.8631, 0.8536, 0.8569, 0.8566], maxlen=5)
# deque([0.8548, 0.8538, 0.8567, 0.8608, 0.855], maxlen=5)
# deque([0.8564, 0.8575, 0.8532, 0.8506, 0.8558], maxlen=5)
# deque([0.8511, 0.8547, 0.849, 0.8558, 0.8509], maxlen=5)
# deque([0.8551, 0.8588, 0.8524, 0.8512, 0.8573], maxlen=5)
# Iteration: 19 	Best fly index: 1 	Fitness value: -0.85756 delta:  0.005 counter:  0
# deque([0.85, 0.8578, 0.8548, 0.8531, 0.8623], maxlen=5)
# deque([0.8619, 0.8593, 0.8523, 0.8593, 0.8569], maxlen=5)
# deque([0.8502, 0.8543, 0.8497, 0.8523, 0.8614], maxlen=5)
# deque([0.8535, 0.8536, 0.8545, 0.8596, 0.8562], maxlen=5)
# deque([0.8561, 0.8517, 0.8551, 0.8538, 0.8541], maxlen=5)
# deque([0.8631, 0.8536, 0.8569, 0.8566, 0.8583], maxlen=5)
# deque([0.8538, 0.8567, 0.8608, 0.855, 0.8621], maxlen=5)
# deque([0.8575, 0.8532, 0.8506, 0.8558, 0.8543], maxlen=5)
# deque([0.8547, 0.849, 0.8558, 0.8509, 0.8504], maxlen=5)
# deque([0.8588, 0.8524, 0.8512, 0.8573, 0.8582], maxlen=5)
# Iteration: 20 	Best fly index: 1 	Fitness value: -0.8579399999999999 delta:  0.005 counter:  0
# deque([0.8578, 0.8548, 0.8531, 0.8623, 0.8606], maxlen=5)
# deque([0.8593, 0.8523, 0.8593, 0.8569, 0.8508], maxlen=5)
# deque([0.8543, 0.8497, 0.8523, 0.8614, 0.8562], maxlen=5)
# deque([0.8536, 0.8545, 0.8596, 0.8562, 0.8551], maxlen=5)
# deque([0.8517, 0.8551, 0.8538, 0.8541, 0.8589], maxlen=5)
# deque([0.8536, 0.8569, 0.8566, 0.8583, 0.8568], maxlen=5)
# deque([0.8567, 0.8608, 0.855, 0.8621, 0.8518], maxlen=5)
# deque([0.8532, 0.8506, 0.8558, 0.8543, 0.8553], maxlen=5)
# deque([0.849, 0.8558, 0.8509, 0.8504, 0.8553], maxlen=5)
# deque([0.8524, 0.8512, 0.8573, 0.8582, 0.8574], maxlen=5)
# Iteration: 21 	Best fly index: 0 	Fitness value: -0.8577199999999999 delta:  0.005 counter:  0
# deque([0.8548, 0.8531, 0.8623, 0.8606, 0.8551], maxlen=5)
# deque([0.8523, 0.8593, 0.8569, 0.8508, 0.8556], maxlen=5)
# deque([0.8497, 0.8523, 0.8614, 0.8562, 0.8594], maxlen=5)
# deque([0.8545, 0.8596, 0.8562, 0.8551, 0.8576], maxlen=5)
# deque([0.8551, 0.8538, 0.8541, 0.8589, 0.857], maxlen=5)
# deque([0.8569, 0.8566, 0.8583, 0.8568, 0.8536], maxlen=5)
# deque([0.8608, 0.855, 0.8621, 0.8518, 0.8568], maxlen=5)
# deque([0.8506, 0.8558, 0.8543, 0.8553, 0.8542], maxlen=5)
# deque([0.8558, 0.8509, 0.8504, 0.8553, 0.8587], maxlen=5)
# deque([0.8512, 0.8573, 0.8582, 0.8574, 0.8521], maxlen=5)
# Iteration: 22 	Best fly index: 6 	Fitness value: -0.8573000000000001 delta:  0.005 counter:  0
# deque([0.8531, 0.8623, 0.8606, 0.8551, 0.8491], maxlen=5)
# deque([0.8593, 0.8569, 0.8508, 0.8556, 0.854], maxlen=5)
# deque([0.8523, 0.8614, 0.8562, 0.8594, 0.8589], maxlen=5)
# deque([0.8596, 0.8562, 0.8551, 0.8576, 0.8585], maxlen=5)
# deque([0.8538, 0.8541, 0.8589, 0.857, 0.8613], maxlen=5)
# deque([0.8566, 0.8583, 0.8568, 0.8536, 0.8504], maxlen=5)
# deque([0.855, 0.8621, 0.8518, 0.8568, 0.857], maxlen=5)
# deque([0.8558, 0.8543, 0.8553, 0.8542, 0.8585], maxlen=5)
# deque([0.8509, 0.8504, 0.8553, 0.8587, 0.857], maxlen=5)
# deque([0.8573, 0.8582, 0.8574, 0.8521, 0.8601], maxlen=5)
# Iteration: 23 	Best fly index: 2 	Fitness value: -0.85764 delta:  0.005 counter:  0
# deque([0.8623, 0.8606, 0.8551, 0.8491, 0.8586], maxlen=5)
# deque([0.8569, 0.8508, 0.8556, 0.854, 0.8502], maxlen=5)
# deque([0.8614, 0.8562, 0.8594, 0.8589, 0.8536], maxlen=5)
# deque([0.8562, 0.8551, 0.8576, 0.8585, 0.8536], maxlen=5)
# deque([0.8541, 0.8589, 0.857, 0.8613, 0.8483], maxlen=5)
# deque([0.8583, 0.8568, 0.8536, 0.8504, 0.8491], maxlen=5)
# deque([0.8621, 0.8518, 0.8568, 0.857, 0.8551], maxlen=5)
# deque([0.8543, 0.8553, 0.8542, 0.8585, 0.8492], maxlen=5)
# deque([0.8504, 0.8553, 0.8587, 0.857, 0.8528], maxlen=5)
# deque([0.8582, 0.8574, 0.8521, 0.8601, 0.8576], maxlen=5)
# Iteration: 24 	Best fly index: 2 	Fitness value: -0.8579000000000001 delta:  0.005 counter:  0
# deque([0.8606, 0.8551, 0.8491, 0.8586, 0.8583], maxlen=5)
# deque([0.8508, 0.8556, 0.854, 0.8502, 0.8608], maxlen=5)
# deque([0.8562, 0.8594, 0.8589, 0.8536, 0.8545], maxlen=5)
# deque([0.8551, 0.8576, 0.8585, 0.8536, 0.8517], maxlen=5)
# deque([0.8589, 0.857, 0.8613, 0.8483, 0.8493], maxlen=5)
# deque([0.8568, 0.8536, 0.8504, 0.8491, 0.8623], maxlen=5)
# deque([0.8518, 0.8568, 0.857, 0.8551, 0.8557], maxlen=5)
# deque([0.8553, 0.8542, 0.8585, 0.8492, 0.8601], maxlen=5)
# deque([0.8553, 0.8587, 0.857, 0.8528, 0.8553], maxlen=5)
# deque([0.8574, 0.8521, 0.8601, 0.8576, 0.8577], maxlen=5)
# Iteration: 25 	Best fly index: 9 	Fitness value: -0.8569800000000001 delta:  0.005 counter:  0
# deque([0.8551, 0.8491, 0.8586, 0.8583, 0.8604], maxlen=5)
# deque([0.8556, 0.854, 0.8502, 0.8608, 0.8606], maxlen=5)
# deque([0.8594, 0.8589, 0.8536, 0.8545, 0.8552], maxlen=5)
# deque([0.8576, 0.8585, 0.8536, 0.8517, 0.8569], maxlen=5)
# deque([0.857, 0.8613, 0.8483, 0.8493, 0.8462], maxlen=5)
# deque([0.8536, 0.8504, 0.8491, 0.8623, 0.8523], maxlen=5)
# deque([0.8568, 0.857, 0.8551, 0.8557, 0.861], maxlen=5)
# deque([0.8542, 0.8585, 0.8492, 0.8601, 0.857], maxlen=5)
# deque([0.8587, 0.857, 0.8528, 0.8553, 0.8556], maxlen=5)
# deque([0.8521, 0.8601, 0.8576, 0.8577, 0.8562], maxlen=5)
# Iteration: 26 	Best fly index: 6 	Fitness value: -0.8571200000000001 delta:  0.005 counter:  0
# deque([0.8491, 0.8586, 0.8583, 0.8604, 0.8535], maxlen=5)
# deque([0.854, 0.8502, 0.8608, 0.8606, 0.8541], maxlen=5)
# deque([0.8589, 0.8536, 0.8545, 0.8552, 0.8517], maxlen=5)
# deque([0.8585, 0.8536, 0.8517, 0.8569, 0.8563], maxlen=5)
# deque([0.8613, 0.8483, 0.8493, 0.8462, 0.8598], maxlen=5)
# deque([0.8504, 0.8491, 0.8623, 0.8523, 0.8548], maxlen=5)
# deque([0.857, 0.8551, 0.8557, 0.861, 0.8557], maxlen=5)
# deque([0.8585, 0.8492, 0.8601, 0.857, 0.8543], maxlen=5)
# deque([0.857, 0.8528, 0.8553, 0.8556, 0.8497], maxlen=5)
# deque([0.8601, 0.8576, 0.8577, 0.8562, 0.8525], maxlen=5)
# Iteration: 27 	Best fly index: 6 	Fitness value: -0.8568999999999999 delta:  0.005 counter:  0
# deque([0.8586, 0.8583, 0.8604, 0.8535, 0.8511], maxlen=5)
# deque([0.8502, 0.8608, 0.8606, 0.8541, 0.8536], maxlen=5)
# deque([0.8536, 0.8545, 0.8552, 0.8517, 0.8607], maxlen=5)
# deque([0.8536, 0.8517, 0.8569, 0.8563, 0.8532], maxlen=5)
# deque([0.8483, 0.8493, 0.8462, 0.8598, 0.8539], maxlen=5)
# deque([0.8491, 0.8623, 0.8523, 0.8548, 0.8539], maxlen=5)
# deque([0.8551, 0.8557, 0.861, 0.8557, 0.8592], maxlen=5)
# deque([0.8492, 0.8601, 0.857, 0.8543, 0.8552], maxlen=5)
# deque([0.8528, 0.8553, 0.8556, 0.8497, 0.8541], maxlen=5)
# deque([0.8576, 0.8577, 0.8562, 0.8525, 0.8572], maxlen=5)
# Iteration: 28 	Best fly index: 6 	Fitness value: -0.85734 delta:  0.005 counter:  0
# deque([0.8583, 0.8604, 0.8535, 0.8511, 0.8605], maxlen=5)
# deque([0.8608, 0.8606, 0.8541, 0.8536, 0.8611], maxlen=5)
# deque([0.8545, 0.8552, 0.8517, 0.8607, 0.8562], maxlen=5)
# deque([0.8517, 0.8569, 0.8563, 0.8532, 0.8512], maxlen=5)
# deque([0.8493, 0.8462, 0.8598, 0.8539, 0.8594], maxlen=5)
# deque([0.8623, 0.8523, 0.8548, 0.8539, 0.8558], maxlen=5)
# deque([0.8557, 0.861, 0.8557, 0.8592, 0.8567], maxlen=5)
# deque([0.8601, 0.857, 0.8543, 0.8552, 0.86], maxlen=5)
# deque([0.8553, 0.8556, 0.8497, 0.8541, 0.8601], maxlen=5)
# deque([0.8577, 0.8562, 0.8525, 0.8572, 0.8636], maxlen=5)
# Iteration: 29 	Best fly index: 1 	Fitness value: -0.8580400000000001 delta:  0.005 counter:  0
# deque([0.8604, 0.8535, 0.8511, 0.8605, 0.8494], maxlen=5)
# deque([0.8606, 0.8541, 0.8536, 0.8611, 0.8517], maxlen=5)
# deque([0.8552, 0.8517, 0.8607, 0.8562, 0.8593], maxlen=5)
# deque([0.8569, 0.8563, 0.8532, 0.8512, 0.8503], maxlen=5)
# deque([0.8462, 0.8598, 0.8539, 0.8594, 0.8564], maxlen=5)
# deque([0.8523, 0.8548, 0.8539, 0.8558, 0.8569], maxlen=5)
# deque([0.861, 0.8557, 0.8592, 0.8567, 0.8588], maxlen=5)
# deque([0.857, 0.8543, 0.8552, 0.86, 0.8548], maxlen=5)
# deque([0.8556, 0.8497, 0.8541, 0.8601, 0.8545], maxlen=5)
# deque([0.8562, 0.8525, 0.8572, 0.8636, 0.8534], maxlen=5)
# Iteration: 30 	Best fly index: 6 	Fitness value: -0.8582799999999999 delta:  0.005 counter:  0
# deque([0.8535, 0.8511, 0.8605, 0.8494, 0.857], maxlen=5)
# deque([0.8541, 0.8536, 0.8611, 0.8517, 0.8524], maxlen=5)
# deque([0.8517, 0.8607, 0.8562, 0.8593, 0.8576], maxlen=5)
# deque([0.8563, 0.8532, 0.8512, 0.8503, 0.8546], maxlen=5)
# deque([0.8598, 0.8539, 0.8594, 0.8564, 0.8542], maxlen=5)
# deque([0.8548, 0.8539, 0.8558, 0.8569, 0.8512], maxlen=5)
# deque([0.8557, 0.8592, 0.8567, 0.8588, 0.8483], maxlen=5)
# deque([0.8543, 0.8552, 0.86, 0.8548, 0.8546], maxlen=5)
# deque([0.8497, 0.8541, 0.8601, 0.8545, 0.8542], maxlen=5)
# deque([0.8525, 0.8572, 0.8636, 0.8534, 0.8528], maxlen=5)
# Iteration: 31 	Best fly index: 2 	Fitness value: -0.8571 delta:  0.005 counter:  0
# deque([0.8511, 0.8605, 0.8494, 0.857, 0.8612], maxlen=5)
# deque([0.8536, 0.8611, 0.8517, 0.8524, 0.8541], maxlen=5)
# deque([0.8607, 0.8562, 0.8593, 0.8576, 0.8565], maxlen=5)
# deque([0.8532, 0.8512, 0.8503, 0.8546, 0.8583], maxlen=5)
# deque([0.8539, 0.8594, 0.8564, 0.8542, 0.8647], maxlen=5)
# deque([0.8539, 0.8558, 0.8569, 0.8512, 0.8566], maxlen=5)
# deque([0.8592, 0.8567, 0.8588, 0.8483, 0.8585], maxlen=5)
# deque([0.8552, 0.86, 0.8548, 0.8546, 0.862], maxlen=5)
# deque([0.8541, 0.8601, 0.8545, 0.8542, 0.8561], maxlen=5)
# deque([0.8572, 0.8636, 0.8534, 0.8528, 0.8584], maxlen=5)
# Iteration: 32 	Best fly index: 2 	Fitness value: -0.85806 delta:  0.005 counter:  0
# deque([0.8605, 0.8494, 0.857, 0.8612, 0.8499], maxlen=5)
# deque([0.8611, 0.8517, 0.8524, 0.8541, 0.8567], maxlen=5)
# deque([0.8562, 0.8593, 0.8576, 0.8565, 0.8571], maxlen=5)
# deque([0.8512, 0.8503, 0.8546, 0.8583, 0.8581], maxlen=5)
# deque([0.8594, 0.8564, 0.8542, 0.8647, 0.8523], maxlen=5)
# deque([0.8558, 0.8569, 0.8512, 0.8566, 0.8576], maxlen=5)
# deque([0.8567, 0.8588, 0.8483, 0.8585, 0.8579], maxlen=5)
# deque([0.86, 0.8548, 0.8546, 0.862, 0.8532], maxlen=5)
# deque([0.8601, 0.8545, 0.8542, 0.8561, 0.8549], maxlen=5)
# deque([0.8636, 0.8534, 0.8528, 0.8584, 0.8526], maxlen=5)
# Iteration: 33 	Best fly index: 4 	Fitness value: -0.8573999999999999 delta:  0.005 counter:  0
# deque([0.8494, 0.857, 0.8612, 0.8499, 0.8523], maxlen=5)
# deque([0.8517, 0.8524, 0.8541, 0.8567, 0.8569], maxlen=5)
# deque([0.8593, 0.8576, 0.8565, 0.8571, 0.8518], maxlen=5)
# deque([0.8503, 0.8546, 0.8583, 0.8581, 0.8569], maxlen=5)
# deque([0.8564, 0.8542, 0.8647, 0.8523, 0.8597], maxlen=5)
# deque([0.8569, 0.8512, 0.8566, 0.8576, 0.8555], maxlen=5)
# deque([0.8588, 0.8483, 0.8585, 0.8579, 0.8536], maxlen=5)
# deque([0.8548, 0.8546, 0.862, 0.8532, 0.8524], maxlen=5)
# deque([0.8545, 0.8542, 0.8561, 0.8549, 0.8515], maxlen=5)
# deque([0.8534, 0.8528, 0.8584, 0.8526, 0.8526], maxlen=5)
# Iteration: 34 	Best fly index: 4 	Fitness value: -0.85746 delta:  0.005 counter:  0
# deque([0.857, 0.8612, 0.8499, 0.8523, 0.8551], maxlen=5)
# deque([0.8524, 0.8541, 0.8567, 0.8569, 0.8589], maxlen=5)
# deque([0.8576, 0.8565, 0.8571, 0.8518, 0.8495], maxlen=5)
# deque([0.8546, 0.8583, 0.8581, 0.8569, 0.8557], maxlen=5)
# deque([0.8542, 0.8647, 0.8523, 0.8597, 0.8536], maxlen=5)
# deque([0.8512, 0.8566, 0.8576, 0.8555, 0.8551], maxlen=5)
# deque([0.8483, 0.8585, 0.8579, 0.8536, 0.8568], maxlen=5)
# deque([0.8546, 0.862, 0.8532, 0.8524, 0.857], maxlen=5)
# deque([0.8542, 0.8561, 0.8549, 0.8515, 0.8604], maxlen=5)
# deque([0.8528, 0.8584, 0.8526, 0.8526, 0.8561], maxlen=5)
# Iteration: 35 	Best fly index: 4 	Fitness value: -0.8569000000000001 delta:  0.005 counter:  0
# deque([0.8612, 0.8499, 0.8523, 0.8551, 0.8487], maxlen=5)
# deque([0.8541, 0.8567, 0.8569, 0.8589, 0.8524], maxlen=5)
# deque([0.8565, 0.8571, 0.8518, 0.8495, 0.8559], maxlen=5)
# deque([0.8583, 0.8581, 0.8569, 0.8557, 0.854], maxlen=5)
# deque([0.8647, 0.8523, 0.8597, 0.8536, 0.851], maxlen=5)
# deque([0.8566, 0.8576, 0.8555, 0.8551, 0.8587], maxlen=5)
# deque([0.8585, 0.8579, 0.8536, 0.8568, 0.8483], maxlen=5)
# deque([0.862, 0.8532, 0.8524, 0.857, 0.8572], maxlen=5)
# deque([0.8561, 0.8549, 0.8515, 0.8604, 0.8529], maxlen=5)
# deque([0.8584, 0.8526, 0.8526, 0.8561, 0.8601], maxlen=5)
# Iteration: 36 	Best fly index: 5 	Fitness value: -0.8567 delta:  0.005 counter:  0
# deque([0.8499, 0.8523, 0.8551, 0.8487, 0.8531], maxlen=5)
# deque([0.8567, 0.8569, 0.8589, 0.8524, 0.8492], maxlen=5)
# deque([0.8571, 0.8518, 0.8495, 0.8559, 0.8522], maxlen=5)
# deque([0.8581, 0.8569, 0.8557, 0.854, 0.8507], maxlen=5)
# deque([0.8523, 0.8597, 0.8536, 0.851, 0.8559], maxlen=5)
# deque([0.8576, 0.8555, 0.8551, 0.8587, 0.8547], maxlen=5)
# deque([0.8579, 0.8536, 0.8568, 0.8483, 0.8629], maxlen=5)
# deque([0.8532, 0.8524, 0.857, 0.8572, 0.8547], maxlen=5)
# deque([0.8549, 0.8515, 0.8604, 0.8529, 0.8628], maxlen=5)
# deque([0.8526, 0.8526, 0.8561, 0.8601, 0.8502], maxlen=5)
# Iteration: 37 	Best fly index: 8 	Fitness value: -0.8564999999999999 delta:  0.005 counter:  0
# deque([0.8523, 0.8551, 0.8487, 0.8531, 0.8566], maxlen=5)
# deque([0.8569, 0.8589, 0.8524, 0.8492, 0.8564], maxlen=5)
# deque([0.8518, 0.8495, 0.8559, 0.8522, 0.8532], maxlen=5)
# deque([0.8569, 0.8557, 0.854, 0.8507, 0.8533], maxlen=5)
# deque([0.8597, 0.8536, 0.851, 0.8559, 0.859], maxlen=5)
# deque([0.8555, 0.8551, 0.8587, 0.8547, 0.858], maxlen=5)
# deque([0.8536, 0.8568, 0.8483, 0.8629, 0.8585], maxlen=5)
# deque([0.8524, 0.857, 0.8572, 0.8547, 0.8553], maxlen=5)
# deque([0.8515, 0.8604, 0.8529, 0.8628, 0.848], maxlen=5)
# deque([0.8526, 0.8561, 0.8601, 0.8502, 0.8563], maxlen=5)
# Iteration: 38 	Best fly index: 5 	Fitness value: -0.8564 delta:  0.005 counter:  0
# deque([0.8551, 0.8487, 0.8531, 0.8566, 0.8569], maxlen=5)
# deque([0.8589, 0.8524, 0.8492, 0.8564, 0.8572], maxlen=5)
# deque([0.8495, 0.8559, 0.8522, 0.8532, 0.8533], maxlen=5)
# deque([0.8557, 0.854, 0.8507, 0.8533, 0.8579], maxlen=5)
# deque([0.8536, 0.851, 0.8559, 0.859, 0.8614], maxlen=5)
# deque([0.8551, 0.8587, 0.8547, 0.858, 0.8515], maxlen=5)
# deque([0.8568, 0.8483, 0.8629, 0.8585, 0.8547], maxlen=5)
# deque([0.857, 0.8572, 0.8547, 0.8553, 0.8617], maxlen=5)
# deque([0.8604, 0.8529, 0.8628, 0.848, 0.8538], maxlen=5)
# deque([0.8561, 0.8601, 0.8502, 0.8563, 0.8503], maxlen=5)
# Iteration: 39 	Best fly index: 7 	Fitness value: -0.8571799999999999 delta:  0.005 counter:  0
# deque([0.8487, 0.8531, 0.8566, 0.8569, 0.8541], maxlen=5)
# deque([0.8524, 0.8492, 0.8564, 0.8572, 0.8613], maxlen=5)
# deque([0.8559, 0.8522, 0.8532, 0.8533, 0.8565], maxlen=5)
# deque([0.854, 0.8507, 0.8533, 0.8579, 0.8538], maxlen=5)
# deque([0.851, 0.8559, 0.859, 0.8614, 0.8552], maxlen=5)
# deque([0.8587, 0.8547, 0.858, 0.8515, 0.8592], maxlen=5)
# deque([0.8483, 0.8629, 0.8585, 0.8547, 0.855], maxlen=5)
# deque([0.8572, 0.8547, 0.8553, 0.8617, 0.8529], maxlen=5)
# deque([0.8529, 0.8628, 0.848, 0.8538, 0.8503], maxlen=5)
# deque([0.8601, 0.8502, 0.8563, 0.8503, 0.8576], maxlen=5)
# Iteration: 40 	Best fly index: 4 	Fitness value: -0.8565000000000002 delta:  0.005 counter:  0
# deque([0.8531, 0.8566, 0.8569, 0.8541, 0.8614], maxlen=5)
# deque([0.8492, 0.8564, 0.8572, 0.8613, 0.8526], maxlen=5)
# deque([0.8522, 0.8532, 0.8533, 0.8565, 0.8588], maxlen=5)
# deque([0.8507, 0.8533, 0.8579, 0.8538, 0.8552], maxlen=5)
# deque([0.8559, 0.859, 0.8614, 0.8552, 0.8548], maxlen=5)
# deque([0.8547, 0.858, 0.8515, 0.8592, 0.8528], maxlen=5)
# deque([0.8629, 0.8585, 0.8547, 0.855, 0.853], maxlen=5)
# deque([0.8547, 0.8553, 0.8617, 0.8529, 0.8642], maxlen=5)
# deque([0.8628, 0.848, 0.8538, 0.8503, 0.8613], maxlen=5)
# deque([0.8502, 0.8563, 0.8503, 0.8576, 0.8588], maxlen=5)
# Iteration: 41 	Best fly index: 7 	Fitness value: -0.8577600000000001 delta:  0.005 counter:  0
# deque([0.8566, 0.8569, 0.8541, 0.8614, 0.8526], maxlen=5)
# deque([0.8564, 0.8572, 0.8613, 0.8526, 0.8538], maxlen=5)
# deque([0.8532, 0.8533, 0.8565, 0.8588, 0.8561], maxlen=5)
# deque([0.8533, 0.8579, 0.8538, 0.8552, 0.8507], maxlen=5)
# deque([0.859, 0.8614, 0.8552, 0.8548, 0.8594], maxlen=5)
# deque([0.858, 0.8515, 0.8592, 0.8528, 0.8555], maxlen=5)
# deque([0.8585, 0.8547, 0.855, 0.853, 0.8534], maxlen=5)
# deque([0.8553, 0.8617, 0.8529, 0.8642, 0.8551], maxlen=5)
# deque([0.848, 0.8538, 0.8503, 0.8613, 0.8573], maxlen=5)
# deque([0.8563, 0.8503, 0.8576, 0.8588, 0.8562], maxlen=5)
# Iteration: 42 	Best fly index: 4 	Fitness value: -0.8579600000000001 delta:  0.005 counter:  0
# deque([0.8569, 0.8541, 0.8614, 0.8526, 0.8501], maxlen=5)
# deque([0.8572, 0.8613, 0.8526, 0.8538, 0.8602], maxlen=5)
# deque([0.8533, 0.8565, 0.8588, 0.8561, 0.8662], maxlen=5)
# deque([0.8579, 0.8538, 0.8552, 0.8507, 0.861], maxlen=5)
# deque([0.8614, 0.8552, 0.8548, 0.8594, 0.8614], maxlen=5)
# deque([0.8515, 0.8592, 0.8528, 0.8555, 0.8532], maxlen=5)
# deque([0.8547, 0.855, 0.853, 0.8534, 0.853], maxlen=5)
# deque([0.8617, 0.8529, 0.8642, 0.8551, 0.8597], maxlen=5)
# deque([0.8538, 0.8503, 0.8613, 0.8573, 0.8545], maxlen=5)
# deque([0.8503, 0.8576, 0.8588, 0.8562, 0.8597], maxlen=5)
# Iteration: 43 	Best fly index: 7 	Fitness value: -0.8587199999999999 delta:  0.005 counter:  0
# deque([0.8541, 0.8614, 0.8526, 0.8501, 0.8562], maxlen=5)
# deque([0.8613, 0.8526, 0.8538, 0.8602, 0.8574], maxlen=5)
# deque([0.8565, 0.8588, 0.8561, 0.8662, 0.8598], maxlen=5)
# deque([0.8538, 0.8552, 0.8507, 0.861, 0.8507], maxlen=5)
# deque([0.8552, 0.8548, 0.8594, 0.8614, 0.8511], maxlen=5)
# deque([0.8592, 0.8528, 0.8555, 0.8532, 0.8553], maxlen=5)
# deque([0.855, 0.853, 0.8534, 0.853, 0.862], maxlen=5)
# deque([0.8529, 0.8642, 0.8551, 0.8597, 0.8585], maxlen=5)
# deque([0.8503, 0.8613, 0.8573, 0.8545, 0.8509], maxlen=5)
# deque([0.8576, 0.8588, 0.8562, 0.8597, 0.8436], maxlen=5)
# Iteration: 44 	Best fly index: 2 	Fitness value: -0.8594800000000001 delta:  0.005 counter:  0
# deque([0.8614, 0.8526, 0.8501, 0.8562, 0.858], maxlen=5)
# deque([0.8526, 0.8538, 0.8602, 0.8574, 0.8501], maxlen=5)
# deque([0.8588, 0.8561, 0.8662, 0.8598, 0.8512], maxlen=5)
# deque([0.8552, 0.8507, 0.861, 0.8507, 0.8521], maxlen=5)
# deque([0.8548, 0.8594, 0.8614, 0.8511, 0.8569], maxlen=5)
# deque([0.8528, 0.8555, 0.8532, 0.8553, 0.8574], maxlen=5)
# deque([0.853, 0.8534, 0.853, 0.862, 0.8549], maxlen=5)
# deque([0.8642, 0.8551, 0.8597, 0.8585, 0.861], maxlen=5)
# deque([0.8613, 0.8573, 0.8545, 0.8509, 0.8586], maxlen=5)
# deque([0.8588, 0.8562, 0.8597, 0.8436, 0.8507], maxlen=5)
# Iteration: 45 	Best fly index: 7 	Fitness value: -0.8596999999999999 delta:  0.005 counter:  0
# deque([0.8526, 0.8501, 0.8562, 0.858, 0.8572], maxlen=5)
# deque([0.8538, 0.8602, 0.8574, 0.8501, 0.8554], maxlen=5)
# deque([0.8561, 0.8662, 0.8598, 0.8512, 0.8584], maxlen=5)
# deque([0.8507, 0.861, 0.8507, 0.8521, 0.8604], maxlen=5)
# deque([0.8594, 0.8614, 0.8511, 0.8569, 0.8569], maxlen=5)
# deque([0.8555, 0.8532, 0.8553, 0.8574, 0.8569], maxlen=5)
# deque([0.8534, 0.853, 0.862, 0.8549, 0.8546], maxlen=5)
# deque([0.8551, 0.8597, 0.8585, 0.861, 0.8564], maxlen=5)
# deque([0.8573, 0.8545, 0.8509, 0.8586, 0.8585], maxlen=5)
# deque([0.8562, 0.8597, 0.8436, 0.8507, 0.8588], maxlen=5)
# Iteration: 46 	Best fly index: 2 	Fitness value: -0.8583400000000001 delta:  0.005 counter:  0
# deque([0.8501, 0.8562, 0.858, 0.8572, 0.8547], maxlen=5)
# deque([0.8602, 0.8574, 0.8501, 0.8554, 0.8529], maxlen=5)
# deque([0.8662, 0.8598, 0.8512, 0.8584, 0.8544], maxlen=5)
# deque([0.861, 0.8507, 0.8521, 0.8604, 0.8577], maxlen=5)
# deque([0.8614, 0.8511, 0.8569, 0.8569, 0.8602], maxlen=5)
# deque([0.8532, 0.8553, 0.8574, 0.8569, 0.8623], maxlen=5)
# deque([0.853, 0.862, 0.8549, 0.8546, 0.8682], maxlen=5)
# deque([0.8597, 0.8585, 0.861, 0.8564, 0.8565], maxlen=5)
# deque([0.8545, 0.8509, 0.8586, 0.8585, 0.8585], maxlen=5)
# deque([0.8597, 0.8436, 0.8507, 0.8588, 0.8576], maxlen=5)
# Iteration: 47 	Best fly index: 6 	Fitness value: -0.85854 delta:  0.005 counter:  0
# deque([0.8562, 0.858, 0.8572, 0.8547, 0.8571], maxlen=5)
# deque([0.8574, 0.8501, 0.8554, 0.8529, 0.8534], maxlen=5)
# deque([0.8598, 0.8512, 0.8584, 0.8544, 0.8554], maxlen=5)
# deque([0.8507, 0.8521, 0.8604, 0.8577, 0.852], maxlen=5)
# deque([0.8511, 0.8569, 0.8569, 0.8602, 0.8561], maxlen=5)
# deque([0.8553, 0.8574, 0.8569, 0.8623, 0.8605], maxlen=5)
# deque([0.862, 0.8549, 0.8546, 0.8682, 0.8573], maxlen=5)
# deque([0.8585, 0.861, 0.8564, 0.8565, 0.8605], maxlen=5)
# deque([0.8509, 0.8586, 0.8585, 0.8585, 0.856], maxlen=5)
# deque([0.8436, 0.8507, 0.8588, 0.8576, 0.8542], maxlen=5)
# Iteration: 48 	Best fly index: 6 	Fitness value: -0.8593999999999999 delta:  0.005 counter:  0
# deque([0.858, 0.8572, 0.8547, 0.8571, 0.8504], maxlen=5)
# deque([0.8501, 0.8554, 0.8529, 0.8534, 0.8475], maxlen=5)
# deque([0.8512, 0.8584, 0.8544, 0.8554, 0.8582], maxlen=5)
# deque([0.8521, 0.8604, 0.8577, 0.852, 0.8584], maxlen=5)
# deque([0.8569, 0.8569, 0.8602, 0.8561, 0.8569], maxlen=5)
# deque([0.8574, 0.8569, 0.8623, 0.8605, 0.8582], maxlen=5)
# deque([0.8549, 0.8546, 0.8682, 0.8573, 0.8543], maxlen=5)
# deque([0.861, 0.8564, 0.8565, 0.8605, 0.8545], maxlen=5)
# deque([0.8586, 0.8585, 0.8585, 0.856, 0.8495], maxlen=5)
# deque([0.8507, 0.8588, 0.8576, 0.8542, 0.8546], maxlen=5)
# Iteration: 49 	Best fly index: 5 	Fitness value: -0.85906 delta:  0.005 counter:  0
# deque([0.8572, 0.8547, 0.8571, 0.8504, 0.8559], maxlen=5)
# deque([0.8554, 0.8529, 0.8534, 0.8475, 0.8536], maxlen=5)
# deque([0.8584, 0.8544, 0.8554, 0.8582, 0.8553], maxlen=5)
# deque([0.8604, 0.8577, 0.852, 0.8584, 0.8586], maxlen=5)
# deque([0.8569, 0.8602, 0.8561, 0.8569, 0.8563], maxlen=5)
# deque([0.8569, 0.8623, 0.8605, 0.8582, 0.852], maxlen=5)
# deque([0.8546, 0.8682, 0.8573, 0.8543, 0.8581], maxlen=5)
# deque([0.8564, 0.8565, 0.8605, 0.8545, 0.8537], maxlen=5)
# deque([0.8585, 0.8585, 0.856, 0.8495, 0.8564], maxlen=5)
# deque([0.8588, 0.8576, 0.8542, 0.8546, 0.8573], maxlen=5)
# Iteration: 50 	Best fly index: 6 	Fitness value: -0.8584999999999999 delta:  0.005 counter:  0
# deque([0.8547, 0.8571, 0.8504, 0.8559, 0.8496], maxlen=5)
# deque([0.8529, 0.8534, 0.8475, 0.8536, 0.8514], maxlen=5)
# deque([0.8544, 0.8554, 0.8582, 0.8553, 0.8522], maxlen=5)
# deque([0.8577, 0.852, 0.8584, 0.8586, 0.8543], maxlen=5)
# deque([0.8602, 0.8561, 0.8569, 0.8563, 0.8561], maxlen=5)
# deque([0.8623, 0.8605, 0.8582, 0.852, 0.858], maxlen=5)
# deque([0.8682, 0.8573, 0.8543, 0.8581, 0.8479], maxlen=5)
# deque([0.8565, 0.8605, 0.8545, 0.8537, 0.8542], maxlen=5)
# deque([0.8585, 0.856, 0.8495, 0.8564, 0.859], maxlen=5)
# deque([0.8576, 0.8542, 0.8546, 0.8573, 0.8547], maxlen=5)
# Iteration: 51 	Best fly index: 5 	Fitness value: -0.8581999999999999 delta:  0.005 counter:  0
# deque([0.8571, 0.8504, 0.8559, 0.8496, 0.8513], maxlen=5)
# deque([0.8534, 0.8475, 0.8536, 0.8514, 0.8546], maxlen=5)
# deque([0.8554, 0.8582, 0.8553, 0.8522, 0.856], maxlen=5)
# deque([0.852, 0.8584, 0.8586, 0.8543, 0.857], maxlen=5)
# deque([0.8561, 0.8569, 0.8563, 0.8561, 0.8559], maxlen=5)
# deque([0.8605, 0.8582, 0.852, 0.858, 0.847], maxlen=5)
# deque([0.8573, 0.8543, 0.8581, 0.8479, 0.8545], maxlen=5)
# deque([0.8605, 0.8545, 0.8537, 0.8542, 0.8566], maxlen=5)
# deque([0.856, 0.8495, 0.8564, 0.859, 0.8584], maxlen=5)
# deque([0.8542, 0.8546, 0.8573, 0.8547, 0.8561], maxlen=5)
# Iteration: 52 	Best fly index: 4 	Fitness value: -0.85626 delta:  0.005 counter:  0
# deque([0.8504, 0.8559, 0.8496, 0.8513, 0.8588], maxlen=5)
# deque([0.8475, 0.8536, 0.8514, 0.8546, 0.8549], maxlen=5)
# deque([0.8582, 0.8553, 0.8522, 0.856, 0.8554], maxlen=5)
# deque([0.8584, 0.8586, 0.8543, 0.857, 0.8521], maxlen=5)
# deque([0.8569, 0.8563, 0.8561, 0.8559, 0.8634], maxlen=5)
# deque([0.8582, 0.852, 0.858, 0.847, 0.8635], maxlen=5)
# deque([0.8543, 0.8581, 0.8479, 0.8545, 0.8567], maxlen=5)
# deque([0.8545, 0.8537, 0.8542, 0.8566, 0.858], maxlen=5)
# deque([0.8495, 0.8564, 0.859, 0.8584, 0.8562], maxlen=5)
# deque([0.8546, 0.8573, 0.8547, 0.8561, 0.8561], maxlen=5)
# Iteration: 53 	Best fly index: 4 	Fitness value: -0.8577200000000001 delta:  0.005 counter:  0
# deque([0.8559, 0.8496, 0.8513, 0.8588, 0.8583], maxlen=5)
# deque([0.8536, 0.8514, 0.8546, 0.8549, 0.8491], maxlen=5)
# deque([0.8553, 0.8522, 0.856, 0.8554, 0.8549], maxlen=5)
# deque([0.8586, 0.8543, 0.857, 0.8521, 0.8585], maxlen=5)
# deque([0.8563, 0.8561, 0.8559, 0.8634, 0.8546], maxlen=5)
# deque([0.852, 0.858, 0.847, 0.8635, 0.8598], maxlen=5)
# deque([0.8581, 0.8479, 0.8545, 0.8567, 0.8612], maxlen=5)
# deque([0.8537, 0.8542, 0.8566, 0.858, 0.8499], maxlen=5)
# deque([0.8564, 0.859, 0.8584, 0.8562, 0.8552], maxlen=5)
# deque([0.8573, 0.8547, 0.8561, 0.8561, 0.8528], maxlen=5)
# Iteration: 54 	Best fly index: 4 	Fitness value: -0.8572599999999999 delta:  0.005 counter:  0
# deque([0.8496, 0.8513, 0.8588, 0.8583, 0.8519], maxlen=5)
# deque([0.8514, 0.8546, 0.8549, 0.8491, 0.8616], maxlen=5)
# deque([0.8522, 0.856, 0.8554, 0.8549, 0.8581], maxlen=5)
# deque([0.8543, 0.857, 0.8521, 0.8585, 0.8536], maxlen=5)
# deque([0.8561, 0.8559, 0.8634, 0.8546, 0.8579], maxlen=5)
# deque([0.858, 0.847, 0.8635, 0.8598, 0.8542], maxlen=5)
# deque([0.8479, 0.8545, 0.8567, 0.8612, 0.8536], maxlen=5)
# deque([0.8542, 0.8566, 0.858, 0.8499, 0.8542], maxlen=5)
# deque([0.859, 0.8584, 0.8562, 0.8552, 0.8634], maxlen=5)
# deque([0.8547, 0.8561, 0.8561, 0.8528, 0.8599], maxlen=5)
# Iteration: 55 	Best fly index: 8 	Fitness value: -0.8584399999999999 delta:  0.005 counter:  0
# deque([0.8513, 0.8588, 0.8583, 0.8519, 0.8574], maxlen=5)
# deque([0.8546, 0.8549, 0.8491, 0.8616, 0.8541], maxlen=5)
# deque([0.856, 0.8554, 0.8549, 0.8581, 0.8591], maxlen=5)
# deque([0.857, 0.8521, 0.8585, 0.8536, 0.8503], maxlen=5)
# deque([0.8559, 0.8634, 0.8546, 0.8579, 0.8617], maxlen=5)
# deque([0.847, 0.8635, 0.8598, 0.8542, 0.852], maxlen=5)
# deque([0.8545, 0.8567, 0.8612, 0.8536, 0.857], maxlen=5)
# deque([0.8566, 0.858, 0.8499, 0.8542, 0.8526], maxlen=5)
# deque([0.8584, 0.8562, 0.8552, 0.8634, 0.8554], maxlen=5)
# deque([0.8561, 0.8561, 0.8528, 0.8599, 0.8586], maxlen=5)
# Iteration: 56 	Best fly index: 4 	Fitness value: -0.8587 delta:  0.005 counter:  0
# deque([0.8588, 0.8583, 0.8519, 0.8574, 0.8514], maxlen=5)
# deque([0.8549, 0.8491, 0.8616, 0.8541, 0.8602], maxlen=5)
# deque([0.8554, 0.8549, 0.8581, 0.8591, 0.848], maxlen=5)
# deque([0.8521, 0.8585, 0.8536, 0.8503, 0.851], maxlen=5)
# deque([0.8634, 0.8546, 0.8579, 0.8617, 0.8568], maxlen=5)
# deque([0.8635, 0.8598, 0.8542, 0.852, 0.8528], maxlen=5)
# deque([0.8567, 0.8612, 0.8536, 0.857, 0.8564], maxlen=5)
# deque([0.858, 0.8499, 0.8542, 0.8526, 0.8578], maxlen=5)
# deque([0.8562, 0.8552, 0.8634, 0.8554, 0.8552], maxlen=5)
# deque([0.8561, 0.8528, 0.8599, 0.8586, 0.854], maxlen=5)
# Iteration: 57 	Best fly index: 4 	Fitness value: -0.8588799999999999 delta:  0.005 counter:  0
# deque([0.8583, 0.8519, 0.8574, 0.8514, 0.8571], maxlen=5)
# deque([0.8491, 0.8616, 0.8541, 0.8602, 0.8582], maxlen=5)
# deque([0.8549, 0.8581, 0.8591, 0.848, 0.857], maxlen=5)
# deque([0.8585, 0.8536, 0.8503, 0.851, 0.8545], maxlen=5)
# deque([0.8546, 0.8579, 0.8617, 0.8568, 0.8651], maxlen=5)
# deque([0.8598, 0.8542, 0.852, 0.8528, 0.8515], maxlen=5)
# deque([0.8612, 0.8536, 0.857, 0.8564, 0.8542], maxlen=5)
# deque([0.8499, 0.8542, 0.8526, 0.8578, 0.8562], maxlen=5)
# deque([0.8552, 0.8634, 0.8554, 0.8552, 0.8577], maxlen=5)
# deque([0.8528, 0.8599, 0.8586, 0.854, 0.8509], maxlen=5)
# Iteration: 58 	Best fly index: 4 	Fitness value: -0.85922 delta:  0.005 counter:  0
# deque([0.8519, 0.8574, 0.8514, 0.8571, 0.8511], maxlen=5)
# deque([0.8616, 0.8541, 0.8602, 0.8582, 0.8526], maxlen=5)
# deque([0.8581, 0.8591, 0.848, 0.857, 0.8512], maxlen=5)
# deque([0.8536, 0.8503, 0.851, 0.8545, 0.8541], maxlen=5)
# deque([0.8579, 0.8617, 0.8568, 0.8651, 0.8524], maxlen=5)
# deque([0.8542, 0.852, 0.8528, 0.8515, 0.8536], maxlen=5)
# deque([0.8536, 0.857, 0.8564, 0.8542, 0.8596], maxlen=5)
# deque([0.8542, 0.8526, 0.8578, 0.8562, 0.8535], maxlen=5)
# deque([0.8634, 0.8554, 0.8552, 0.8577, 0.8616], maxlen=5)
# deque([0.8599, 0.8586, 0.854, 0.8509, 0.8554], maxlen=5)
# Iteration: 59 	Best fly index: 4 	Fitness value: -0.85878 delta:  0.005 counter:  0
# deque([0.8574, 0.8514, 0.8571, 0.8511, 0.8546], maxlen=5)
# deque([0.8541, 0.8602, 0.8582, 0.8526, 0.8484], maxlen=5)
# deque([0.8591, 0.848, 0.857, 0.8512, 0.8556], maxlen=5)
# deque([0.8503, 0.851, 0.8545, 0.8541, 0.8597], maxlen=5)
# deque([0.8617, 0.8568, 0.8651, 0.8524, 0.8597], maxlen=5)
# deque([0.852, 0.8528, 0.8515, 0.8536, 0.854], maxlen=5)
# deque([0.857, 0.8564, 0.8542, 0.8596, 0.855], maxlen=5)
# deque([0.8526, 0.8578, 0.8562, 0.8535, 0.8606], maxlen=5)
# deque([0.8554, 0.8552, 0.8577, 0.8616, 0.851], maxlen=5)
# deque([0.8586, 0.854, 0.8509, 0.8554, 0.8565], maxlen=5)
# Iteration: 60 	Best fly index: 4 	Fitness value: -0.85914 delta:  0.005 counter:  0
# deque([0.8514, 0.8571, 0.8511, 0.8546, 0.8536], maxlen=5)
# deque([0.8602, 0.8582, 0.8526, 0.8484, 0.8572], maxlen=5)
# deque([0.848, 0.857, 0.8512, 0.8556, 0.8543], maxlen=5)
# deque([0.851, 0.8545, 0.8541, 0.8597, 0.8639], maxlen=5)
# deque([0.8568, 0.8651, 0.8524, 0.8597, 0.8571], maxlen=5)
# deque([0.8528, 0.8515, 0.8536, 0.854, 0.8495], maxlen=5)
# deque([0.8564, 0.8542, 0.8596, 0.855, 0.8545], maxlen=5)
# deque([0.8578, 0.8562, 0.8535, 0.8606, 0.8528], maxlen=5)
# deque([0.8552, 0.8577, 0.8616, 0.851, 0.8506], maxlen=5)
# deque([0.854, 0.8509, 0.8554, 0.8565, 0.8529], maxlen=5)
# Iteration: 61 	Best fly index: 4 	Fitness value: -0.85822 delta:  0.005 counter:  0
# deque([0.8571, 0.8511, 0.8546, 0.8536, 0.8552], maxlen=5)
# deque([0.8582, 0.8526, 0.8484, 0.8572, 0.8573], maxlen=5)
# deque([0.857, 0.8512, 0.8556, 0.8543, 0.8595], maxlen=5)
# deque([0.8545, 0.8541, 0.8597, 0.8639, 0.8572], maxlen=5)
# deque([0.8651, 0.8524, 0.8597, 0.8571, 0.8556], maxlen=5)
# deque([0.8515, 0.8536, 0.854, 0.8495, 0.8523], maxlen=5)
# deque([0.8542, 0.8596, 0.855, 0.8545, 0.856], maxlen=5)
# deque([0.8562, 0.8535, 0.8606, 0.8528, 0.848], maxlen=5)
# deque([0.8577, 0.8616, 0.851, 0.8506, 0.8553], maxlen=5)
# deque([0.8509, 0.8554, 0.8565, 0.8529, 0.8545], maxlen=5)
# Iteration: 62 	Best fly index: 4 	Fitness value: -0.8579800000000001 delta:  0.005 counter:  0
# deque([0.8511, 0.8546, 0.8536, 0.8552, 0.8512], maxlen=5)
# deque([0.8526, 0.8484, 0.8572, 0.8573, 0.851], maxlen=5)
# deque([0.8512, 0.8556, 0.8543, 0.8595, 0.8618], maxlen=5)
# deque([0.8541, 0.8597, 0.8639, 0.8572, 0.8606], maxlen=5)
# deque([0.8524, 0.8597, 0.8571, 0.8556, 0.8569], maxlen=5)
# deque([0.8536, 0.854, 0.8495, 0.8523, 0.8603], maxlen=5)
# deque([0.8596, 0.855, 0.8545, 0.856, 0.8551], maxlen=5)
# deque([0.8535, 0.8606, 0.8528, 0.848, 0.855], maxlen=5)
# deque([0.8616, 0.851, 0.8506, 0.8553, 0.8584], maxlen=5)
# deque([0.8554, 0.8565, 0.8529, 0.8545, 0.8561], maxlen=5)
# Iteration: 63 	Best fly index: 3 	Fitness value: -0.8591 delta:  0.005 counter:  0
# deque([0.8546, 0.8536, 0.8552, 0.8512, 0.8539], maxlen=5)
# deque([0.8484, 0.8572, 0.8573, 0.851, 0.8509], maxlen=5)
# deque([0.8556, 0.8543, 0.8595, 0.8618, 0.8573], maxlen=5)
# deque([0.8597, 0.8639, 0.8572, 0.8606, 0.8574], maxlen=5)
# deque([0.8597, 0.8571, 0.8556, 0.8569, 0.8554], maxlen=5)
# deque([0.854, 0.8495, 0.8523, 0.8603, 0.8542], maxlen=5)
# deque([0.855, 0.8545, 0.856, 0.8551, 0.8569], maxlen=5)
# deque([0.8606, 0.8528, 0.848, 0.855, 0.8538], maxlen=5)
# deque([0.851, 0.8506, 0.8553, 0.8584, 0.8574], maxlen=5)
# deque([0.8565, 0.8529, 0.8545, 0.8561, 0.8543], maxlen=5)
# Iteration: 64 	Best fly index: 3 	Fitness value: -0.85976 delta:  0.005 counter:  0
# deque([0.8536, 0.8552, 0.8512, 0.8539, 0.8523], maxlen=5)
# deque([0.8572, 0.8573, 0.851, 0.8509, 0.8593], maxlen=5)
# deque([0.8543, 0.8595, 0.8618, 0.8573, 0.8556], maxlen=5)
# deque([0.8639, 0.8572, 0.8606, 0.8574, 0.8525], maxlen=5)
# deque([0.8571, 0.8556, 0.8569, 0.8554, 0.857], maxlen=5)
# deque([0.8495, 0.8523, 0.8603, 0.8542, 0.8567], maxlen=5)
# deque([0.8545, 0.856, 0.8551, 0.8569, 0.8547], maxlen=5)
# deque([0.8528, 0.848, 0.855, 0.8538, 0.8652], maxlen=5)
# deque([0.8506, 0.8553, 0.8584, 0.8574, 0.8548], maxlen=5)
# deque([0.8529, 0.8545, 0.8561, 0.8543, 0.857], maxlen=5)
# Iteration: 65 	Best fly index: 3 	Fitness value: -0.85832 delta:  0.005 counter:  0
# deque([0.8552, 0.8512, 0.8539, 0.8523, 0.8645], maxlen=5)
# deque([0.8573, 0.851, 0.8509, 0.8593, 0.8586], maxlen=5)
# deque([0.8595, 0.8618, 0.8573, 0.8556, 0.8528], maxlen=5)
# deque([0.8572, 0.8606, 0.8574, 0.8525, 0.859], maxlen=5)
# deque([0.8556, 0.8569, 0.8554, 0.857, 0.8571], maxlen=5)
# deque([0.8523, 0.8603, 0.8542, 0.8567, 0.8558], maxlen=5)
# deque([0.856, 0.8551, 0.8569, 0.8547, 0.855], maxlen=5)
# deque([0.848, 0.855, 0.8538, 0.8652, 0.8485], maxlen=5)
# deque([0.8553, 0.8584, 0.8574, 0.8548, 0.8549], maxlen=5)
# deque([0.8545, 0.8561, 0.8543, 0.857, 0.8523], maxlen=5)
# Iteration: 66 	Best fly index: 2 	Fitness value: -0.8573999999999999 delta:  0.005 counter:  0
# deque([0.8512, 0.8539, 0.8523, 0.8645, 0.8523], maxlen=5)
# deque([0.851, 0.8509, 0.8593, 0.8586, 0.8595], maxlen=5)
# deque([0.8618, 0.8573, 0.8556, 0.8528, 0.857], maxlen=5)
# deque([0.8606, 0.8574, 0.8525, 0.859, 0.8536], maxlen=5)
# deque([0.8569, 0.8554, 0.857, 0.8571, 0.8599], maxlen=5)
# deque([0.8603, 0.8542, 0.8567, 0.8558, 0.854], maxlen=5)
# deque([0.8551, 0.8569, 0.8547, 0.855, 0.8539], maxlen=5)
# deque([0.855, 0.8538, 0.8652, 0.8485, 0.8609], maxlen=5)
# deque([0.8584, 0.8574, 0.8548, 0.8549, 0.8565], maxlen=5)
# deque([0.8561, 0.8543, 0.857, 0.8523, 0.861], maxlen=5)
# Iteration: 67 	Best fly index: 4 	Fitness value: -0.8572599999999999 delta:  0.005 counter:  0
# deque([0.8539, 0.8523, 0.8645, 0.8523, 0.8526], maxlen=5)
# deque([0.8509, 0.8593, 0.8586, 0.8595, 0.8544], maxlen=5)
# deque([0.8573, 0.8556, 0.8528, 0.857, 0.8576], maxlen=5)
# deque([0.8574, 0.8525, 0.859, 0.8536, 0.8609], maxlen=5)
# deque([0.8554, 0.857, 0.8571, 0.8599, 0.8579], maxlen=5)
# deque([0.8542, 0.8567, 0.8558, 0.854, 0.854], maxlen=5)
# deque([0.8569, 0.8547, 0.855, 0.8539, 0.8526], maxlen=5)
# deque([0.8538, 0.8652, 0.8485, 0.8609, 0.8515], maxlen=5)
# deque([0.8574, 0.8548, 0.8549, 0.8565, 0.8508], maxlen=5)
# deque([0.8543, 0.857, 0.8523, 0.861, 0.8588], maxlen=5)
# Iteration: 68 	Best fly index: 4 	Fitness value: -0.85746 delta:  0.005 counter:  0
# deque([0.8523, 0.8645, 0.8523, 0.8526, 0.8554], maxlen=5)
# deque([0.8593, 0.8586, 0.8595, 0.8544, 0.8543], maxlen=5)
# deque([0.8556, 0.8528, 0.857, 0.8576, 0.8515], maxlen=5)
# deque([0.8525, 0.859, 0.8536, 0.8609, 0.8602], maxlen=5)
# deque([0.857, 0.8571, 0.8599, 0.8579, 0.8579], maxlen=5)
# deque([0.8567, 0.8558, 0.854, 0.854, 0.8557], maxlen=5)
# deque([0.8547, 0.855, 0.8539, 0.8526, 0.8601], maxlen=5)
# deque([0.8652, 0.8485, 0.8609, 0.8515, 0.856], maxlen=5)
# deque([0.8548, 0.8549, 0.8565, 0.8508, 0.8558], maxlen=5)
# deque([0.857, 0.8523, 0.861, 0.8588, 0.8533], maxlen=5)
# Iteration: 69 	Best fly index: 4 	Fitness value: -0.85796 delta:  0.005 counter:  0
# deque([0.8645, 0.8523, 0.8526, 0.8554, 0.8535], maxlen=5)
# deque([0.8586, 0.8595, 0.8544, 0.8543, 0.8538], maxlen=5)
# deque([0.8528, 0.857, 0.8576, 0.8515, 0.8631], maxlen=5)
# deque([0.859, 0.8536, 0.8609, 0.8602, 0.8554], maxlen=5)
# deque([0.8571, 0.8599, 0.8579, 0.8579, 0.8555], maxlen=5)
# deque([0.8558, 0.854, 0.854, 0.8557, 0.8531], maxlen=5)
# deque([0.855, 0.8539, 0.8526, 0.8601, 0.8535], maxlen=5)
# deque([0.8485, 0.8609, 0.8515, 0.856, 0.862], maxlen=5)
# deque([0.8549, 0.8565, 0.8508, 0.8558, 0.8571], maxlen=5)
# deque([0.8523, 0.861, 0.8588, 0.8533, 0.8556], maxlen=5)
# Iteration: 70 	Best fly index: 3 	Fitness value: -0.85782 delta:  0.005 counter:  0
# deque([0.8523, 0.8526, 0.8554, 0.8535, 0.8513], maxlen=5)
# deque([0.8595, 0.8544, 0.8543, 0.8538, 0.8491], maxlen=5)
# deque([0.857, 0.8576, 0.8515, 0.8631, 0.8577], maxlen=5)
# deque([0.8536, 0.8609, 0.8602, 0.8554, 0.8555], maxlen=5)
# deque([0.8599, 0.8579, 0.8579, 0.8555, 0.854], maxlen=5)
# deque([0.854, 0.854, 0.8557, 0.8531, 0.8519], maxlen=5)
# deque([0.8539, 0.8526, 0.8601, 0.8535, 0.8574], maxlen=5)
# deque([0.8609, 0.8515, 0.856, 0.862, 0.8567], maxlen=5)
# deque([0.8565, 0.8508, 0.8558, 0.8571, 0.8526], maxlen=5)
# deque([0.861, 0.8588, 0.8533, 0.8556, 0.8514], maxlen=5)
# Iteration: 71 	Best fly index: 7 	Fitness value: -0.8574200000000001 delta:  0.005 counter:  0
# deque([0.8526, 0.8554, 0.8535, 0.8513, 0.8557], maxlen=5)
# deque([0.8544, 0.8543, 0.8538, 0.8491, 0.8586], maxlen=5)
# deque([0.8576, 0.8515, 0.8631, 0.8577, 0.8563], maxlen=5)
# deque([0.8609, 0.8602, 0.8554, 0.8555, 0.8588], maxlen=5)
# deque([0.8579, 0.8579, 0.8555, 0.854, 0.8542], maxlen=5)
# deque([0.854, 0.8557, 0.8531, 0.8519, 0.8522], maxlen=5)
# deque([0.8526, 0.8601, 0.8535, 0.8574, 0.8526], maxlen=5)
# deque([0.8515, 0.856, 0.862, 0.8567, 0.8587], maxlen=5)
# deque([0.8508, 0.8558, 0.8571, 0.8526, 0.8563], maxlen=5)
# deque([0.8588, 0.8533, 0.8556, 0.8514, 0.8537], maxlen=5)
# Iteration: 72 	Best fly index: 3 	Fitness value: -0.85816 delta:  0.005 counter:  0
# deque([0.8554, 0.8535, 0.8513, 0.8557, 0.8499], maxlen=5)
# deque([0.8543, 0.8538, 0.8491, 0.8586, 0.8543], maxlen=5)
# deque([0.8515, 0.8631, 0.8577, 0.8563, 0.8613], maxlen=5)
# deque([0.8602, 0.8554, 0.8555, 0.8588, 0.8538], maxlen=5)
# ...
# deque([0.8525, 0.8585, 0.8518, 0.8655, 0.8503], maxlen=5)
# deque([0.8562, 0.8585, 0.861, 0.8562, 0.8534], maxlen=5)
# deque([0.8557, 0.8532, 0.8518, 0.8582, 0.8574], maxlen=5)
# deque([0.8512, 0.8601, 0.8569, 0.8552, 0.8562], maxlen=5)
# deque([0.8522, 0.8564, 0.8587, 0.8555, 0.848], maxlen=5)
# deque([0.8534, 0.8493, 0.8537, 0.8562, 0.854], maxlen=5)
# deque([0.861, 0.8571, 0.8544, 0.8511, 0.8559], maxlen=5)
# Iteration: 169 	Best fly index: 1 	Fitness value: -0.85732 delta:  0.005 counter:  0
# deque([0.8485, 0.8561, 0.859, 0.8536, 0.8591], maxlen=5)
# deque([0.8603, 0.8546, 0.8577, 0.8574, 0.8571], maxlen=5)
# deque([0.8499, 0.8551, 0.8585, 0.8531, 0.8575], maxlen=5)
# deque([0.8585, 0.8518, 0.8655, 0.8503, 0.8527], maxlen=5)
# deque([0.8585, 0.861, 0.8562, 0.8534, 0.8518], maxlen=5)
# deque([0.8532, 0.8518, 0.8582, 0.8574, 0.8494], maxlen=5)
# deque([0.8601, 0.8569, 0.8552, 0.8562, 0.8589], maxlen=5)
# deque([0.8564, 0.8587, 0.8555, 0.848, 0.8604], maxlen=5)
# deque([0.8493, 0.8537, 0.8562, 0.854, 0.8547], maxlen=5)
# deque([0.8571, 0.8544, 0.8511, 0.8559, 0.8533], maxlen=5)
# Iteration: 170 	Best fly index: 6 	Fitness value: -0.85746 delta:  0.005 counter:  0
# deque([0.8561, 0.859, 0.8536, 0.8591, 0.8479], maxlen=5)
# deque([0.8546, 0.8577, 0.8574, 0.8571, 0.8604], maxlen=5)
# deque([0.8551, 0.8585, 0.8531, 0.8575, 0.8513], maxlen=5)
# deque([0.8518, 0.8655, 0.8503, 0.8527, 0.8497], maxlen=5)
# deque([0.861, 0.8562, 0.8534, 0.8518, 0.8529], maxlen=5)
# deque([0.8518, 0.8582, 0.8574, 0.8494, 0.8578], maxlen=5)
# deque([0.8569, 0.8552, 0.8562, 0.8589, 0.8509], maxlen=5)
# deque([0.8587, 0.8555, 0.848, 0.8604, 0.8555], maxlen=5)
# deque([0.8537, 0.8562, 0.854, 0.8547, 0.8517], maxlen=5)
# deque([0.8544, 0.8511, 0.8559, 0.8533, 0.8544], maxlen=5)
# Iteration: 171 	Best fly index: 1 	Fitness value: -0.8574400000000001 delta:  0.005 counter:  0
# deque([0.859, 0.8536, 0.8591, 0.8479, 0.8571], maxlen=5)
# deque([0.8577, 0.8574, 0.8571, 0.8604, 0.8579], maxlen=5)
# deque([0.8585, 0.8531, 0.8575, 0.8513, 0.851], maxlen=5)
# deque([0.8655, 0.8503, 0.8527, 0.8497, 0.856], maxlen=5)
# deque([0.8562, 0.8534, 0.8518, 0.8529, 0.8515], maxlen=5)
# deque([0.8582, 0.8574, 0.8494, 0.8578, 0.8531], maxlen=5)
# deque([0.8552, 0.8562, 0.8589, 0.8509, 0.8474], maxlen=5)
# deque([0.8555, 0.848, 0.8604, 0.8555, 0.8631], maxlen=5)
# deque([0.8562, 0.854, 0.8547, 0.8517, 0.8509], maxlen=5)
# deque([0.8511, 0.8559, 0.8533, 0.8544, 0.857], maxlen=5)
# Iteration: 172 	Best fly index: 1 	Fitness value: -0.8581 delta:  0.005 counter:  0
# deque([0.8536, 0.8591, 0.8479, 0.8571, 0.8576], maxlen=5)
# deque([0.8574, 0.8571, 0.8604, 0.8579, 0.8583], maxlen=5)
# deque([0.8531, 0.8575, 0.8513, 0.851, 0.8574], maxlen=5)
# deque([0.8503, 0.8527, 0.8497, 0.856, 0.8521], maxlen=5)
# deque([0.8534, 0.8518, 0.8529, 0.8515, 0.8496], maxlen=5)
# deque([0.8574, 0.8494, 0.8578, 0.8531, 0.8591], maxlen=5)
# deque([0.8562, 0.8589, 0.8509, 0.8474, 0.8594], maxlen=5)
# deque([0.848, 0.8604, 0.8555, 0.8631, 0.857], maxlen=5)
# deque([0.854, 0.8547, 0.8517, 0.8509, 0.8566], maxlen=5)
# deque([0.8559, 0.8533, 0.8544, 0.857, 0.8544], maxlen=5)
# Iteration: 173 	Best fly index: 1 	Fitness value: -0.85822 delta:  0.005 counter:  0
# deque([0.8591, 0.8479, 0.8571, 0.8576, 0.8573], maxlen=5)
# deque([0.8571, 0.8604, 0.8579, 0.8583, 0.8593], maxlen=5)
# deque([0.8575, 0.8513, 0.851, 0.8574, 0.8583], maxlen=5)
# deque([0.8527, 0.8497, 0.856, 0.8521, 0.8589], maxlen=5)
# deque([0.8518, 0.8529, 0.8515, 0.8496, 0.8545], maxlen=5)
# deque([0.8494, 0.8578, 0.8531, 0.8591, 0.8592], maxlen=5)
# deque([0.8589, 0.8509, 0.8474, 0.8594, 0.8544], maxlen=5)
# deque([0.8604, 0.8555, 0.8631, 0.857, 0.8551], maxlen=5)
# deque([0.8547, 0.8517, 0.8509, 0.8566, 0.8541], maxlen=5)
# deque([0.8533, 0.8544, 0.857, 0.8544, 0.8547], maxlen=5)
# Iteration: 174 	Best fly index: 1 	Fitness value: -0.8586 delta:  0.005 counter:  0
# deque([0.8479, 0.8571, 0.8576, 0.8573, 0.8548], maxlen=5)
# deque([0.8604, 0.8579, 0.8583, 0.8593, 0.8593], maxlen=5)
# deque([0.8513, 0.851, 0.8574, 0.8583, 0.8587], maxlen=5)
# deque([0.8497, 0.856, 0.8521, 0.8589, 0.8611], maxlen=5)
# deque([0.8529, 0.8515, 0.8496, 0.8545, 0.8551], maxlen=5)
# deque([0.8578, 0.8531, 0.8591, 0.8592, 0.8551], maxlen=5)
# deque([0.8509, 0.8474, 0.8594, 0.8544, 0.8524], maxlen=5)
# deque([0.8555, 0.8631, 0.857, 0.8551, 0.8541], maxlen=5)
# deque([0.8517, 0.8509, 0.8566, 0.8541, 0.8509], maxlen=5)
# deque([0.8544, 0.857, 0.8544, 0.8547, 0.8586], maxlen=5)
# Iteration: 175 	Best fly index: 1 	Fitness value: -0.85904 delta:  0.005 counter:  0
# deque([0.8571, 0.8576, 0.8573, 0.8548, 0.85], maxlen=5)
# deque([0.8579, 0.8583, 0.8593, 0.8593, 0.8558], maxlen=5)
# deque([0.851, 0.8574, 0.8583, 0.8587, 0.8594], maxlen=5)
# deque([0.856, 0.8521, 0.8589, 0.8611, 0.8551], maxlen=5)
# deque([0.8515, 0.8496, 0.8545, 0.8551, 0.8535], maxlen=5)
# deque([0.8531, 0.8591, 0.8592, 0.8551, 0.8588], maxlen=5)
# deque([0.8474, 0.8594, 0.8544, 0.8524, 0.8518], maxlen=5)
# deque([0.8631, 0.857, 0.8551, 0.8541, 0.8595], maxlen=5)
# deque([0.8509, 0.8566, 0.8541, 0.8509, 0.8629], maxlen=5)
# deque([0.857, 0.8544, 0.8547, 0.8586, 0.8541], maxlen=5)
# Iteration: 176 	Best fly index: 1 	Fitness value: -0.8581200000000001 delta:  0.005 counter:  0
# deque([0.8576, 0.8573, 0.8548, 0.85, 0.8527], maxlen=5)
# deque([0.8583, 0.8593, 0.8593, 0.8558, 0.8621], maxlen=5)
# deque([0.8574, 0.8583, 0.8587, 0.8594, 0.8559], maxlen=5)
# deque([0.8521, 0.8589, 0.8611, 0.8551, 0.858], maxlen=5)
# deque([0.8496, 0.8545, 0.8551, 0.8535, 0.8641], maxlen=5)
# deque([0.8591, 0.8592, 0.8551, 0.8588, 0.8633], maxlen=5)
# deque([0.8594, 0.8544, 0.8524, 0.8518, 0.8552], maxlen=5)
# deque([0.857, 0.8551, 0.8541, 0.8595, 0.8574], maxlen=5)
# deque([0.8566, 0.8541, 0.8509, 0.8629, 0.8555], maxlen=5)
# deque([0.8544, 0.8547, 0.8586, 0.8541, 0.8528], maxlen=5)
# Iteration: 177 	Best fly index: 5 	Fitness value: -0.8591 delta:  0.005 counter:  0
# deque([0.8573, 0.8548, 0.85, 0.8527, 0.856], maxlen=5)
# deque([0.8593, 0.8593, 0.8558, 0.8621, 0.8523], maxlen=5)
# deque([0.8583, 0.8587, 0.8594, 0.8559, 0.86], maxlen=5)
# deque([0.8589, 0.8611, 0.8551, 0.858, 0.8563], maxlen=5)
# deque([0.8545, 0.8551, 0.8535, 0.8641, 0.8556], maxlen=5)
# deque([0.8592, 0.8551, 0.8588, 0.8633, 0.8526], maxlen=5)
# deque([0.8544, 0.8524, 0.8518, 0.8552, 0.8528], maxlen=5)
# deque([0.8551, 0.8541, 0.8595, 0.8574, 0.8554], maxlen=5)
# deque([0.8541, 0.8509, 0.8629, 0.8555, 0.8596], maxlen=5)
# deque([0.8547, 0.8586, 0.8541, 0.8528, 0.855], maxlen=5)
# Iteration: 178 	Best fly index: 2 	Fitness value: -0.85846 delta:  0.005 counter:  0
# deque([0.8548, 0.85, 0.8527, 0.856, 0.8517], maxlen=5)
# deque([0.8593, 0.8558, 0.8621, 0.8523, 0.8561], maxlen=5)
# deque([0.8587, 0.8594, 0.8559, 0.86, 0.858], maxlen=5)
# deque([0.8611, 0.8551, 0.858, 0.8563, 0.854], maxlen=5)
# deque([0.8551, 0.8535, 0.8641, 0.8556, 0.8587], maxlen=5)
# deque([0.8551, 0.8588, 0.8633, 0.8526, 0.8579], maxlen=5)
# deque([0.8524, 0.8518, 0.8552, 0.8528, 0.8551], maxlen=5)
# deque([0.8541, 0.8595, 0.8574, 0.8554, 0.8497], maxlen=5)
# deque([0.8509, 0.8629, 0.8555, 0.8596, 0.8548], maxlen=5)
# deque([0.8586, 0.8541, 0.8528, 0.855, 0.8546], maxlen=5)
# Iteration: 179 	Best fly index: 2 	Fitness value: -0.8583999999999999 delta:  0.005 counter:  0
# deque([0.85, 0.8527, 0.856, 0.8517, 0.8596], maxlen=5)
# deque([0.8558, 0.8621, 0.8523, 0.8561, 0.8498], maxlen=5)
# deque([0.8594, 0.8559, 0.86, 0.858, 0.8606], maxlen=5)
# deque([0.8551, 0.858, 0.8563, 0.854, 0.8499], maxlen=5)
# deque([0.8535, 0.8641, 0.8556, 0.8587, 0.8566], maxlen=5)
# deque([0.8588, 0.8633, 0.8526, 0.8579, 0.855], maxlen=5)
# deque([0.8518, 0.8552, 0.8528, 0.8551, 0.8559], maxlen=5)
# deque([0.8595, 0.8574, 0.8554, 0.8497, 0.861], maxlen=5)
# deque([0.8629, 0.8555, 0.8596, 0.8548, 0.8478], maxlen=5)
# deque([0.8541, 0.8528, 0.855, 0.8546, 0.8582], maxlen=5)
# Iteration: 180 	Best fly index: 2 	Fitness value: -0.85878 delta:  0.005 counter:  0
# deque([0.8527, 0.856, 0.8517, 0.8596, 0.8562], maxlen=5)
# deque([0.8621, 0.8523, 0.8561, 0.8498, 0.8561], maxlen=5)
# deque([0.8559, 0.86, 0.858, 0.8606, 0.8582], maxlen=5)
# deque([0.858, 0.8563, 0.854, 0.8499, 0.8561], maxlen=5)
# deque([0.8641, 0.8556, 0.8587, 0.8566, 0.8554], maxlen=5)
# deque([0.8633, 0.8526, 0.8579, 0.855, 0.8594], maxlen=5)
# deque([0.8552, 0.8528, 0.8551, 0.8559, 0.853], maxlen=5)
# deque([0.8574, 0.8554, 0.8497, 0.861, 0.8591], maxlen=5)
# deque([0.8555, 0.8596, 0.8548, 0.8478, 0.8533], maxlen=5)
# deque([0.8528, 0.855, 0.8546, 0.8582, 0.8602], maxlen=5)
# Iteration: 181 	Best fly index: 2 	Fitness value: -0.85854 delta:  0.005 counter:  0
# deque([0.856, 0.8517, 0.8596, 0.8562, 0.8487], maxlen=5)
# deque([0.8523, 0.8561, 0.8498, 0.8561, 0.8549], maxlen=5)
# deque([0.86, 0.858, 0.8606, 0.8582, 0.8602], maxlen=5)
# deque([0.8563, 0.854, 0.8499, 0.8561, 0.8494], maxlen=5)
# deque([0.8556, 0.8587, 0.8566, 0.8554, 0.8483], maxlen=5)
# deque([0.8526, 0.8579, 0.855, 0.8594, 0.8568], maxlen=5)
# deque([0.8528, 0.8551, 0.8559, 0.853, 0.8559], maxlen=5)
# deque([0.8554, 0.8497, 0.861, 0.8591, 0.8561], maxlen=5)
# deque([0.8596, 0.8548, 0.8478, 0.8533, 0.8551], maxlen=5)
# deque([0.855, 0.8546, 0.8582, 0.8602, 0.8551], maxlen=5)
# Iteration: 182 	Best fly index: 2 	Fitness value: -0.8593999999999999 delta:  0.005 counter:  0
# deque([0.8517, 0.8596, 0.8562, 0.8487, 0.8594], maxlen=5)
# deque([0.8561, 0.8498, 0.8561, 0.8549, 0.8579], maxlen=5)
# deque([0.858, 0.8606, 0.8582, 0.8602, 0.8513], maxlen=5)
# deque([0.854, 0.8499, 0.8561, 0.8494, 0.8559], maxlen=5)
# deque([0.8587, 0.8566, 0.8554, 0.8483, 0.8545], maxlen=5)
# deque([0.8579, 0.855, 0.8594, 0.8568, 0.8477], maxlen=5)
# deque([0.8551, 0.8559, 0.853, 0.8559, 0.8577], maxlen=5)
# deque([0.8497, 0.861, 0.8591, 0.8561, 0.8557], maxlen=5)
# deque([0.8548, 0.8478, 0.8533, 0.8551, 0.8572], maxlen=5)
# deque([0.8546, 0.8582, 0.8602, 0.8551, 0.858], maxlen=5)
# Iteration: 183 	Best fly index: 2 	Fitness value: -0.8576599999999999 delta:  0.005 counter:  0
# deque([0.8596, 0.8562, 0.8487, 0.8594, 0.8521], maxlen=5)
# deque([0.8498, 0.8561, 0.8549, 0.8579, 0.8504], maxlen=5)
# deque([0.8606, 0.8582, 0.8602, 0.8513, 0.8589], maxlen=5)
# deque([0.8499, 0.8561, 0.8494, 0.8559, 0.8492], maxlen=5)
# deque([0.8566, 0.8554, 0.8483, 0.8545, 0.8555], maxlen=5)
# deque([0.855, 0.8594, 0.8568, 0.8477, 0.8591], maxlen=5)
# deque([0.8559, 0.853, 0.8559, 0.8577, 0.8553], maxlen=5)
# deque([0.861, 0.8591, 0.8561, 0.8557, 0.8555], maxlen=5)
# deque([0.8478, 0.8533, 0.8551, 0.8572, 0.8545], maxlen=5)
# deque([0.8582, 0.8602, 0.8551, 0.858, 0.8555], maxlen=5)
# Iteration: 184 	Best fly index: 2 	Fitness value: -0.85784 delta:  0.005 counter:  0
# deque([0.8562, 0.8487, 0.8594, 0.8521, 0.8662], maxlen=5)
# deque([0.8561, 0.8549, 0.8579, 0.8504, 0.8537], maxlen=5)
# deque([0.8582, 0.8602, 0.8513, 0.8589, 0.8559], maxlen=5)
# deque([0.8561, 0.8494, 0.8559, 0.8492, 0.8532], maxlen=5)
# deque([0.8554, 0.8483, 0.8545, 0.8555, 0.8596], maxlen=5)
# deque([0.8594, 0.8568, 0.8477, 0.8591, 0.8549], maxlen=5)
# deque([0.853, 0.8559, 0.8577, 0.8553, 0.8543], maxlen=5)
# deque([0.8591, 0.8561, 0.8557, 0.8555, 0.8522], maxlen=5)
# deque([0.8533, 0.8551, 0.8572, 0.8545, 0.8523], maxlen=5)
# deque([0.8602, 0.8551, 0.858, 0.8555, 0.8491], maxlen=5)
# Iteration: 185 	Best fly index: 2 	Fitness value: -0.8569000000000001 delta:  0.005 counter:  0
# deque([0.8487, 0.8594, 0.8521, 0.8662, 0.8507], maxlen=5)
# deque([0.8549, 0.8579, 0.8504, 0.8537, 0.861], maxlen=5)
# deque([0.8602, 0.8513, 0.8589, 0.8559, 0.856], maxlen=5)
# deque([0.8494, 0.8559, 0.8492, 0.8532, 0.8556], maxlen=5)
# deque([0.8483, 0.8545, 0.8555, 0.8596, 0.8589], maxlen=5)
# deque([0.8568, 0.8477, 0.8591, 0.8549, 0.849], maxlen=5)
# deque([0.8559, 0.8577, 0.8553, 0.8543, 0.8568], maxlen=5)
# deque([0.8561, 0.8557, 0.8555, 0.8522, 0.8512], maxlen=5)
# deque([0.8551, 0.8572, 0.8545, 0.8523, 0.855], maxlen=5)
# deque([0.8551, 0.858, 0.8555, 0.8491, 0.8553], maxlen=5)
# Iteration: 186 	Best fly index: 2 	Fitness value: -0.85646 delta:  0.005 counter:  0
# deque([0.8594, 0.8521, 0.8662, 0.8507, 0.861], maxlen=5)
# deque([0.8579, 0.8504, 0.8537, 0.861, 0.8564], maxlen=5)
# deque([0.8513, 0.8589, 0.8559, 0.856, 0.8612], maxlen=5)
# deque([0.8559, 0.8492, 0.8532, 0.8556, 0.8566], maxlen=5)
# deque([0.8545, 0.8555, 0.8596, 0.8589, 0.8603], maxlen=5)
# deque([0.8477, 0.8591, 0.8549, 0.849, 0.8551], maxlen=5)
# deque([0.8577, 0.8553, 0.8543, 0.8568, 0.8575], maxlen=5)
# deque([0.8557, 0.8555, 0.8522, 0.8512, 0.8571], maxlen=5)
# deque([0.8572, 0.8545, 0.8523, 0.855, 0.8572], maxlen=5)
# deque([0.858, 0.8555, 0.8491, 0.8553, 0.8582], maxlen=5)
# Iteration: 187 	Best fly index: 0 	Fitness value: -0.85788 delta:  0.005 counter:  0
# deque([0.8521, 0.8662, 0.8507, 0.861, 0.8576], maxlen=5)
# deque([0.8504, 0.8537, 0.861, 0.8564, 0.8609], maxlen=5)
# deque([0.8589, 0.8559, 0.856, 0.8612, 0.857], maxlen=5)
# deque([0.8492, 0.8532, 0.8556, 0.8566, 0.8592], maxlen=5)
# deque([0.8555, 0.8596, 0.8589, 0.8603, 0.851], maxlen=5)
# deque([0.8591, 0.8549, 0.849, 0.8551, 0.8548], maxlen=5)
# deque([0.8553, 0.8543, 0.8568, 0.8575, 0.8583], maxlen=5)
# deque([0.8555, 0.8522, 0.8512, 0.8571, 0.857], maxlen=5)
# deque([0.8545, 0.8523, 0.855, 0.8572, 0.8572], maxlen=5)
# deque([0.8555, 0.8491, 0.8553, 0.8582, 0.8539], maxlen=5)
# Iteration: 188 	Best fly index: 2 	Fitness value: -0.8577999999999999 delta:  0.005 counter:  0
# deque([0.8662, 0.8507, 0.861, 0.8576, 0.8577], maxlen=5)
# deque([0.8537, 0.861, 0.8564, 0.8609, 0.8579], maxlen=5)
# deque([0.8559, 0.856, 0.8612, 0.857, 0.8567], maxlen=5)
# deque([0.8532, 0.8556, 0.8566, 0.8592, 0.8553], maxlen=5)
# deque([0.8596, 0.8589, 0.8603, 0.851, 0.8571], maxlen=5)
# deque([0.8549, 0.849, 0.8551, 0.8548, 0.8569], maxlen=5)
# deque([0.8543, 0.8568, 0.8575, 0.8583, 0.8599], maxlen=5)
# deque([0.8522, 0.8512, 0.8571, 0.857, 0.8534], maxlen=5)
# deque([0.8523, 0.855, 0.8572, 0.8572, 0.8558], maxlen=5)
# deque([0.8491, 0.8553, 0.8582, 0.8539, 0.8612], maxlen=5)
# Iteration: 189 	Best fly index: 0 	Fitness value: -0.85864 delta:  0.005 counter:  0
# deque([0.8507, 0.861, 0.8576, 0.8577, 0.8551], maxlen=5)
# deque([0.861, 0.8564, 0.8609, 0.8579, 0.8568], maxlen=5)
# deque([0.856, 0.8612, 0.857, 0.8567, 0.8574], maxlen=5)
# deque([0.8556, 0.8566, 0.8592, 0.8553, 0.8538], maxlen=5)
# deque([0.8589, 0.8603, 0.851, 0.8571, 0.8594], maxlen=5)
# deque([0.849, 0.8551, 0.8548, 0.8569, 0.8545], maxlen=5)
# deque([0.8568, 0.8575, 0.8583, 0.8599, 0.8586], maxlen=5)
# deque([0.8512, 0.8571, 0.857, 0.8534, 0.8539], maxlen=5)
# deque([0.855, 0.8572, 0.8572, 0.8558, 0.848], maxlen=5)
# deque([0.8553, 0.8582, 0.8539, 0.8612, 0.8584], maxlen=5)
# Iteration: 190 	Best fly index: 1 	Fitness value: -0.8586 delta:  0.005 counter:  0
# deque([0.861, 0.8576, 0.8577, 0.8551, 0.8587], maxlen=5)
# deque([0.8564, 0.8609, 0.8579, 0.8568, 0.8571], maxlen=5)
# deque([0.8612, 0.857, 0.8567, 0.8574, 0.8536], maxlen=5)
# deque([0.8566, 0.8592, 0.8553, 0.8538, 0.8548], maxlen=5)
# deque([0.8603, 0.851, 0.8571, 0.8594, 0.8525], maxlen=5)
# deque([0.8551, 0.8548, 0.8569, 0.8545, 0.8574], maxlen=5)
# deque([0.8575, 0.8583, 0.8599, 0.8586, 0.8561], maxlen=5)
# deque([0.8571, 0.857, 0.8534, 0.8539, 0.85], maxlen=5)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 newweihgts = DFO(flies)
#
# Cell In[13], line 11, in DFO(start_flies)
#       9 for itr in range (maxIterations):
#      10 	for i in range(N): # EVALUATION --- 10 needs to be the population size
# ---> 11 		fitness[i] = f(X[i], flies_history[i])
#      12 	s = np.argmin(fitness) # FIND BEST FLY
#      17 	#fitness_history.append(fitness[s])
#      18 	#delta_history.append(delta)
#
# Cell In[5], line 36, in f(fly, flies_history, model, env)
#      33 done = False
#      35 while not done:
# ---> 36     state_encoded = encode_state(np.array([state]), env.observation_space.n)
#      37     action_mask = get_mask(info, n_actions=env.action_space.n)
#      39     with torch.no_grad():
#
# Cell In[1], line 19, in encode_state(obs, n_states)
#      17 def encode_state(obs, n_states):  # Modified to take n_states as parameter
#      18     obs = torch.Tensor(obs)
# ---> 19     return nn.functional.one_hot(obs.long(), n_states).float()
#
# KeyboardInterrupt:

# %%
np.save('realbest_fly_weights.npy', newweihgts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 np.save('realbest_fly_weights.npy', newweihgts)
#
# NameError: name 'newweihgts' is not defined
