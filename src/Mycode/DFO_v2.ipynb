# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.3

# %%
import os
import sys
# Add the root directory to Python path
root_dir = "C:\\Users\\Jordan Lankford\\Documents\\GitHub\\FineTune-DQN"
if root_dir not in sys.path:
    sys.path.append(root_dir)

# Now imports should work
from src.utils.utils import set_seeds
import torch
import torch.nn as nn
import gymnasium as gym
import numpy as np
from src.utils.utils import set_seeds
from torchsummary import summary

def encode_state(obs, n_states):
    obs = torch.Tensor(obs)
    return nn.functional.one_hot(obs.long(), n_states).float()

def get_mask(info, n_actions=25):
    allowed_actions = info['admissible_actions']
    mask = np.zeros(n_actions)
    mask[allowed_actions] = 1
    return torch.Tensor(mask).unsqueeze(0)

# Modified QNetwork to match the deep DQN structure
class QNetwork(nn.Module):
    def __init__(self, env):
        super().__init__()
        self.n_states = env.observation_space.n
        self.n_actions = env.action_space.n
        
        # Match the architecture of the deep DQN
        self.network = nn.Sequential(
            nn.Linear(self.n_states, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, self.n_actions)
        )

    def forward(self, x, action_masks=None):
        q_values = self.network(x)
        if action_masks is not None:
            q_values = q_values - ((1 - action_masks) * 1e10)
        return q_values

# Create environment and network
env = gym.make('Sepsis/ICU-Sepsis-v2')
q_network = QNetwork(env)

# Load the trained deep DQN weights
model_path = r"C:\Users\Jordan Lankford\Documents\GitHub\FineTune-DQN\models\dqn\dqn_final_seed_0.pt"
state_dict = torch.load(model_path)

# Print the keys in the state dict to verify structure
print("State dict keys:", state_dict.keys())

# Load the weights
try:
    q_network.load_state_dict(state_dict)
    print("Successfully loaded weights!")
except Exception as e:
    print(f"Error loading weights: {e}")
    # Try loading with strict=False if there are issues
    q_network.load_state_dict(state_dict, strict=False)
    print("Loaded weights with strict=False")

# Print model structure
print("\nModel Architecture:")
print(q_network)
# Out:
# State dict keys: odict_keys(['network.0.weight', 'network.0.bias', 'network.2.weight', 'network.2.bias', 'network.4.weight', 'network.4.bias'])
# Successfully loaded weights!
#
# Model Architecture:
# QNetwork(
#   (network): Sequential(
#     (0): Linear(in_features=716, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=25, bias=True)
#   )
# )
# C:\Users\Jordan Lankford\AppData\Local\Temp\ipykernel_18660\2027990685.py:55: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_path)

# %%
weight_shapes = []
for param in q_network.parameters():
    weight_shapes.append(param.shape)
print(weight_shapes)
# Out:
# [torch.Size([128, 716]), torch.Size([128]), torch.Size([128, 128]), torch.Size([128]), torch.Size([25, 128]), torch.Size([25])]

# %%
values_in_dimension=[]
for shape in weight_shapes:
    values_in_dimension.append(np.prod(shape))
print(values_in_dimension)
# Out:
# [np.int64(91648), np.int64(128), np.int64(16384), np.int64(128), np.int64(3200), np.int64(25)]

# %%
weights = [param.detach().numpy() for param in q_network.parameters()]  # Get all model weights as numpy arrays

# %%
import torch
import torch.nn as nn
import numpy as np
import gymnasium as gym
from torchsummary import summary



def f(fly, flies_history = None, model=q_network,env=env):
    
    cloned_model = q_network
    
    # Reshape fly's weights to match the model's weight shape
    reshaped_fly = reshape_to_model_weights(fly, model)
    
    # Load the reshaped weights into the cloned model
    cloned_model.load_state_dict(dict(zip([name for name, _ in cloned_model.named_parameters()], reshaped_fly)))

    # Set the model to evaluation mode
    cloned_model.eval()

    # Run the evaluation (similar to what is done in evaluate_network)
    episode_rewards = []
    episode_lengths = []
    
    num_episodes = 20000  # or any other number you'd like to test  USE 10000 FOR STABAL ISH
    for episode in range(num_episodes):
        state, info = env.reset()
        episode_reward = 0
        steps = 0
        done = False
        
        while not done:
            state_encoded = encode_state(np.array([state]), env.observation_space.n)
            action_mask = get_mask(info, n_actions=env.action_space.n)
            
            with torch.no_grad():
                q_values = cloned_model(state_encoded, action_mask)
                action = torch.argmax(q_values).item()
            
            next_state, reward, terminated, truncated, info = env.step(action)
            episode_reward += reward
            steps += 1
            state = next_state
            done = terminated or truncated

        episode_rewards.append(episode_reward)
        episode_lengths.append(steps)
    

    fitness = np.mean(episode_rewards)
    # Return the average reward (or any other metric you want)
    return -f_avrg(fitness, flies_history)
    #return -fitness

# %%
#run fly through the fitness function 20 times, calculate the range in fitness values

#f(fly, flies_history = None, model=q_network,env=env)
fitness_values = []
for i in range(20):
    fitness_values.append(f(flies[0], flies_history = None, model=q_network,env=env))

print(fitness_values)
#range of fitness values
range_fitness = max(fitness_values) - min(fitness_values)
print(range_fitness)
# Out:
# [np.float64(-0.8124), np.float64(-0.8074), np.float64(-0.81455), np.float64(-0.80705), np.float64(-0.8125), np.float64(-0.8096), np.float64(-0.80815), np.float64(-0.8064), np.float64(-0.80905), np.float64(-0.8143), np.float64(-0.81195), np.float64(-0.8096), np.float64(-0.80975), np.float64(-0.81325), np.float64(-0.8111), np.float64(-0.80875), np.float64(-0.80945), np.float64(-0.8159), np.float64(-0.8128), np.float64(-0.8118)]
# 0.009499999999999953

# %%
#standard deviation of fitness values
std_fitness = np.std(fitness_values)
print(std_fitness)
#mean of fitness values
mean_fitness = np.mean(fitness_values)
print(mean_fitness)
# Out:
# 0.002600570850794101
# -0.8107875

# %%
for i in range(20):
    #take the firtst ith number of flies and caluculate mean fitness
    mean_fitness = np.mean(fitness_values[:i])
    print("mean when using", i ,"flies:", mean_fitness)
# Out:
# mean when using 0 flies: nan
# mean when using 1 flies: -0.8124
# mean when using 2 flies: -0.8099000000000001
# mean when using 3 flies: -0.8114500000000001
# mean when using 4 flies: -0.8103500000000001
# mean when using 5 flies: -0.8107800000000001
# mean when using 6 flies: -0.8105833333333333
# mean when using 7 flies: -0.8102357142857144
# mean when using 8 flies: -0.80975625
# mean when using 9 flies: -0.8096777777777777
# mean when using 10 flies: -0.81014
# mean when using 11 flies: -0.8103045454545454
# mean when using 12 flies: -0.8102458333333332
# mean when using 13 flies: -0.8102076923076922
# mean when using 14 flies: -0.8104249999999998
# mean when using 15 flies: -0.8104699999999999
# mean when using 16 flies: -0.8103625
# mean when using 17 flies: -0.8103088235294118
# mean when using 18 flies: -0.8106194444444443
# mean when using 19 flies: -0.8107342105263157
# C:\Users\Jordan Lankford\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\_core\fromnumeric.py:3904: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\Jordan Lankford\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\_core\_methods.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
'''
from parallel_fitness import parallel_fitness, QNetwork
import time 

def f_parallel(fly, model=q_network, num_processes=4):
    """
    Wrapper for parallel fitness evaluation
    """
    reshaped_fly = reshape_to_model_weights(fly, model)
    state_dict = dict(zip([name for name, _ in model.named_parameters()], reshaped_fly))
    return parallel_fitness(state_dict, num_processes=num_processes)


# Compare performance
print("Testing sequential evaluation:")
start = time.perf_counter()
result_seq = f(flies[0])
time_seq = time.perf_counter() - start
print(f"Sequential result: {result_seq}")
print(f"Sequential time: {time_seq:.2f}s")

print("\nTesting parallel evaluation:")
start = time.perf_counter()
result_par = f_parallel(flies[0], num_processes=4)
time_par = time.perf_counter() - start
print(f"Parallel result: {result_par}")
print(f"Parallel time: {time_par:.2f}s")

print(f"\nSpeedup: {time_seq/time_par:.2f}x")'
'''
# Out:
# Testing sequential evaluation:
# Sequential result: -0.809
# Sequential time: 33.63s
#
# Testing parallel evaluation:
# Evaluated 10000 episodes in 50.38 seconds
# Parallel result: -0.8062
# Parallel time: 50.39s
#
# Speedup: 0.67x

# %%
'''
from vectorized_fitness import vectorized_fitness, QNetwork
import time

def f_vectorized(fly, model=q_network, num_envs=4):
    """
    Wrapper for vectorized fitness evaluation
    """
    reshaped_fly = reshape_to_model_weights(fly, model)
    state_dict = dict(zip([name for name, _ in model.named_parameters()], reshaped_fly))
    return vectorized_fitness(state_dict, num_envs=num_envs)

# Test code


print("\nTesting vectorized evaluation:")
start = time.perf_counter()
result_vec = f_vectorized(flies[0], num_envs=4)
time_vec = time.perf_counter() - start
print(f"Vectorized result: {result_vec}")
print(f"Vectorized time: {time_vec:.2f}s")


print("Testing sequential evaluation:")
start = time.perf_counter()
result_seq = f(flies[0])
time_seq = time.perf_counter() - start
print(f"Sequential result: {result_seq}")
print(f"Sequential time: {time_seq:.2f}s")

print(f"\nSpeedup: {time_seq/time_vec:.2f}x")'
'''
# Out:
# Testing vectorized evaluation:
# Evaluated 1068 episodes in 2.43 seconds
# Vectorized result: -0.0
# Vectorized time: 3.88s
# Testing sequential evaluation:
# Sequential result: -0.8124
# Sequential time: 37.90s
#
# Speedup: 9.77x

# %%
def reshape_to_model_weights(flattened_fly, model=q_network):
    # List to store reshaped weights
    reshaped_weights = []
    counter = 0  # Counter for elements in fly
    
    # Get the shapes of the model's parameters
    values_in_dimension = [param.numel() for param in model.parameters()]
    weight_shapes = [param.shape for param in model.parameters()]
    
    for i in range(len(values_in_dimension)):
        # Get the flattened weights for this layer
        weight_flat = flattened_fly[counter: counter + values_in_dimension[i]]
        
        # Reshape and convert to torch.Tensor
        reshaped_layer_weights = torch.tensor(weight_flat, dtype=torch.float32).reshape(weight_shapes[i])
        
        # Append the reshaped weight to the list
        reshaped_weights.append(reshaped_layer_weights)
        
        # Move the counter to the next parameter block
        counter += values_in_dimension[i]
    
    return reshaped_weights

# %%
def initialize_flies_from_model(number_of_flies, weights, model, inclusive):
    population = []

    if inclusive == False:
        for i in range(number_of_flies):
            fly = []  # This will hold the flattened weights for a single fly
            
            for param in model.parameters():  # Iterate through model parameters (weights and biases)
                # Generate random weights with the same shape as the model's weight matrix
                scalers = np.random.uniform(0.9, 1.1, size=param.shape)
                print(param.shape)  # Print the shape to see what the weights look like
                scaledweights = param.detach().numpy() * scalers  # Multiply the weight values by the scalers
                
                # Flatten the random weights and add them to the fly
                flattened_weights = scaledweights.flatten()
                fly.append(flattened_weights)
            
            # After flattening each layer's weights, flatten the entire fly and add to population
            population.append(np.concatenate(fly))  # Concatenate the list of flattened weight arrays
            
    if inclusive == True:
        for i in range(number_of_flies):
            fly = []  # This will hold the flattened weights for a single fly
            
            for param in model.parameters():  # Iterate through model parameters (weights and biases)
                if i == 0:
                    flattened_weights = param.detach().numpy().flatten()  # Get the flattened weights for the first fly
                    fly.append(flattened_weights)
                else:
                    scalers = np.random.uniform(0.9, 1.1, size=param.shape)
                    print(param.shape)  # Print the shape to see what the weights look like
                    scaledweights = param.detach().numpy() * scalers  # Multiply the weight values by the scalers
                    
                    # Flatten the random weights and add them to the fly
                    flattened_weights = scaledweights.flatten()
                    fly.append(flattened_weights)
                
            # After flattening each layer's weights, flatten the entire fly and add to population
            population.append(np.concatenate(fly))  # Concatenate the list of flattened weight arrays
        
    return population

# %%
num_of_flies = 10

flies = initialize_flies_from_model(num_of_flies,weights,q_network,True)



from collections import deque
max_history = 5
flies_history = [deque(maxlen=max_history) for _ in range(num_of_flies)]
# Out:
# torch.Size([128, 716])
# torch.Size([128])
# torch.Size([128, 128])
# torch.Size([128])
# torch.Size([25, 128])
# torch.Size([25])
# torch.Size([128, 716])
# torch.Size([128])
# torch.Size([128, 128])
# torch.Size([128])
# torch.Size([25, 128])
# torch.Size([25])
# torch.Size([128, 716])
# torch.Size([128])
# torch.Size([128, 128])
# torch.Size([128])
# torch.Size([25, 128])
# torch.Size([25])
# torch.Size([128, 716])
# torch.Size([128])
# torch.Size([128, 128])
# torch.Size([128])
# torch.Size([25, 128])
# torch.Size([25])
# torch.Size([128, 716])
# torch.Size([128])
# torch.Size([128, 128])
# torch.Size([128])
# torch.Size([25, 128])
# torch.Size([25])
# torch.Size([128, 716])
# torch.Size([128])
# torch.Size([128, 128])
# torch.Size([128])
# torch.Size([25, 128])
# torch.Size([25])
# torch.Size([128, 716])
# torch.Size([128])
# torch.Size([128, 128])
# torch.Size([128])
# torch.Size([25, 128])
# torch.Size([25])
# torch.Size([128, 716])
# torch.Size([128])
# torch.Size([128, 128])
# torch.Size([128])
# torch.Size([25, 128])
# torch.Size([25])
# torch.Size([128, 716])
# torch.Size([128])
# torch.Size([128, 128])
# torch.Size([128])
# torch.Size([25, 128])
# torch.Size([25])

# %%
print(flies_history[0])
# Out:
# deque([], maxlen=5)

# %%
def f_avrg(fitness, flies_history):

    flies_history.append(fitness)

    print(flies_history)

    return sum(flies_history) / len(flies_history) # mean

# %%
f(flies[0],flies_history[0])

# %%
len(flies[0])

# %%
N = len(flies)			# POPULATION SIZE
D = len(flies[0])					# DIMENSIONALITY 
delta = 0.005			# DISTURBANCE THRESHOLD 
maxIterations = 200	# ITERATIONS ALLOWED
sd = np.std(flies[0])		# STANDARD DEVIATION

# %%
#print the min and max values and the range of the initial population
min_value = np.min(flies[0])
max_value = np.max(flies[0])
range_value = max_value - min_value
print("Initial Population:")
print("Min:", min_value)
print("Max:", max_value)
print("Range:", range_value)
sd = np.std(flies[0])
print("Standard Deviation:", sd)
median = np.median(flies[0])
print("Median:", median)
# Out:
# Initial Population:
# Min: -4.9936833
# Max: 4.964795
# Range: 9.958479
# Standard Deviation: 0.1878362
# Median: 0.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 13
#      11 median = np.median(flies[0])
#      12 print("Median:", median)
# ---> 13 mode = np.mode(flies[0])
#      14 print("Mode:", mode)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\__init__.py:428, in __getattr__(attr)
#     425     import numpy.char as char
#     426     return char.chararray
# --> 428 raise AttributeError("module {!r} has no attribute "
#     429                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'mode'

# %%
def DFO(start_flies):
    """
    DFO with initial history population phase
    """
    X = np.array(start_flies)     
    fitness = np.zeros(N)         
    flies_history = [deque(maxlen=5) for _ in range(N)]

    # First phase: Populate histories for all flies
    print("Populating initial histories...")
    for _ in range(max_history):  # Run evaluations to fill histories
        for i in range(N):
            fitness[i] = f(X[i], flies_history[i])
            print(f"Fly {i} history: {list(flies_history[i])}")
    
    # # Now all flies have full histories, start optimization
    s = np.argmin(fitness)
    print(f"\nStarting optimization with best fly: {s}, fitness: {fitness[s]:.3f}")
    
    # Main DFO loop
    for itr in range(maxIterations):
        # Recalculate best fly's fitness
        best_fly_fitness = f(X[s], flies_history[s])
        fitness[s] = best_fly_fitness
        
        print(f"\nIteration: {itr}")
        print(f"Best fly {s} recalculated fitness: {fitness[s]:.3f}")
        print(f"Best fly history: {list(flies_history[s])}")

        for i in range(N):
            if i == s:
                continue

            left = (i-1) % N
            right = (i+1) % N
            bNeighbour = right if fitness[right] < fitness[left] else left

            old_position = X[i].copy()
            old_fitness = fitness[i]

            U = np.random.uniform(0, 1, D)
            R = np.random.uniform(0, 1, D)
            X[i] = np.where(R < delta,
                           np.random.normal(loc=X[i], scale=sd), #Change to scale=sd, rather than delta
                           X[bNeighbour] + U * (X[s] - X[i])) # MADE BOTH RESSART AND NORMAL USE THE CURRENT FLY RATHER THAN FORCING SELFLESS UPDATE

            new_fitness = f(X[i], flies_history[i])
            
            if new_fitness < old_fitness:
                fitness[i] = new_fitness
                if new_fitness < fitness[s]:
                    s = i
                    print(f"New best found! Fly {i}: {new_fitness:.3f}")
                    print(f"New best history: {list(flies_history[i])}")
            else:
                X[i] = old_position
                fitness[i] = old_fitness

        # After all flies updated, recheck who is best
        s = np.argmin(fitness)
        print(f"End of iteration best fly: {s} with fitness: {fitness[s]:.3f}")
        print(f"Best fly history: {list(flies_history[s])}")

    return X[s]

# %%
newweihgts = DFO(flies)
# Out:
# Populating initial histories...
# deque([np.float64(0.81405)], maxlen=5)
# Fly 0 history: [np.float64(0.81405)]
# deque([np.float64(0.81275)], maxlen=5)
# Fly 1 history: [np.float64(0.81275)]
# deque([np.float64(0.8044)], maxlen=5)
# Fly 2 history: [np.float64(0.8044)]
# deque([np.float64(0.8016)], maxlen=5)
# Fly 3 history: [np.float64(0.8016)]
# deque([np.float64(0.8114)], maxlen=5)
# Fly 4 history: [np.float64(0.8114)]
# deque([np.float64(0.80785)], maxlen=5)
# Fly 5 history: [np.float64(0.80785)]
# deque([np.float64(0.80605)], maxlen=5)
# Fly 6 history: [np.float64(0.80605)]
# deque([np.float64(0.79835)], maxlen=5)
# Fly 7 history: [np.float64(0.79835)]
# deque([np.float64(0.79525)], maxlen=5)
# Fly 8 history: [np.float64(0.79525)]
# deque([np.float64(0.8112)], maxlen=5)
# Fly 9 history: [np.float64(0.8112)]
# deque([np.float64(0.81405), np.float64(0.8114)], maxlen=5)
# Fly 0 history: [np.float64(0.81405), np.float64(0.8114)]
# deque([np.float64(0.81275), np.float64(0.80415)], maxlen=5)
# Fly 1 history: [np.float64(0.81275), np.float64(0.80415)]
# deque([np.float64(0.8044), np.float64(0.8035)], maxlen=5)
# Fly 2 history: [np.float64(0.8044), np.float64(0.8035)]
# deque([np.float64(0.8016), np.float64(0.80105)], maxlen=5)
# Fly 3 history: [np.float64(0.8016), np.float64(0.80105)]
# deque([np.float64(0.8114), np.float64(0.8087)], maxlen=5)
# Fly 4 history: [np.float64(0.8114), np.float64(0.8087)]
# deque([np.float64(0.80785), np.float64(0.80875)], maxlen=5)
# Fly 5 history: [np.float64(0.80785), np.float64(0.80875)]
# deque([np.float64(0.80605), np.float64(0.81135)], maxlen=5)
# Fly 6 history: [np.float64(0.80605), np.float64(0.81135)]
# deque([np.float64(0.79835), np.float64(0.79855)], maxlen=5)
# Fly 7 history: [np.float64(0.79835), np.float64(0.79855)]
# deque([np.float64(0.79525), np.float64(0.7973)], maxlen=5)
# Fly 8 history: [np.float64(0.79525), np.float64(0.7973)]
# deque([np.float64(0.8112), np.float64(0.8101)], maxlen=5)
# Fly 9 history: [np.float64(0.8112), np.float64(0.8101)]
# deque([np.float64(0.81405), np.float64(0.8114), np.float64(0.8141)], maxlen=5)
# Fly 0 history: [np.float64(0.81405), np.float64(0.8114), np.float64(0.8141)]
# deque([np.float64(0.81275), np.float64(0.80415), np.float64(0.81015)], maxlen=5)
# Fly 1 history: [np.float64(0.81275), np.float64(0.80415), np.float64(0.81015)]
# deque([np.float64(0.8044), np.float64(0.8035), np.float64(0.801)], maxlen=5)
# Fly 2 history: [np.float64(0.8044), np.float64(0.8035), np.float64(0.801)]
# deque([np.float64(0.8016), np.float64(0.80105), np.float64(0.8049)], maxlen=5)
# Fly 3 history: [np.float64(0.8016), np.float64(0.80105), np.float64(0.8049)]
# deque([np.float64(0.8114), np.float64(0.8087), np.float64(0.8055)], maxlen=5)
# Fly 4 history: [np.float64(0.8114), np.float64(0.8087), np.float64(0.8055)]
# deque([np.float64(0.80785), np.float64(0.80875), np.float64(0.802)], maxlen=5)
# Fly 5 history: [np.float64(0.80785), np.float64(0.80875), np.float64(0.802)]
# deque([np.float64(0.80605), np.float64(0.81135), np.float64(0.81185)], maxlen=5)
# deque([np.float64(0.8073), np.float64(0.80715), np.float64(0.8083), np.float64(0.8137), np.float64(0.80955)], maxlen=5)
# deque([np.float64(0.8057), np.float64(0.8097), np.float64(0.80565), np.float64(0.80705), np.float64(0.80445)], maxlen=5)
# deque([np.float64(0.8073), np.float64(0.8132), np.float64(0.82045), np.float64(0.80765), np.float64(0.8081)], maxlen=5)
# deque([np.float64(0.8098), np.float64(0.809), np.float64(0.80685), np.float64(0.81315), np.float64(0.8084)], maxlen=5)
# End of iteration best fly: 8 with fitness: -0.813
# Best fly history: [np.float64(0.81635), np.float64(0.8122), np.float64(0.81305), np.float64(0.8124), np.float64(0.8103)]
# deque([np.float64(0.8122), np.float64(0.81305), np.float64(0.8124), np.float64(0.8103), np.float64(0.809)], maxlen=5)
#
# Iteration: 10
# Best fly 8 recalculated fitness: -0.811
# Best fly history: [np.float64(0.8122), np.float64(0.81305), np.float64(0.8124), np.float64(0.8103), np.float64(0.809)]
# deque([np.float64(0.80115), np.float64(0.80415), np.float64(0.80905), np.float64(0.80915), np.float64(0.80915)], maxlen=5)
# deque([np.float64(0.8143), np.float64(0.80835), np.float64(0.81415), np.float64(0.80725), np.float64(0.81235)], maxlen=5)
# deque([np.float64(0.8068), np.float64(0.81315), np.float64(0.8068), np.float64(0.8145), np.float64(0.8136)], maxlen=5)
# deque([np.float64(0.80595), np.float64(0.8088), np.float64(0.8129), np.float64(0.80705), np.float64(0.81505)], maxlen=5)
# deque([np.float64(0.81255), np.float64(0.81125), np.float64(0.81055), np.float64(0.8109), np.float64(0.813)], maxlen=5)
# New best found! Fly 4: -0.812
# New best history: [np.float64(0.81255), np.float64(0.81125), np.float64(0.81055), np.float64(0.8109), np.float64(0.813)]
# deque([np.float64(0.80715), np.float64(0.8083), np.float64(0.8137), np.float64(0.80955), np.float64(0.81395)], maxlen=5)
# deque([np.float64(0.8097), np.float64(0.80565), np.float64(0.80705), np.float64(0.80445), np.float64(0.7996)], maxlen=5)
# deque([np.float64(0.8132), np.float64(0.82045), np.float64(0.80765), np.float64(0.8081), np.float64(0.8102)], maxlen=5)
# New best found! Fly 7: -0.812
# New best history: [np.float64(0.8132), np.float64(0.82045), np.float64(0.80765), np.float64(0.8081), np.float64(0.8102)]
# deque([np.float64(0.81305), np.float64(0.8124), np.float64(0.8103), np.float64(0.809), np.float64(0.8103)], maxlen=5)
# deque([np.float64(0.809), np.float64(0.80685), np.float64(0.81315), np.float64(0.8084), np.float64(0.80565)], maxlen=5)
# End of iteration best fly: 7 with fitness: -0.812
# Best fly history: [np.float64(0.8132), np.float64(0.82045), np.float64(0.80765), np.float64(0.8081), np.float64(0.8102)]
# deque([np.float64(0.82045), np.float64(0.80765), np.float64(0.8081), np.float64(0.8102), np.float64(0.81115)], maxlen=5)
#
# Iteration: 11
# Best fly 7 recalculated fitness: -0.812
# Best fly history: [np.float64(0.82045), np.float64(0.80765), np.float64(0.8081), np.float64(0.8102), np.float64(0.81115)]
# deque([np.float64(0.80415), np.float64(0.80905), np.float64(0.80915), np.float64(0.80915), np.float64(0.80245)], maxlen=5)
# deque([np.float64(0.80835), np.float64(0.81415), np.float64(0.80725), np.float64(0.81235), np.float64(0.81165)], maxlen=5)
# deque([np.float64(0.81315), np.float64(0.8068), np.float64(0.8145), np.float64(0.8136), np.float64(0.8105)], maxlen=5)
# New best found! Fly 2: -0.812
# New best history: [np.float64(0.81315), np.float64(0.8068), np.float64(0.8145), np.float64(0.8136), np.float64(0.8105)]
# deque([np.float64(0.8088), np.float64(0.8129), np.float64(0.80705), np.float64(0.81505), np.float64(0.8019)], maxlen=5)
# deque([np.float64(0.81125), np.float64(0.81055), np.float64(0.8109), np.float64(0.813), np.float64(0.8114)], maxlen=5)
# deque([np.float64(0.8083), np.float64(0.8137), np.float64(0.80955), np.float64(0.81395), np.float64(0.80275)], maxlen=5)
# deque([np.float64(0.80565), np.float64(0.80705), np.float64(0.80445), np.float64(0.7996), np.float64(0.80515)], maxlen=5)
# deque([np.float64(0.80765), np.float64(0.8081), np.float64(0.8102), np.float64(0.81115), np.float64(0.80875)], maxlen=5)
# deque([np.float64(0.8124), np.float64(0.8103), np.float64(0.809), np.float64(0.8103), np.float64(0.8119)], maxlen=5)
# deque([np.float64(0.80685), np.float64(0.81315), np.float64(0.8084), np.float64(0.80565), np.float64(0.8085)], maxlen=5)
# End of iteration best fly: 2 with fitness: -0.812
# Best fly history: [np.float64(0.81315), np.float64(0.8068), np.float64(0.8145), np.float64(0.8136), np.float64(0.8105)]
# deque([np.float64(0.8068), np.float64(0.8145), np.float64(0.8136), np.float64(0.8105), np.float64(0.81185)], maxlen=5)
#
# Iteration: 12
# Best fly 2 recalculated fitness: -0.811
# Best fly history: [np.float64(0.8068), np.float64(0.8145), np.float64(0.8136), np.float64(0.8105), np.float64(0.81185)]
# deque([np.float64(0.80905), np.float64(0.80915), np.float64(0.80915), np.float64(0.80245), np.float64(0.8098)], maxlen=5)
# deque([np.float64(0.81415), np.float64(0.80725), np.float64(0.81235), np.float64(0.81165), np.float64(0.80545)], maxlen=5)
# deque([np.float64(0.8129), np.float64(0.80705), np.float64(0.81505), np.float64(0.8019), np.float64(0.8112)], maxlen=5)
# deque([np.float64(0.81055), np.float64(0.8109), np.float64(0.813), np.float64(0.8114), np.float64(0.8111)], maxlen=5)
# deque([np.float64(0.8137), np.float64(0.80955), np.float64(0.81395), np.float64(0.80275), np.float64(0.80435)], maxlen=5)
# deque([np.float64(0.80705), np.float64(0.80445), np.float64(0.7996), np.float64(0.80515), np.float64(0.7935)], maxlen=5)
# deque([np.float64(0.8081), np.float64(0.8102), np.float64(0.81115), np.float64(0.80875), np.float64(0.8061)], maxlen=5)
# deque([np.float64(0.8103), np.float64(0.809), np.float64(0.8103), np.float64(0.8119), np.float64(0.8133)], maxlen=5)
# deque([np.float64(0.81315), np.float64(0.8084), np.float64(0.80565), np.float64(0.8085), np.float64(0.8075)], maxlen=5)
# End of iteration best fly: 4 with fitness: -0.812
# deque([np.float64(0.80565), np.float64(0.8085), np.float64(0.8075), np.float64(0.8032), np.float64(0.81325)], maxlen=5)
# End of iteration best fly: 4 with fitness: -0.813
# Best fly history: [np.float64(0.813), np.float64(0.8114), np.float64(0.8111), np.float64(0.81235), np.float64(0.81665)]
# deque([np.float64(0.8114), np.float64(0.8111), np.float64(0.81235), np.float64(0.81665), np.float64(0.80695)], maxlen=5)
#
# Iteration: 15
# Best fly 4 recalculated fitness: -0.812
# Best fly history: [np.float64(0.8114), np.float64(0.8111), np.float64(0.81235), np.float64(0.81665), np.float64(0.80695)]
# deque([np.float64(0.80245), np.float64(0.8098), np.float64(0.8099), np.float64(0.8083), np.float64(0.80355)], maxlen=5)
# deque([np.float64(0.81165), np.float64(0.80545), np.float64(0.804), np.float64(0.806), np.float64(0.804)], maxlen=5)
# deque([np.float64(0.8105), np.float64(0.81185), np.float64(0.80765), np.float64(0.81565), np.float64(0.807)], maxlen=5)
# deque([np.float64(0.8019), np.float64(0.8112), np.float64(0.8119), np.float64(0.81185), np.float64(0.80215)], maxlen=5)
# deque([np.float64(0.80275), np.float64(0.80435), np.float64(0.8085), np.float64(0.80475), np.float64(0.8095)], maxlen=5)
# deque([np.float64(0.80515), np.float64(0.7935), np.float64(0.80965), np.float64(0.79865), np.float64(0.8064)], maxlen=5)
# deque([np.float64(0.80875), np.float64(0.8061), np.float64(0.81095), np.float64(0.81325), np.float64(0.8121)], maxlen=5)
# deque([np.float64(0.8119), np.float64(0.8133), np.float64(0.8078), np.float64(0.81275), np.float64(0.8092)], maxlen=5)
# deque([np.float64(0.8085), np.float64(0.8075), np.float64(0.8032), np.float64(0.81325), np.float64(0.81625)], maxlen=5)
# End of iteration best fly: 2 with fitness: -0.812
# Best fly history: [np.float64(0.8105), np.float64(0.81185), np.float64(0.80765), np.float64(0.81565), np.float64(0.807)]
# deque([np.float64(0.81185), np.float64(0.80765), np.float64(0.81565), np.float64(0.807), np.float64(0.80975)], maxlen=5)
#
# Iteration: 16
# Best fly 2 recalculated fitness: -0.810
# Best fly history: [np.float64(0.81185), np.float64(0.80765), np.float64(0.81565), np.float64(0.807), np.float64(0.80975)]
# deque([np.float64(0.8098), np.float64(0.8099), np.float64(0.8083), np.float64(0.80355), np.float64(0.80375)], maxlen=5)
# deque([np.float64(0.80545), np.float64(0.804), np.float64(0.806), np.float64(0.804), np.float64(0.79975)], maxlen=5)
# deque([np.float64(0.8112), np.float64(0.8119), np.float64(0.81185), np.float64(0.80215), np.float64(0.8089)], maxlen=5)
# deque([np.float64(0.8111), np.float64(0.81235), np.float64(0.81665), np.float64(0.80695), np.float64(0.81065)], maxlen=5)
# deque([np.float64(0.80435), np.float64(0.8085), np.float64(0.80475), np.float64(0.8095), np.float64(0.80315)], maxlen=5)
# deque([np.float64(0.7935), np.float64(0.80965), np.float64(0.79865), np.float64(0.8064), np.float64(0.80205)], maxlen=5)
# deque([np.float64(0.8061), np.float64(0.81095), np.float64(0.81325), np.float64(0.8121), np.float64(0.8116)], maxlen=5)
# deque([np.float64(0.8133), np.float64(0.8078), np.float64(0.81275), np.float64(0.8092), np.float64(0.80675)], maxlen=5)
# deque([np.float64(0.8075), np.float64(0.8032), np.float64(0.81325), np.float64(0.81625), np.float64(0.81055)], maxlen=5)
# End of iteration best fly: 4 with fitness: -0.812
# Best fly history: [np.float64(0.8111), np.float64(0.81235), np.float64(0.81665), np.float64(0.80695), np.float64(0.81065)]
# deque([np.float64(0.81235), np.float64(0.81665), np.float64(0.80695), np.float64(0.81065), np.float64(0.81015)], maxlen=5)
#
# Iteration: 17
# Best fly 4 recalculated fitness: -0.811
# Best fly history: [np.float64(0.81235), np.float64(0.81665), np.float64(0.80695), np.float64(0.81065), np.float64(0.81015)]
# deque([np.float64(0.8099), np.float64(0.8083), np.float64(0.80355), np.float64(0.80375), np.float64(0.8032)], maxlen=5)
# deque([np.float64(0.804), np.float64(0.806), np.float64(0.804), np.float64(0.79975), np.float64(0.801)], maxlen=5)
# deque([np.float64(0.80765), np.float64(0.81565), np.float64(0.807), np.float64(0.80975), np.float64(0.80755)], maxlen=5)
# deque([np.float64(0.8119), np.float64(0.81185), np.float64(0.80215), np.float64(0.8089), np.float64(0.806)], maxlen=5)
# deque([np.float64(0.8085), np.float64(0.80475), np.float64(0.8095), np.float64(0.80315), np.float64(0.8043)], maxlen=5)
# deque([np.float64(0.80965), np.float64(0.79865), np.float64(0.8064), np.float64(0.80205), np.float64(0.8064)], maxlen=5)
# deque([np.float64(0.81095), np.float64(0.81325), np.float64(0.8121), np.float64(0.8116), np.float64(0.80925)], maxlen=5)
# deque([np.float64(0.8078), np.float64(0.81275), np.float64(0.8092), np.float64(0.80675), np.float64(0.81275)], maxlen=5)
# deque([np.float64(0.8032), np.float64(0.81325), np.float64(0.81625), np.float64(0.81055), np.float64(0.81315)], maxlen=5)
# End of iteration best fly: 7 with fitness: -0.812
# Best fly history: [np.float64(0.81095), np.float64(0.81325), np.float64(0.8121), np.float64(0.8116), np.float64(0.80925)]
# deque([np.float64(0.81325), np.float64(0.8121), np.float64(0.8116), np.float64(0.80925), np.float64(0.81405)], maxlen=5)
#
# Iteration: 18
# Best fly 7 recalculated fitness: -0.812
# Best fly history: [np.float64(0.81325), np.float64(0.8121), np.float64(0.8116), np.float64(0.80925), np.float64(0.81405)]
# deque([np.float64(0.8083), np.float64(0.80355), np.float64(0.80375), np.float64(0.8032), np.float64(0.80695)], maxlen=5)
# deque([np.float64(0.806), np.float64(0.804), np.float64(0.79975), np.float64(0.801), np.float64(0.8025)], maxlen=5)
# deque([np.float64(0.81565), np.float64(0.807), np.float64(0.80975), np.float64(0.80755), np.float64(0.80835)], maxlen=5)
# deque([np.float64(0.81185), np.float64(0.80215), np.float64(0.8089), np.float64(0.806), np.float64(0.8118)], maxlen=5)
# deque([np.float64(0.81665), np.float64(0.80695), np.float64(0.81065), np.float64(0.81015), np.float64(0.80885)], maxlen=5)
# deque([np.float64(0.80475), np.float64(0.8095), np.float64(0.80315), np.float64(0.8043), np.float64(0.80645)], maxlen=5)
# deque([np.float64(0.8168), np.float64(0.81635), np.float64(0.8163), np.float64(0.81135), np.float64(0.82285)], maxlen=5)
# deque([np.float64(0.81265), np.float64(0.8108), np.float64(0.81965), np.float64(0.81065), np.float64(0.81185)], maxlen=5)
# deque([np.float64(0.81795), np.float64(0.81325), np.float64(0.82125), np.float64(0.8089), np.float64(0.81415)], maxlen=5)
# deque([np.float64(0.80465), np.float64(0.80155), np.float64(0.80395), np.float64(0.80785), np.float64(0.81065)], maxlen=5)
# deque([np.float64(0.81605), np.float64(0.81815), np.float64(0.817), np.float64(0.8163), np.float64(0.81925)], maxlen=5)
# deque([np.float64(0.818), np.float64(0.8154), np.float64(0.81545), np.float64(0.81415), np.float64(0.8204)], maxlen=5)
# deque([np.float64(0.80865), np.float64(0.8203), np.float64(0.80875), np.float64(0.81045), np.float64(0.81485)], maxlen=5)
# deque([np.float64(0.80805), np.float64(0.81635), np.float64(0.8206), np.float64(0.81525), np.float64(0.81755)], maxlen=5)
# deque([np.float64(0.8118), np.float64(0.8052), np.float64(0.80465), np.float64(0.80165), np.float64(0.8114)], maxlen=5)
# End of iteration best fly: 5 with fitness: -0.818
# Best fly history: [np.float64(0.82025), np.float64(0.81575), np.float64(0.8178), np.float64(0.81385), np.float64(0.8204)]
# deque([np.float64(0.81575), np.float64(0.8178), np.float64(0.81385), np.float64(0.8204), np.float64(0.81835)], maxlen=5)
#
# Iteration: 192
# Best fly 5 recalculated fitness: -0.817
# Best fly history: [np.float64(0.81575), np.float64(0.8178), np.float64(0.81385), np.float64(0.8204), np.float64(0.81835)]
# deque([np.float64(0.81635), np.float64(0.8163), np.float64(0.81135), np.float64(0.82285), np.float64(0.81465)], maxlen=5)
# deque([np.float64(0.8108), np.float64(0.81965), np.float64(0.81065), np.float64(0.81185), np.float64(0.80985)], maxlen=5)
# deque([np.float64(0.81325), np.float64(0.82125), np.float64(0.8089), np.float64(0.81415), np.float64(0.8135)], maxlen=5)
# deque([np.float64(0.80155), np.float64(0.80395), np.float64(0.80785), np.float64(0.81065), np.float64(0.807)], maxlen=5)
# deque([np.float64(0.81815), np.float64(0.817), np.float64(0.8163), np.float64(0.81925), np.float64(0.81495)], maxlen=5)
# deque([np.float64(0.8154), np.float64(0.81545), np.float64(0.81415), np.float64(0.8204), np.float64(0.81715)], maxlen=5)
# deque([np.float64(0.8203), np.float64(0.80875), np.float64(0.81045), np.float64(0.81485), np.float64(0.80585)], maxlen=5)
# deque([np.float64(0.81635), np.float64(0.8206), np.float64(0.81525), np.float64(0.81755), np.float64(0.80895)], maxlen=5)
# deque([np.float64(0.8052), np.float64(0.80465), np.float64(0.80165), np.float64(0.8114), np.float64(0.81375)], maxlen=5)
# End of iteration best fly: 4 with fitness: -0.817
# Best fly history: [np.float64(0.81815), np.float64(0.817), np.float64(0.8163), np.float64(0.81925), np.float64(0.81495)]
# deque([np.float64(0.817), np.float64(0.8163), np.float64(0.81925), np.float64(0.81495), np.float64(0.8137)], maxlen=5)
#
# Iteration: 193
# Best fly 4 recalculated fitness: -0.816
# deque([np.float64(0.8204), np.float64(0.81835), np.float64(0.81165), np.float64(0.823), np.float64(0.81015)], maxlen=5)
#
# Iteration: 195
# Best fly 5 recalculated fitness: -0.817
# Best fly history: [np.float64(0.8204), np.float64(0.81835), np.float64(0.81165), np.float64(0.823), np.float64(0.81015)]
# deque([np.float64(0.82285), np.float64(0.81465), np.float64(0.81335), np.float64(0.8175), np.float64(0.8091)], maxlen=5)
# deque([np.float64(0.81185), np.float64(0.80985), np.float64(0.81745), np.float64(0.8191), np.float64(0.82145)], maxlen=5)
# deque([np.float64(0.81415), np.float64(0.8135), np.float64(0.8158), np.float64(0.8112), np.float64(0.8166)], maxlen=5)
# deque([np.float64(0.81065), np.float64(0.807), np.float64(0.8092), np.float64(0.8071), np.float64(0.79925)], maxlen=5)
# deque([np.float64(0.81925), np.float64(0.81495), np.float64(0.8137), np.float64(0.81965), np.float64(0.81935)], maxlen=5)
# New best found! Fly 4: -0.817
# New best history: [np.float64(0.81925), np.float64(0.81495), np.float64(0.8137), np.float64(0.81965), np.float64(0.81935)]
# deque([np.float64(0.81835), np.float64(0.81165), np.float64(0.823), np.float64(0.81015), np.float64(0.8127)], maxlen=5)
# deque([np.float64(0.8204), np.float64(0.81715), np.float64(0.8142), np.float64(0.81525), np.float64(0.81635)], maxlen=5)
# deque([np.float64(0.81485), np.float64(0.80585), np.float64(0.80905), np.float64(0.80665), np.float64(0.806)], maxlen=5)
# deque([np.float64(0.81755), np.float64(0.80895), np.float64(0.8114), np.float64(0.8185), np.float64(0.8154)], maxlen=5)
# deque([np.float64(0.8114), np.float64(0.81375), np.float64(0.81595), np.float64(0.8115), np.float64(0.8101)], maxlen=5)
# End of iteration best fly: 4 with fitness: -0.817
# Best fly history: [np.float64(0.81925), np.float64(0.81495), np.float64(0.8137), np.float64(0.81965), np.float64(0.81935)]
# deque([np.float64(0.81495), np.float64(0.8137), np.float64(0.81965), np.float64(0.81935), np.float64(0.81735)], maxlen=5)
#
# Iteration: 196
# Best fly 4 recalculated fitness: -0.817
# Best fly history: [np.float64(0.81495), np.float64(0.8137), np.float64(0.81965), np.float64(0.81935), np.float64(0.81735)]
# deque([np.float64(0.81465), np.float64(0.81335), np.float64(0.8175), np.float64(0.8091), np.float64(0.81325)], maxlen=5)
# deque([np.float64(0.80985), np.float64(0.81745), np.float64(0.8191), np.float64(0.82145), np.float64(0.8165)], maxlen=5)
# deque([np.float64(0.8135), np.float64(0.8158), np.float64(0.8112), np.float64(0.8166), np.float64(0.80755)], maxlen=5)
# deque([np.float64(0.807), np.float64(0.8092), np.float64(0.8071), np.float64(0.79925), np.float64(0.8079)], maxlen=5)
# deque([np.float64(0.81165), np.float64(0.823), np.float64(0.81015), np.float64(0.8127), np.float64(0.81475)], maxlen=5)
# deque([np.float64(0.81715), np.float64(0.8142), np.float64(0.81525), np.float64(0.81635), np.float64(0.8167)], maxlen=5)
# deque([np.float64(0.80585), np.float64(0.80905), np.float64(0.80665), np.float64(0.806), np.float64(0.80685)], maxlen=5)
# deque([np.float64(0.80895), np.float64(0.8114), np.float64(0.8185), np.float64(0.8154), np.float64(0.8163)], maxlen=5)
# deque([np.float64(0.81375), np.float64(0.81595), np.float64(0.8115), np.float64(0.8101), np.float64(0.8129)], maxlen=5)
# End of iteration best fly: 4 with fitness: -0.817
# Best fly history: [np.float64(0.81495), np.float64(0.8137), np.float64(0.81965), np.float64(0.81935), np.float64(0.81735)]
# deque([np.float64(0.8137), np.float64(0.81965), np.float64(0.81935), np.float64(0.81735), np.float64(0.81955)], maxlen=5)
#
# Iteration: 197
# Best fly 4 recalculated fitness: -0.818
# Best fly history: [np.float64(0.8137), np.float64(0.81965), np.float64(0.81935), np.float64(0.81735), np.float64(0.81955)]
# deque([np.float64(0.81335), np.float64(0.8175), np.float64(0.8091), np.float64(0.81325), np.float64(0.8129)], maxlen=5)
# deque([np.float64(0.81745), np.float64(0.8191), np.float64(0.82145), np.float64(0.8165), np.float64(0.8206)], maxlen=5)
# New best found! Fly 1: -0.819
# New best history: [np.float64(0.81745), np.float64(0.8191), np.float64(0.82145), np.float64(0.8165), np.float64(0.8206)]
# deque([np.float64(0.8158), np.float64(0.8112), np.float64(0.8166), np.float64(0.80755), np.float64(0.81275)], maxlen=5)
# deque([np.float64(0.8092), np.float64(0.8071), np.float64(0.79925), np.float64(0.8079), np.float64(0.80715)], maxlen=5)
# deque([np.float64(0.81965), np.float64(0.81935), np.float64(0.81735), np.float64(0.81955), np.float64(0.8163)], maxlen=5)
# deque([np.float64(0.823), np.float64(0.81015), np.float64(0.8127), np.float64(0.81475), np.float64(0.80975)], maxlen=5)
# deque([np.float64(0.8142), np.float64(0.81525), np.float64(0.81635), np.float64(0.8167), np.float64(0.81665)], maxlen=5)
# deque([np.float64(0.80905), np.float64(0.80665), np.float64(0.806), np.float64(0.80685), np.float64(0.8031)], maxlen=5)
# deque([np.float64(0.8114), np.float64(0.8185), np.float64(0.8154), np.float64(0.8163), np.float64(0.81635)], maxlen=5)
# deque([np.float64(0.81595), np.float64(0.8115), np.float64(0.8101), np.float64(0.8129), np.float64(0.81135)], maxlen=5)
# End of iteration best fly: 1 with fitness: -0.819
# Best fly history: [np.float64(0.81745), np.float64(0.8191), np.float64(0.82145), np.float64(0.8165), np.float64(0.8206)]
# deque([np.float64(0.8191), np.float64(0.82145), np.float64(0.8165), np.float64(0.8206), np.float64(0.81525)], maxlen=5)
#
# Iteration: 198
# Best fly 1 recalculated fitness: -0.819
# Best fly history: [np.float64(0.8191), np.float64(0.82145), np.float64(0.8165), np.float64(0.8206), np.float64(0.81525)]
# deque([np.float64(0.8175), np.float64(0.8091), np.float64(0.81325), np.float64(0.8129), np.float64(0.80925)], maxlen=5)
# deque([np.float64(0.8112), np.float64(0.8166), np.float64(0.80755), np.float64(0.81275), np.float64(0.8106)], maxlen=5)
# deque([np.float64(0.8071), np.float64(0.79925), np.float64(0.8079), np.float64(0.80715), np.float64(0.8099)], maxlen=5)
# deque([np.float64(0.81935), np.float64(0.81735), np.float64(0.81955), np.float64(0.8163), np.float64(0.8126)], maxlen=5)
# deque([np.float64(0.81015), np.float64(0.8127), np.float64(0.81475), np.float64(0.80975), np.float64(0.80645)], maxlen=5)
# deque([np.float64(0.81525), np.float64(0.81635), np.float64(0.8167), np.float64(0.81665), np.float64(0.81875)], maxlen=5)
# deque([np.float64(0.80665), np.float64(0.806), np.float64(0.80685), np.float64(0.8031), np.float64(0.80885)], maxlen=5)
# deque([np.float64(0.8185), np.float64(0.8154), np.float64(0.8163), np.float64(0.81635), np.float64(0.80475)], maxlen=5)
# deque([np.float64(0.8115), np.float64(0.8101), np.float64(0.8129), np.float64(0.81135), np.float64(0.8176)], maxlen=5)
# End of iteration best fly: 1 with fitness: -0.819
# Best fly history: [np.float64(0.8191), np.float64(0.82145), np.float64(0.8165), np.float64(0.8206), np.float64(0.81525)]
# deque([np.float64(0.82145), np.float64(0.8165), np.float64(0.8206), np.float64(0.81525), np.float64(0.8115)], maxlen=5)
#
# Iteration: 199
# Best fly 1 recalculated fitness: -0.817
# Best fly history: [np.float64(0.82145), np.float64(0.8165), np.float64(0.8206), np.float64(0.81525), np.float64(0.8115)]
# deque([np.float64(0.8091), np.float64(0.81325), np.float64(0.8129), np.float64(0.80925), np.float64(0.81205)], maxlen=5)
# deque([np.float64(0.8166), np.float64(0.80755), np.float64(0.81275), np.float64(0.8106), np.float64(0.81)], maxlen=5)
# deque([np.float64(0.79925), np.float64(0.8079), np.float64(0.80715), np.float64(0.8099), np.float64(0.8099)], maxlen=5)
# deque([np.float64(0.81735), np.float64(0.81955), np.float64(0.8163), np.float64(0.8126), np.float64(0.8194)], maxlen=5)
# deque([np.float64(0.8127), np.float64(0.81475), np.float64(0.80975), np.float64(0.80645), np.float64(0.81455)], maxlen=5)
# deque([np.float64(0.81635), np.float64(0.8167), np.float64(0.81665), np.float64(0.81875), np.float64(0.81625)], maxlen=5)
# deque([np.float64(0.806), np.float64(0.80685), np.float64(0.8031), np.float64(0.80885), np.float64(0.8086)], maxlen=5)
# deque([np.float64(0.8154), np.float64(0.8163), np.float64(0.81635), np.float64(0.80475), np.float64(0.81045)], maxlen=5)
# deque([np.float64(0.8101), np.float64(0.8129), np.float64(0.81135), np.float64(0.8176), np.float64(0.8088)], maxlen=5)
# End of iteration best fly: 4 with fitness: -0.818
# Best fly history: [np.float64(0.81735), np.float64(0.81955), np.float64(0.8163), np.float64(0.8126), np.float64(0.8194)]

# %%
np.save('realbest_fly_weights.npy', newweihgts)

# %%
newweihgts = np.load('realbest_fly_weights.npy')

# %%
#Saving fine tuned weights

cloned_model = q_network
    # Reshape fly's weights to match the model's weight shape
reshaped_fly = reshape_to_model_weights(newweihgts)
    
    # Load the reshaped weights into the cloned model
cloned_model.load_state_dict(dict(zip([name for name, _ in cloned_model.named_parameters()], reshaped_fly)))


# save the model as dfoFineTuned
torch.save(cloned_model.state_dict(), 'dfoFineTuned.pt')

# %%
# Out:
# 111513
